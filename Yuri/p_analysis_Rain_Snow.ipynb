# %% [markdown]
# # DB 종료 후 DF 작업하기

# %% [markdown]
# - m_df.csv는 날짜, 미세먼지농도, 강수량, 적설량(cm), 평일/주말, 계절, 연도, 미세먼지등급, 강수량등급, 적설량등급, 적설량(mm)
#
# - m_df2.csv는 m_df와 동일한 컬럼 갯수와 이름을 가지지만, 미세먼지농도, 강수량, 적설량(mm) 3개 컬럼이 min-max스케일 됨

# %% [markdown]
# 여기서부터 시작

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymysql
# from sqlalchemy import create_engine
# !pip install scikit-learn
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import skew, kurtosis
import os

# %%
# matplotlib 한글 사용

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %% [markdown]
# ### 데이터 불러와서 가공하기

# %%
fd_df = pd.read_csv('./data/fine_dust.csv')
wt_df = pd.read_csv('./data/weather_data.csv')
fd_df.columns, wt_df.columns
# Out:
# (Index(['Unnamed: 0', 'station_id', 'station_name', 'date', 'fine_dust(㎍/㎥)'], dtype='object'),
#  Index(['Unnamed: 0', 'station_id', 'station_name', 'date_time', 'avg_temp',
#         'min_temp', 'max_temp', 'daily_precipitation', 'avg_wind_speed',
#         'daily_snow_depth'],
#        dtype='object'))

# %%
# 필요 컬럼만 자르기
fd_df = fd_df.loc[:, ['date', 'fine_dust(㎍/㎥)']] 
fd_df.columns=['Date', 'Fine_dust(㎍/㎥)']
wt_df = wt_df.loc[:, ['date_time', 'daily_precipitation', 'daily_snow_depth']]
wt_df.columns=['Date', 'Precipitation(mm)', 'Snow_depth(cm)']
fd_df.info(), wt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323 entries, 0 to 1322
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1323 non-null   object
#  1   Fine_dust(㎍/㎥)  1323 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 20.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1399 entries, 0 to 1398
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1399 non-null   object
#  1   Precipitation(mm)  591 non-null    float64
#  2   Snow_depth(cm)     92 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 32.9+ KB
# (None, None)

# %%
# 미세먼지에서 아래 날짜 누락됨 (날짜 자체가 없음)
# Timestamp('2021-01-23 00:00:00'),
#  Timestamp('2021-03-01 00:00:00'),
#  Timestamp('2021-03-28 00:00:00'),
#  Timestamp('2021-04-04 00:00:00'),
#  Timestamp('2021-05-28 00:00:00'),
#  Timestamp('2021-05-30 00:00:00'),
#  Timestamp('2021-10-02 00:00:00'),
#  Timestamp('2021-11-21 00:00:00'),
#  Timestamp('2021-11-22 00:00:00'),
#  Timestamp('2022-02-15 00:00:00'),
#  Timestamp('2022-03-07 00:00:00'),
#  Timestamp('2022-03-14 00:00:00'),
#  Timestamp('2022-03-18 00:00:00'),
#  Timestamp('2022-03-19 00:00:00'),
#  Timestamp('2022-03-26 00:00:00'),
#  Timestamp('2022-04-01 00:00:00'),
#  Timestamp('2022-04-15 00:00:00'),
#  Timestamp('2022-04-29 00:00:00'),
#  Timestamp('2022-06-06 00:00:00'),
#  Timestamp('2022-06-07 00:00:00'),
#  Timestamp('2022-06-24 00:00:00'),
#  Timestamp('2022-06-30 00:00:00'),
#  Timestamp('2022-08-02 00:00:00'),
#  Timestamp('2022-08-08 00:00:00'),
#  Timestamp('2022-08-09 00:00:00'),
#  Timestamp('2022-09-05 00:00:00'),
#  Timestamp('2022-09-06 00:00:00'),
#  Timestamp('2022-10-06 00:00:00'),
#  Timestamp('2022-10-08 00:00:00'),
#  Timestamp('2022-10-10 00:00:00'),
#  Timestamp('2022-10-25 00:00:00'),
#  Timestamp('2022-10-26 00:00:00'),
#  Timestamp('2023-01-14 00:00:00'),
#  Timestamp('2023-01-15 00:00:00'),
#  Timestamp('2023-04-05 00:00:00'),
#  Timestamp('2023-05-05 00:00:00'),
#  Timestamp('2023-05-06 00:00:00'),
#  Timestamp('2023-06-09 00:00:00'),
#  Timestamp('2023-07-09 00:00:00'),
#  Timestamp('2023-08-08 00:00:00'),
#  Timestamp('2023-08-09 00:00:00'),
#  Timestamp('2023-08-10 00:00:00'),
#  Timestamp('2023-09-08 00:00:00'),
#  Timestamp('2023-09-21 00:00:00'),
#  Timestamp('2023-09-26 00:00:00'),
#  Timestamp('2023-11-10 00:00:00'),
#  Timestamp('2023-12-11 00:00:00'),
#  Timestamp('2023-12-12 00:00:00'),
#  Timestamp('2023-12-14 00:00:00'),
#  Timestamp('2023-12-15 00:00:00'),
#  Timestamp('2024-01-20 00:00:00'),
#  Timestamp('2024-02-05 00:00:00'),
#  Timestamp('2024-02-21 00:00:00'),
#  Timestamp('2024-02-22 00:00:00'),
#  Timestamp('2024-03-25 00:00:00'),
#  Timestamp('2024-03-26 00:00:00'),
#  Timestamp('2024-03-27 00:00:00'),
#  Timestamp('2024-05-06 00:00:00'),
#  Timestamp('2024-05-15 00:00:00'),
#  Timestamp('2024-05-16 00:00:00'),
#  Timestamp('2024-05-17 00:00:00'),
#  Timestamp('2024-06-03 00:00:00'),
#  Timestamp('2024-07-22 00:00:00'),
#  Timestamp('2024-07-23 00:00:00'),
#  Timestamp('2024-07-24 00:00:00'),
#  Timestamp('2024-09-12 00:00:00'),
#  Timestamp('2024-09-16 00:00:00'),
#  Timestamp('2024-09-21 00:00:00'),
#  Timestamp('2024-09-22 00:00:00'),
#  Timestamp('2024-09-23 00:00:00'),
#  Timestamp('2024-09-24 00:00:00'),
#  Timestamp('2024-09-27 00:00:00'),
#  Timestamp('2024-10-19 00:00:00'),
#  Timestamp('2024-10-20 00:00:00'),
#  Timestamp('2024-10-23 00:00:00'),
#  Timestamp('2024-10-29 00:00:00')

# %%
# 미세먼지, 비, 눈 데이터프레임 합치기
df = pd.merge(left=fd_df, right=wt_df, how='outer', on="Date")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1399 entries, 0 to 1398
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1399 non-null   object
#  1   Fine_dust(㎍/㎥)     1323 non-null   float64
#  2   Precipitation(mm)  591 non-null    float64
#  3   Snow_depth(cm)     92 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 43.8+ KB

# %% [markdown]
# ### 날짜를 기준으로 년, 계절, 평일/주말(+공휴일) 나누기

# %% [markdown]
# df의 Date의 타입 변경

# %%
df.info() # date 타입이 object임을 확인
df['Date'] = pd.to_datetime(df['Date'])
df.info() # date타입이 datetime64[ns]으로 변경됨
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1399 entries, 0 to 1398
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1399 non-null   object
#  1   Fine_dust(㎍/㎥)     1323 non-null   float64
#  2   Precipitation(mm)  591 non-null    float64
#  3   Snow_depth(cm)     92 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 43.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1399 entries, 0 to 1398
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1399 non-null   datetime64[ns]
#  1   Fine_dust(㎍/㎥)     1323 non-null   float64
#  2   Precipitation(mm)  591 non-null    float64
#  3   Snow_depth(cm)     92 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 43.8 KB

# %%
# fine_dust["Date"]에 따라 평일, 주말 나누기(월~금 : 0~4, 토일 : 5, 6)
df["Day"] = np.where(df["Date"].dt.weekday < 5, "Weekday", "Weekend")
df
# Out:
#            Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm)      Day
# 0    2021-01-01            36.0                NaN             NaN  Weekday
# 1    2021-01-02            43.0                NaN             NaN  Weekend
# 2    2021-01-03            47.0                NaN             NaN  Weekend
# 3    2021-01-04            50.0                0.0             0.0  Weekday
# 4    2021-01-05            37.0                0.0             0.0  Weekday
# ...         ...             ...                ...             ...      ...
# 1394 2024-10-26            26.0                NaN             NaN  Weekend
# 1395 2024-10-27            27.0                0.0             NaN  Weekend
# 1396 2024-10-28            38.0                0.0             NaN  Weekday
# 1397 2024-10-29             NaN                0.0             NaN  Weekday
# 1398 2024-10-30            28.0                NaN             NaN  Weekday
#
# [1399 rows x 5 columns]

# %% [markdown]
# 공휴일 데이터인 hd의 date의 타입 변경

# %%
hd = pd.read_csv('./data/hd_21_24.csv', encoding="CP949")
hd.rename(columns={"일시":"date"}, inplace=True)
hd['date'] = pd.to_datetime(hd['date'])
hd.columns=['Date', 'dateName']
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      66 non-null     datetime64[ns]
#  1   dateName  66 non-null     object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# fine_dust['Day_type'] 만들어서 평일/주말+공휴일로 나누기 (공휴일은 주말로 처리)

# %%
# df와 hd DF 합치기
m_df = pd.merge(df, hd, how='outer', on='Date')
m_df.head()
# Out:
#         Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm)      Day  \
# 0 2021-01-01            36.0                NaN             NaN  Weekday
# 1 2021-01-02            43.0                NaN             NaN  Weekend
# 2 2021-01-03            47.0                NaN             NaN  Weekend
# 3 2021-01-04            50.0                0.0             0.0  Weekday
# 4 2021-01-05            37.0                0.0             0.0  Weekday
#
#   dateName
# 0     1월1일
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# date_name2 시리즈를 만들어서 
# dateName이 있다면, 주말처리
# 없다면, Day의 평일/주말 값을 가져오기
# apply 활용
date_name2 = m_df.apply(lambda row : 'Weekend' 
                        if str(row['dateName']) != 'nan' else row['Day'], axis=1)

# %%
# apply 활용해서 평일, 주말(+공휴일)로 나눈 값을
# 합친 df에 적용하기 
m_df['Day_type'] = date_name2

# 필요한 컬럼/행으로 자르기
m_df = m_df.loc[:, ['Date', 'Fine_dust(㎍/㎥)',  'Precipitation(mm)', 'Snow_depth(cm)', 'Day_type']]
m_df = m_df.iloc[:1329, :]
m_df.head(1), m_df.tail(1)
# Out:
# (        Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type
#  0 2021-01-01            36.0                NaN             NaN  Weekend,
#             Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type
#  1328 2024-08-21            13.0               42.2             NaN  Weekday)

# %% [markdown]
# 병합된 DF을 계절별, 연도별로 구분하기

# %%
# Date를 기준으로 계절별 구분 
# (봄: 3~5, 여름: 6~8, 가을: 9~11, 겨울: 12~2)
conditions = [
    ( m_df["Date"].dt.month >= 3 ) & ( m_df["Date"].dt.month <= 5 ),
    ( m_df["Date"].dt.month >= 6 ) & ( m_df["Date"].dt.month <= 8 ),
    ( m_df["Date"].dt.month >= 9 ) & ( m_df["Date"].dt.month <= 11 ),
]
Season = ["Spring", "Summer", "Fall"]
m_df["Season"] = np.select(conditions, Season, default="Winter")

print( m_df.iloc[58:60, :] )
print( m_df.iloc[150:152, :] )
print( m_df.iloc[242:244, :] )
print( m_df.iloc[333:335, :] )
# Out:
#          Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 58 2021-02-28            32.0                NaN             NaN  Weekend
# 59 2021-03-01             NaN               67.5             2.3  Weekend
#
#     Season
# 58  Winter
# 59  Spring
#           Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 150 2021-05-31            59.0                4.0             NaN  Weekday
# 151 2021-06-01            52.0                3.2             NaN  Weekday
#
#      Season
# 150  Spring
# 151  Summer
#           Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 242 2021-08-31            37.0               77.4             NaN  Weekday
# 243 2021-09-01             9.0                0.8             NaN  Weekday
#
#      Season
# 242  Summer
# 243    Fall
#           Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 333 2021-11-30            31.0               27.2             NaN  Weekday
# 334 2021-12-01            19.0                NaN             NaN  Weekday
#
#      Season
# 333    Fall
# 334  Winter

# %%
# Date를 기준으로 연도별 구분 
m_df["Year"] = m_df["Date"].dt.year
print( m_df.iloc[364:366, :] )
# Out:
#           Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 364 2021-12-31            21.0                NaN             NaN  Weekday
# 365 2022-01-01            34.0                NaN             NaN  Weekend
#
#      Season  Year
# 364  Winter  2021
# 365  Winter  2022

# %% [markdown]
# 결측치 처리

# %%
# 미세먼지 - 결측치는 계절별 평균으로 입력

# m_df[m_df['Fine_dust(㎍/㎥)'].isnull()] # 미세먼지에서 결측치 확인 

# 계절별 평균 구하기
Season_means = m_df.groupby('Season')['Fine_dust(㎍/㎥)'].mean()
Season_means
                # Fall      29.830116
                # Spring    57.397101
                # Summer    28.134503
                # Winter    46.641509

# 결측치행에 평균값 넣기
m_df["Fine_dust(㎍/㎥)"] = m_df["Fine_dust(㎍/㎥)"]. \
                        fillna(m_df.groupby("Season")["Fine_dust(㎍/㎥)"].transform("mean"))

m_df[m_df['Fine_dust(㎍/㎥)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Fine_dust(㎍/㎥), Precipitation(mm), Snow_depth(cm), Day_type, Season, Year]
# Index: []

# %%
# 강수량, 적설량 - 결측치는 0으로 입력
m_df.fillna({"Precipitation(mm)": 0, "Snow_depth(cm)": 0}, inplace=True)
m_df.isnull().sum()
# Out:
# Date                 0
# Fine_dust(㎍/㎥)       0
# Precipitation(mm)    0
# Snow_depth(cm)       0
# Day_type             0
# Season               0
# Year                 0
# dtype: int64

# %% [markdown]
# 미세먼지/강수량/적설량 등급 메기기

# %%
# 미세먼지
# 좋음 (0-30 ㎍/m³) → Good
# 보통 (31-80 ㎍/m³) → Moderate
# 나쁨 (81-150 ㎍/m³) → Bad
# 매우 나쁨 (151 ㎍/m³ 이상) → Very Bad

# 새로운 컬럼을 생성하고 조건에 따라 값 입력
conditionlist = [
    (m_df['Fine_dust(㎍/㎥)'] <= 30),
    (m_df['Fine_dust(㎍/㎥)'] > 30) & (m_df['Fine_dust(㎍/㎥)'] <= 80),
    (m_df['Fine_dust(㎍/㎥)'] > 80) & (m_df['Fine_dust(㎍/㎥)'] <= 150),
    (m_df['Fine_dust(㎍/㎥)'] > 150),
]

values = ['Good', 'Normal', 'Bad', 'Very_bad']

m_df["FD_Grade"] = np.select(conditionlist, values, default="Unknown")
m_df.head(2)
# Out:
#         Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 0 2021-01-01            36.0                0.0             0.0  Weekend
# 1 2021-01-02            43.0                0.0             0.0  Weekend
#
#    Season  Year FD_Grade
# 0  Winter  2021   Normal
# 1  Winter  2021   Normal

# %%
# 강수량
# 건조 (Dry): 강수량이 없는 날, 즉 0mm
# 약강수 (Light): 0mm < 강수량 ≤ 10mm
# 중강수 (Moderate): 10mm < 강수량 ≤ 50mm
# 대강수 (Heavy): 강수량 > 50mm

# 새로운 컬럼을 생성하고 조건에 따라 값 입력
conditionlist = [
    (m_df['Precipitation(mm)'] == 00),
    (m_df['Precipitation(mm)'] > 00) & (m_df['Precipitation(mm)'] <= 10),
    (m_df['Precipitation(mm)'] > 10) & (m_df['Precipitation(mm)'] <= 50),
    (m_df['Precipitation(mm)'] > 50),
]

values = ['Dry', 'Light', 'Moderate', 'Heavy']

m_df["P_Grade"] = np.select(conditionlist, values, default="Dry")
m_df.head(2)
# Out:
#         Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 0 2021-01-01            36.0                0.0             0.0  Weekend
# 1 2021-01-02            43.0                0.0             0.0  Weekend
#
#    Season  Year FD_Grade P_Grade
# 0  Winter  2021   Normal     Dry
# 1  Winter  2021   Normal     Dry

# %%
# 적설량
# 무적설 (No Snow): 적설량 = 0cm
# 소적설 (Light Snow): 0cm < 적설량 ≤ 2cm
# 중적설 (Moderate Snow): 2cm < 적설량 ≤ 10cm
# 대적설 (Heavy Snow): 적설량 > 10cm

# 새로운 컬럼을 생성하고 조건에 따라 값 입력
conditionlist = [
    (m_df['Snow_depth(cm)'] == 00),
    (m_df['Snow_depth(cm)'] > 00) & (m_df['Snow_depth(cm)'] <= 2),
    (m_df['Snow_depth(cm)'] > 2) & (m_df['Snow_depth(cm)'] <= 10),
    (m_df['Snow_depth(cm)'] > 10),
]

values = ['No_Snow', 'Light_Snow', 'Moderate_Snow', 'Heavy_Snow']

m_df["S_Grade"] = np.select(conditionlist, values, default="Dry")
m_df.head(2)
# Out:
#         Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 0 2021-01-01            36.0                0.0             0.0  Weekend
# 1 2021-01-02            43.0                0.0             0.0  Weekend
#
#    Season  Year FD_Grade P_Grade  S_Grade
# 0  Winter  2021   Normal     Dry  No_Snow
# 1  Winter  2021   Normal     Dry  No_Snow

# %% [markdown]
# 범주화

# %%
# 범주화 - 계절/미세먼지등급/강수량등급/적설량등급
# 순서있는 범주형 : ordered = True, 순서 없는 범주형 : ordered = False
c_Season = ["Spring", "Summer", "Fall", "Winter"]
c_Season1 = CategoricalDtype(categories = c_Season, ordered = True)

c_FD_Grade = ['Good', 'Normal', 'Bad', 'Very_bad']
c_FD_Grade1 = CategoricalDtype(categories = c_FD_Grade, ordered = True)

c_P_Grade = ['Dry', 'Light', 'Moderate', 'Heavy']
c_P_Grade1 = CategoricalDtype(categories = c_P_Grade, ordered = True)

c_S_Grade = ['No_Snow', 'Light_Snow', 'Moderate_Snow', 'Heavy_Snow']
c_S_Grade1 = CategoricalDtype(categories = c_S_Grade, ordered = True)

m_df["Season"] = m_df["Season"].astype(c_Season1)
m_df["FD_Grade"] = m_df["FD_Grade"].astype(c_FD_Grade1)
m_df["P_Grade"] = m_df["P_Grade"].astype(c_P_Grade1)
m_df["S_Grade"] = m_df["S_Grade"].astype(c_S_Grade1)
m_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1329 entries, 0 to 1328
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1329 non-null   datetime64[ns]
#  1   Fine_dust(㎍/㎥)     1329 non-null   float64
#  2   Precipitation(mm)  1329 non-null   float64
#  3   Snow_depth(cm)     1329 non-null   float64
#  4   Day_type           1329 non-null   object
#  5   Season             1329 non-null   category
#  6   Year               1329 non-null   int32
#  7   FD_Grade           1329 non-null   category
#  8   P_Grade            1329 non-null   category
#  9   S_Grade            1329 non-null   category
# dtypes: category(4), datetime64[ns](1), float64(3), int32(1), object(1)
# memory usage: 63.2+ KB

# %% [markdown]
# ### 데이터 분석

# %% [markdown]
# 1. 단일 그룹 분석

# %% [markdown]
# - 강수량, 적설량 (단일 그룹 분석)

# %%
def group_analysis_by_single_column(df, group_col_name, col_name):
    # 전체 count를 위한 그룹화 (0 포함)
    total_counts = df.groupby(group_col_name, observed=True)[col_name].agg([
        ("Total_Count", "count"),
        ("Zero_Count", lambda x: (x == 0).sum()) # 0인 값만 갯수 세기
    ])
    
    # 0이 아닌 값들에 대한 통계
    non_zero_stats = df[df[col_name] != 0].groupby(group_col_name, observed=True)[col_name].agg([
        ("cnt_nz", "count"),    # count non-zero
        ("max", "max"),
        ("min_nz", "min"),      # min non-zero
        ("mean_nz", "mean"),    # mean non-zero
        ("median_nz", "median"),    # mean non-zero
        ("var_nz", "var")
    ])
    
    # 두 결과를 병합
    combined_stats = pd.concat([total_counts, non_zero_stats], axis=1)
        
    return combined_stats

# %% [markdown]
# - 강수량 (단일 그룹 분석)

# %%
# 강수량
# 단일 그룹 분석 결과를 데이터 프레임으로 저장
df_Year_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "Year", 
                    col_name = "Precipitation(mm)")
df_PGrade_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "P_Grade", 
                    col_name = "Precipitation(mm)")
df_Season_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "Season", 
                    col_name = "Precipitation(mm)")
df_day_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "Day_type", 
                    col_name = "Precipitation(mm)")

# 딕셔너리로 데이터프레입 합치기
combined_stats_p1 = {
    "Year": df_Year_stats,
    "Precipitation_Grade": df_PGrade_stats,
    "Season": df_Season_stats,
    "Day_Type": df_day_stats
}

print( "단일 그룹 분석 - 강수량")
# 결과 확인
for key, value in combined_stats_p1.items():
    print(f"\n\n{key} Stats (강수량):\n", value)
# Out:
# 단일 그룹 분석 - 강수량
#
#
# Year Stats (강수량):
#        Total_Count  Zero_Count  cnt_nz    max  min_nz    mean_nz  median_nz  \
# Year
# 2021          365         248     117   77.4     0.1  10.141026        3.5
# 2022          365         261     104  176.2     0.1  17.070192        3.1
# 2023          365         256     109   91.6     0.1  14.667890        4.4
# 2024          234         155      79  128.8     0.1  12.973418        4.1
#
#            var_nz
# Year
# 2021   286.951751
# 2022  1019.433375
# 2023   420.251459
# 2024   491.096592
#
#
# Precipitation_Grade Stats (강수량):
#            Total_Count  Zero_Count  cnt_nz    max  min_nz    mean_nz  \
# P_Grade
# Dry               920         920     NaN    NaN     NaN        NaN
# Light             279           0   279.0    9.9     0.1   2.582079
# Moderate          100           0   100.0   48.3    10.4  24.093000
# Heavy              30           0    30.0  176.2    50.3  81.860000
#
#           median_nz      var_nz
# P_Grade
# Dry             NaN         NaN
# Light           1.7    6.683131
# Moderate       20.5  124.108334
# Heavy          67.8  895.911448
#
#
# Season Stats (강수량):
#          Total_Count  Zero_Count  cnt_nz    max  min_nz    mean_nz  median_nz  \
# Season
# Spring          368         269      99   67.5     0.1  10.098990       3.10
# Summer          358         199     159  176.2     0.1  21.331447       6.40
# Fall            273         207      66  120.0     0.1  13.756061       4.85
# Winter          330         245      85   37.3     0.1   3.365882       1.10
#
#             var_nz
# Season
# Spring  227.295407
# Summer  955.422929
# Fall    440.788347
# Winter   39.086798
#
#
# Day_Type Stats (강수량):
#            Total_Count  Zero_Count  cnt_nz    max  min_nz    mean_nz  \
# Day_type
# Weekday           910         637     273  176.2     0.1  13.667033
# Weekend           419         283     136   76.0     0.1  13.635294
#
#           median_nz      var_nz
# Day_type
# Weekday        3.40  662.116850
# Weekend        4.55  331.045264

# %% [markdown]
# - 시각화 (단일 그룹)

# %% [markdown]
# - 강수량

# %%
# 비 온 날과 안 온날의 개수 세기

# Set up a 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(10, 7))
axes = axes.flatten()  # Flatten for easy indexing

# Define the keys and titles for each plot
keys = list(combined_stats_p1.keys())
titles = ["Year", "Precipitation Grade", "Season", "Day_Type"]

# Plot each dataset in a subplot
for i, key in enumerate(keys):
    value = combined_stats_p1[key]
    labels = value.index  # x-axis labels

    # Bar positions
    x = np.arange(len(labels))
    width = 0.35  # Width of the bars for 2 bars

    # Plot side-by-side bars for Zero_Count and Non-Zero Count (cnt_nz)
    axes[i].bar(x - width/2, value["Zero_Count"], width, label='Zero Count', color='orange')
    axes[i].bar(x + width/2, value["cnt_nz"], width, label='Non-Zero Count', color='lightgreen')

    # Labeling
    axes[i].set_title(f"{titles[i]} - Zero and Non-Zero Counts")
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(labels, rotation=45)
    axes[i].set_ylabel("Counts")
    axes[i].legend(loc="upper right")

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# 데이터 구조 확인
for group_name, df in combined_stats_p1.items():
    print(f"\n{group_name} 데이터프레임의 컬럼:")
    print(df.columns.tolist())
# Out:
# Year 데이터프레임의 컬럼:
# ['Total_Count', 'Zero_Count', 'cnt_nz', 'max', 'min_nz', 'mean_nz', 'median_nz', 'var_nz']
#
# Precipitation_Grade 데이터프레임의 컬럼:
# ['Total_Count', 'Zero_Count', 'cnt_nz', 'max', 'min_nz', 'mean_nz', 'median_nz', 'var_nz']
#
# Season 데이터프레임의 컬럼:
# ['Total_Count', 'Zero_Count', 'cnt_nz', 'max', 'min_nz', 'mean_nz', 'median_nz', 'var_nz']
#
# Day_Type 데이터프레임의 컬럼:
# ['Total_Count', 'Zero_Count', 'cnt_nz', 'max', 'min_nz', 'mean_nz', 'median_nz', 'var_nz']

# %%
df_Year_stats = df_Year_stats.reset_index()
df_PGrade_stats = df_PGrade_stats.reset_index()
df_Season_stats = df_Season_stats.reset_index()
df_day_stats = df_day_stats.reset_index()
df_day_stats
# Out:
#   Day_type  Total_Count  Zero_Count  cnt_nz    max  min_nz    mean_nz  \
# 0  Weekday          910         637     273  176.2     0.1  13.667033
# 1  Weekend          419         283     136   76.0     0.1  13.635294
#
#    median_nz      var_nz
# 0       3.40  662.116850
# 1       4.55  331.045264

# %%
year_ar = m_df.loc[:, "Year"]
PGrade_ar = m_df.loc[:, "P_Grade"]
Season_ar = m_df.loc[:, "Season"]
Day_ar = m_df.loc[:, "Day_type"]

year_dict = {}
for year in year_ar.unique():
    year_dict[year] = m_df[m_df['Year'] == year]["Precipitation(mm)"]

fig, ax = plt.subplots()
ax.boxplot(year_dict.values())
ax.set_xticklabels(list(year_dict.keys()))

# plt.xticks(['year', 'PGrade', 'Season', 'Day'], )
# plt.yticks(m_df["Precipitation(mm)"])

plt.show()

# %% [markdown]
# 적설량 (단일 그룹 분석)

# %%
# 적설량
# 단일 그룹 분석 결과를 데이터 프레임으로 저장
df_Year_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "Year", 
                    col_name = "Snow_depth(cm)")
df_SGrade_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "S_Grade", 
                    col_name = "Snow_depth(cm)")
df_Season_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "Season", 
                    col_name = "Snow_depth(cm)")
df_day_stats = group_analysis_by_single_column(
                    df = m_df, 
                    group_col_name = "Day_type", 
                    col_name = "Snow_depth(cm)")

# 딕셔너리로 데이터프레입 합치기
combined_stats_s1 = {
    "Year": df_Year_stats,
    "Snow_depth_Grade": df_SGrade_stats,
    "Season": df_Season_stats,
    "Day Type": df_day_stats
}

print( "단일 그룹 분석 - 적설량")
# 결과 확인
for key, value in combined_stats_s1.items():
    print(f"\n\n{key} Stats (적설량):\n", value)
# Out:
# 단일 그룹 분석 - 적설량
#
#
# Year Stats (적설량):
#        Total_Count  Zero_Count  cnt_nz   max  min_nz   mean_nz  median_nz  \
# Year
# 2021          365         340      25   5.1     0.1  2.176000        1.4
# 2022          365         334      31   5.0     0.1  1.529032        1.1
# 2023          365         349      16  12.2     0.2  2.806250        1.6
# 2024          234         216      18  13.8     0.2  3.866667        2.7
#
#          var_nz
# Year
# 2021   2.937733
# 2022   1.727462
# 2023  11.180625
# 2024  11.521176
#
#
# Snow_depth_Grade Stats (적설량):
#                 Total_Count  Zero_Count  cnt_nz   max  min_nz    mean_nz  \
# S_Grade
# No_Snow               1239        1239     NaN   NaN     NaN        NaN
# Light_Snow              54           0    54.0   2.0     0.1   0.950000
# Moderate_Snow           33           0    33.0   8.8     2.1   3.903030
# Heavy_Snow               3           0     3.0  13.8    10.2  12.066667
#
#                median_nz    var_nz
# S_Grade
# No_Snow              NaN       NaN
# Light_Snow           0.9  0.324434
# Moderate_Snow        3.6  1.872178
# Heavy_Snow          12.2  3.253333
#
#
# Season Stats (적설량):
#          Total_Count  Zero_Count  cnt_nz   max  min_nz   mean_nz  median_nz  \
# Season
# Spring          368         365     3.0   2.3     0.7  1.766667        2.3
# Summer          358         358     NaN   NaN     NaN       NaN        NaN
# Fall            273         273     NaN   NaN     NaN       NaN        NaN
# Winter          330         243    87.0  13.8     0.1  2.425287        1.6
#
#           var_nz
# Season
# Spring  0.853333
# Summer       NaN
# Fall         NaN
# Winter  6.384469
#
#
# Day Type Stats (적설량):
#            Total_Count  Zero_Count  cnt_nz   max  min_nz   mean_nz  median_nz  \
# Day_type
# Weekday           910         851      59  13.8     0.2  2.355932        1.7
# Weekend           419         388      31  12.2     0.1  2.493548        1.6
#
#             var_nz
# Day_type
# Weekday   5.618025
# Weekend   7.526624

# %%
# 눈 온 날과 안 온날의 개수 세기

# Set up a 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(10, 7))
axes = axes.flatten()  # Flatten for easy indexing

# Define the keys and titles for each plot
keys = list(combined_stats_s1.keys())
titles = ["Year", "Precipitation Grade", "Season", "Day_Type"]

# Plot each dataset in a subplot
for i, key in enumerate(keys):
    value = combined_stats_s1[key]
    labels = value.index  # x-axis labels

    # Bar positions
    x = np.arange(len(labels))
    width = 0.35  # Width of the bars for 2 bars

    # Plot side-by-side bars for Zero_Count and Non-Zero Count (cnt_nz)
    axes[i].bar(x - width/2, value["Zero_Count"], width, label='Zero Count', color='orange')
    axes[i].bar(x + width/2, value["cnt_nz"], width, label='Non-Zero Count', color='lightgreen')

    # Labeling
    axes[i].set_title(f"{titles[i]} - Zero and Non-Zero Counts")
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(labels, rotation=45)
    axes[i].set_ylabel("Counts")
    axes[i].legend()

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. 두 개 변수 조합 분석

# %%
# 2-1. 연도와 등급을 조합해서 분석
# 2-2. 연도와 계절을 조합해서 분석
# 2-3. 연도와 평일/주말을 조합해서 분석
# 2-4. 등급과 계절을 조합해서 분석
# 2-5. 등급과 평일/주말을 조합해서 분석
# 2-6. 계절과 평일/주말을 조합해서 분석

# %% [markdown]
# - 강수량, 적설량 (두개 변수 조합 분석)

# %%
def group_analysis_by_two_columns(df, group_col1, group_col2, target_col):
    # 기본 통계치 계산
    stats = df.groupby([group_col1, group_col2], observed=True)[target_col].agg([
        ("tot_cnt", "count"),               # 전체 카운트
        ("cnt_nz", lambda x: (x != 0).sum()), # 0 제외 카운트
        ("zero_cnt", lambda x: (x == 0).sum()), # 0인 값의 카운트
        ("min", lambda x: x[x != 0].min()), # 0 제외 최소값
        ("max", "max"),
        ("mean", "mean"),
        ("med", "median"),
        ("var", "var"),
        ("q1", lambda x: x.quantile(0.25)),
        ("q3", lambda x: x.quantile(0.75)),
        ("iqr", lambda x: x.quantile(0.75) - x.quantile(0.25)),
        ("skew", lambda x: skew(x)),
        ("kurt", lambda x: kurtosis(x)),
        ("range", lambda x: x.max() - x.min())
    ])
    
    # 컬럼 순서 재정렬
    stats = stats[[
        # 카운트 관련 (0 포함/제외 구분)
        "tot_cnt", "cnt_nz", "zero_cnt",
        # 기본 통계치 (min은 0 제외)
        "min", "max", "mean", "med", "var",
        "q1", "q3", "iqr",
        "skew", "kurt", "range"]]
    
    return stats

# %% [markdown]
# - 강수량 (두 개 변수 조합 분석)

# %%
# 함수 실행 예시
df_Year_P_Grade_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Year", 
    group_col2 = "P_Grade", 
    target_col = "Precipitation(mm)")
df_Year_Season_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Year", 
    group_col2 = "Season", 
    target_col = "Precipitation(mm)")
df_Year_day_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Year", 
    group_col2 = "Day_type", 
    target_col = "Precipitation(mm)")
df_P_Grade_Season_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "P_Grade", 
    group_col2 = "Season", 
    target_col = "Precipitation(mm)")
df_P_Grade_day_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "P_Grade", 
    group_col2 = "Day_type", 
    target_col = "Precipitation(mm)")
df_Season_day_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Season", 
    group_col2 = "Day_type", 
    target_col = "Precipitation(mm)")

# 결과를 딕셔너리로 정리
double_group_stats_P2 = {
    "Year-P_Grade": df_Year_P_Grade_stats,
    "Year-Season": df_Year_Season_stats,
    "Year-Day": df_Year_day_stats,
    "P_Grade-Season": df_P_Grade_Season_stats,
    "P_Grade-Day": df_P_Grade_day_stats,
    "Season-Day": df_Season_day_stats
}

# 결과 출력
print("2. 이중 그룹 분석 - 강수량")
for key, value in double_group_stats_P2.items():
    print(f"\n{key} Stats (강수량):\n", value)
# Out:
# 2. 이중 그룹 분석 - 강수량
#
# Year-P_Grade Stats (강수량):
#                 tot_cnt  cnt_nz  zero_cnt   min    max        mean     med  \
# Year P_Grade
# 2021 Dry           248       0       248   NaN    0.0    0.000000    0.00
#      Light          88      88         0   0.1    9.3    2.860227    1.70
#      Moderate       21      21         0  10.5   38.2   19.452381   18.10
#      Heavy           8       8         0  56.2   77.4   65.787500   67.15
# 2022 Dry           261       0       261   NaN    0.0    0.000000    0.00
#      Light          68      68         0   0.1    9.9    2.107353    1.25
#      Moderate       26      26         0  10.4   47.2   23.634615   19.30
#      Heavy          10      10         0  51.1  176.2  101.750000  108.75
# 2023 Dry           256       0       256   NaN    0.0    0.000000    0.00
#      Light          70      70         0   0.1    9.7    2.467143    1.50
#      Moderate       31      31         0  10.4   47.5   28.603226   30.30
#      Heavy           8       8         0  50.3   91.6   67.425000   62.80
# 2024 Dry           155       0       155   NaN    0.0    0.000000    0.00
#      Light          53      53         0   0.1    9.7    2.881132    2.10
#      Moderate       22      22         0  10.9   48.3   22.709091   17.45
#      Heavy           4       4         0  65.1  128.8   93.150000   89.35
#
#                        var      q1       q3     iqr      skew      kurt  range
# Year P_Grade
# 2021 Dry          0.000000   0.000    0.000   0.000       NaN       NaN    0.0
#      Light        7.934147   0.475    4.600   4.125  0.899062 -0.449060    9.2
#      Moderate    52.848619  13.100   25.500  12.400  0.809835  0.070826   27.7
#      Heavy       40.186964  62.100   67.650   5.550  0.292006 -0.181415   21.2
# 2022 Dry          0.000000   0.000    0.000   0.000       NaN       NaN    0.0
#      Light        5.183079   0.500    2.700   2.200  1.722180  2.558065    9.8
#      Moderate   116.373554  15.575   33.725  18.150  0.654382 -0.884944   36.8
#      Heavy     1521.518333  68.575  122.325  53.750  0.346357 -0.653384  125.1
# 2023 Dry          0.000000   0.000    0.000   0.000       NaN       NaN    0.0
#      Light        5.671803   0.625    3.775   3.150  1.190610  0.675275    9.6
#      Moderate   158.250323  15.600   39.450  23.850 -0.058465 -1.321291   37.1
#      Heavy      220.245000  57.425   76.050  18.625  0.596594 -1.036149   41.3
# 2024 Dry          0.000000   0.000    0.000   0.000       NaN       NaN    0.0
#      Light        7.715791   0.500    4.100   3.600  1.071183  0.103686    9.6
#      Moderate   116.307532  15.300   30.950  15.650  0.899142 -0.264704   37.4
#      Heavy      755.070000  76.200  106.300  30.100  0.391291 -1.233432   63.7
#
# Year-Season Stats (강수량):
#               tot_cnt  cnt_nz  zero_cnt  min    max       mean  med  \
# Year Season
# 2021 Spring       92      35        57  0.1   67.5   4.544565  0.0
#      Summer       92      34        58  0.1   77.4   5.261957  0.0
#      Fall         91      25        66  0.3   68.1   2.751648  0.0
#      Winter       90      23        67  0.1    9.2   0.376667  0.0
# 2022 Spring       92      20        72  0.3   42.1   1.418478  0.0
#      Summer       92      45        47  0.1  176.2  13.161957  0.0
#      Fall         91      18        73  0.1  120.0   4.506593  0.0
#      Winter       90      21        69  0.1    5.4   0.264444  0.0
# 2023 Spring       92      22        70  0.1   50.3   2.858696  0.0
#      Summer       92      43        49  0.1   91.6  10.365217  0.0
#      Fall         91      23        68  0.1   45.8   2.718681  0.0
#      Winter       90      21        69  0.1   37.3   1.497778  0.0
# 2024 Spring       92      22        70  0.1   48.3   2.045652  0.0
#      Summer       82      37        45  0.1  128.8   9.062195  0.0
#      Winter       60      20        40  0.2   17.8   1.560000  0.0
#
#                     var   q1     q3    iqr      skew       kurt  range
# Year Season
# 2021 Spring  151.551948  0.0  1.700  1.700  3.887522  15.664179   67.5
#      Summer  210.248757  0.0  2.925  2.925  3.651175  12.913089   77.4
#      Fall     79.152747  0.0  0.350  0.350  5.209765  31.865247   68.1
#      Winter    1.370124  0.0  0.075  0.075  5.340598  34.770365    9.2
# 2022 Spring   29.281523  0.0  0.000  0.000  5.554989  35.015209   42.1
#      Summer  985.687658  0.0  7.950  7.950  3.277627  10.968398  176.2
#      Fall    276.783734  0.0  0.000  0.000  5.084473  28.275988  120.0
#      Winter    0.631980  0.0  0.000  0.000  4.323567  21.329170    5.4
# 2023 Spring   93.181792  0.0  0.000  0.000  3.793709  13.437662   50.3
#      Summer  441.021854  0.0  5.800  5.800  2.212030   4.065888   91.6
#      Fall     65.514647  0.0  0.050  0.050  3.837917  14.734814   45.8
#      Winter   31.671006  0.0  0.000  0.000  4.939129  25.284128   37.3
# 2024 Spring   46.313278  0.0  0.000  0.000  4.797498  25.722799   48.3
#      Summer  484.444109  0.0  5.400  5.400  3.535121  13.435950  128.8
#      Winter   14.955661  0.0  0.425  0.425  2.961102   8.236696   17.8
#
# Year-Day Stats (강수량):
#                 tot_cnt  cnt_nz  zero_cnt  min    max      mean  med  \
# Year Day_type
# 2021 Weekday       251      80       171  0.1   77.4  2.331474  0.0
#      Weekend       114      37        77  0.1   68.1  5.274561  0.0
# 2022 Weekday       249      69       180  0.1  176.2  5.380723  0.0
#      Weekend       116      35        81  0.1   76.0  3.754310  0.0
# 2023 Weekday       249      73       176  0.1   91.6  4.595582  0.0
#      Weekend       116      36        80  0.1   47.5  3.918103  0.0
# 2024 Weekday       161      51       110  0.1  128.8  4.110559  0.0
#      Weekend        73      28        45  0.1   48.3  4.973973  0.0
#
#                       var   q1     q3    iqr      skew       kurt  range
# Year Day_type
# 2021 Weekday    61.492485  0.0  0.700  0.700  6.513885  51.833170   77.4
#      Weekend   224.864037  0.0  0.475  0.475  3.302126   9.928865   68.1
# 2022 Weekday   446.442127  0.0  0.200  0.200  5.445854  31.722342  176.2
#      Weekend   136.909633  0.0  0.350  0.350  4.033432  17.335708   76.0
# 2023 Weekday   198.695101  0.0  0.500  0.500  3.845751  15.365480   91.6
#      Weekend   108.889496  0.0  0.875  0.875  2.979701   7.820026   47.5
# 2024 Weekday   244.807075  0.0  0.800  0.800  5.763026  35.983288  128.8
#      Weekend   109.811674  0.0  3.100  3.100  2.408313   5.123750   48.3
#
# P_Grade-Season Stats (강수량):
#                   tot_cnt  cnt_nz  zero_cnt   min    max       mean    med  \
# P_Grade  Season
# Dry      Spring      269       0       269   NaN    0.0   0.000000   0.00
#          Summer      199       0       199   NaN    0.0   0.000000   0.00
#          Fall        207       0       207   NaN    0.0   0.000000   0.00
#          Winter      245       0       245   NaN    0.0   0.000000   0.00
# Light    Spring       72      72         0   0.1    9.2   2.768056   1.70
#          Summer       89      89         0   0.1    9.9   3.035955   2.20
#          Fall         41      41         0   0.1    8.5   2.939024   2.10
#          Winter       77      77         0   0.1    9.7   1.693506   0.90
# Moderate Spring       23      23         0  10.9   48.3  24.330435  20.60
#          Summer       48      48         0  10.4   47.5  25.595833  23.15
#          Fall         21      21         0  10.4   45.8  22.161905  19.50
#          Winter        8       8         0  10.9   37.3  19.462500  17.05
# Heavy    Spring        4       4         0  50.3   67.5  60.225000  61.55
#          Summer       22      22         0  51.1  176.2  86.040909  75.05
#          Fall          4       4         0  57.9  120.0  80.500000  72.05
#
#                          var      q1       q3     iqr      skew      kurt  \
# P_Grade  Season
# Dry      Spring     0.000000   0.000    0.000   0.000       NaN       NaN
#          Summer     0.000000   0.000    0.000   0.000       NaN       NaN
#          Fall       0.000000   0.000    0.000   0.000       NaN       NaN
#          Winter     0.000000   0.000    0.000   0.000       NaN       NaN
# Light    Spring     7.807275   0.500    4.150   3.650  1.094478 -0.053962
#          Summer     7.121874   0.900    5.100   4.200  0.876010 -0.271099
#          Fall       6.042939   0.800    4.500   3.700  0.657913 -0.467949
#          Winter     4.582984   0.300    2.300   2.000  2.295116  5.280575
# Moderate Spring   133.192213  15.250   30.950  15.700  0.812066 -0.460781
#          Summer   133.740408  15.900   34.450  18.550  0.348737 -1.196331
#          Fall     103.216476  14.200   27.800  13.600  0.758724 -0.473005
#          Winter    92.402679  12.675   21.125   8.450  0.998857 -0.497113
# Heavy    Spring    70.729167  54.725   67.050  12.325 -0.233225 -1.689384
#          Summer  1012.379675  63.050  101.950  38.900  1.207415  0.921039
#          Fall     748.340000  65.550   87.000  21.450  0.904159 -0.841868
#
#                  range
# P_Grade  Season
# Dry      Spring    0.0
#          Summer    0.0
#          Fall      0.0
#          Winter    0.0
# Light    Spring    9.1
#          Summer    9.8
#          Fall      8.4
#          Winter    9.6
# Moderate Spring   37.4
#          Summer   37.1
#          Fall     35.4
#          Winter   26.4
# Heavy    Spring   17.2
#          Summer  125.1
#          Fall     62.1
#
# P_Grade-Day Stats (강수량):
#                     tot_cnt  cnt_nz  zero_cnt   min    max       mean    med  \
# P_Grade  Day_type
# Dry      Weekday       637       0       637   NaN    0.0   0.000000   0.00
#          Weekend       283       0       283   NaN    0.0   0.000000   0.00
# Light    Weekday       194     194         0   0.1    9.7   2.638660   1.70
#          Weekend        85      85         0   0.1    9.9   2.452941   1.50
# Moderate Weekday        57      57         0  10.4   46.7  22.435088  18.50
#          Weekend        43      43         0  10.4   48.3  26.290698  25.00
# Heavy    Weekday        22      22         0  50.3  176.2  88.200000  78.65
#          Weekend         8       8         0  56.2   76.0  64.425000  64.85
#
#                            var      q1       q3     iqr      skew      kurt  \
# P_Grade  Day_type
# Dry      Weekday      0.000000   0.000    0.000   0.000       NaN       NaN
#          Weekend      0.000000   0.000    0.000   0.000       NaN       NaN
# Light    Weekday      6.757617   0.700    3.800   3.100  1.161621  0.291629
#          Weekend      6.567283   0.400    4.300   3.900  1.238499  0.776901
# Moderate Weekday    111.265175  13.300   30.000  16.700  0.735072 -0.630449
#          Weekend    135.512292  16.150   33.900  17.750  0.417909 -1.090099
# Heavy    Weekday   1065.227619  64.125  111.625  47.500  0.948497  0.354376
#          Weekend     42.216429  59.475   67.650   8.175  0.400612 -0.706166
#
#                    range
# P_Grade  Day_type
# Dry      Weekday     0.0
#          Weekend     0.0
# Light    Weekday     9.6
#          Weekend     9.8
# Moderate Weekday    36.3
#          Weekend    37.9
# Heavy    Weekday   125.9
#          Weekend    19.8
#
# Season-Day Stats (강수량):
#                   tot_cnt  cnt_nz  zero_cnt  min    max       mean  med  \
# Season Day_type
# Spring Weekday       253      59       194  0.1   50.3   1.340711  0.0
#        Weekend       115      40        75  0.1   67.5   5.744348  0.0
# Summer Weekday       253     112       141  0.1  176.2  10.402372  0.0
#        Weekend       105      47        58  0.1   62.8   7.237143  0.0
# Fall   Weekday       182      43       139  0.1  120.0   2.951099  0.0
#        Weekend        91      23        68  0.1   76.0   4.074725  0.0
# Winter Weekday       222      59       163  0.1   37.3   1.004505  0.0
#        Weekend       108      26        82  0.1   17.1   0.584259  0.0
#
#                         var   q1    q3   iqr      skew       kurt  range
# Season Day_type
# Spring Weekday    21.751471  0.0  0.00  0.00  6.331604  52.551980   50.3
#        Weekend   198.605823  0.0  0.55  0.55  2.818457   7.443661   67.5
# Summer Weekday   676.452137  0.0  5.20  5.20  3.374680  12.389605  176.2
#        Weekend   191.964280  0.0  6.40  6.40  2.219627   4.338672   62.8
# Fall   Weekday   121.661739  0.0  0.00  0.00  7.429333  69.878666  120.0
#        Weekend   178.040576  0.0  0.05  0.05  4.047462  16.244952   76.0
# Winter Weekday    15.746586  0.0  0.10  0.10  6.401246  47.242132   37.3
#        Weekend     4.723395  0.0  0.00  0.00  6.018276  39.016390   17.1

# %%
m_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1329 entries, 0 to 1328
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1329 non-null   datetime64[ns]
#  1   Fine_dust(㎍/㎥)     1329 non-null   float64
#  2   Precipitation(mm)  1329 non-null   float64
#  3   Snow_depth(cm)     1329 non-null   float64
#  4   Day_type           1329 non-null   object
#  5   Season             1329 non-null   category
#  6   Year               1329 non-null   int32
#  7   FD_Grade           1329 non-null   category
#  8   P_Grade            1329 non-null   category
#  9   S_Grade            1329 non-null   category
# dtypes: category(4), datetime64[ns](1), float64(3), int32(1), object(1)
# memory usage: 63.2+ KB

# %% [markdown]
# - 적설량 (두 개 변수 조합 분석)

# %%
# 함수 실행 예시
df_Year_S_Grade_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Year", 
    group_col2 = "S_Grade", 
    target_col = "Snow_depth(cm)")
df_Year_Season_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Year", 
    group_col2 = "Season", 
    target_col = "Snow_depth(cm)")
df_Year_day_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Year", 
    group_col2 = "Day_type", 
    target_col = "Snow_depth(cm)")
df_S_Grade_Season_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "S_Grade", 
    group_col2 = "Season", 
    target_col = "Snow_depth(cm)")
df_S_Grade_day_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "S_Grade", 
    group_col2 = "Day_type", 
    target_col = "Snow_depth(cm)")
df_Season_day_stats = group_analysis_by_two_columns(
    df = m_df,
    group_col1 = "Season", 
    group_col2 = "Day_type", 
    target_col = "Snow_depth(cm)")

# 결과를 딕셔너리로 정리
double_group_stats_S2 = {
    "Year-S_Grade": df_Year_S_Grade_stats,
    "Year-Season": df_Year_Season_stats,
    "Year-Day": df_Year_day_stats,
    "S_Grade-Season": df_S_Grade_Season_stats,
    "S_Grade-Day": df_S_Grade_day_stats,
    "Season-Day": df_Season_day_stats
}

# 결과 출력
print("2. 이중 그룹 분석 - 적설량")
for key, value in double_group_stats_S2.items():
    print(f"\n{key} Stats (적설량):\n", value)
# Out:
# 2. 이중 그룹 분석 - 적설량
#
# Year-S_Grade Stats (적설량):
#                      tot_cnt  cnt_nz  zero_cnt   min   max       mean    med  \
# Year S_Grade
# 2021 No_Snow            340       0       340   NaN   0.0   0.000000   0.00
#      Light_Snow          14      14         0   0.1   1.8   0.821429   0.85
#      Moderate_Snow       11      11         0   2.3   5.1   3.900000   4.20
# 2022 No_Snow            334       0       334   NaN   0.0   0.000000   0.00
#      Light_Snow          25      25         0   0.1   1.9   0.976000   0.90
#      Moderate_Snow        6       6         0   2.4   5.0   3.833333   3.80
# 2023 No_Snow            349       0       349   NaN   0.0   0.000000   0.00
#      Light_Snow           9       9         0   0.2   1.7   0.788889   0.60
#      Moderate_Snow        6       6         0   2.1   8.8   4.266667   3.60
#      Heavy_Snow           1       1         0  12.2  12.2  12.200000  12.20
# 2024 No_Snow            216       0       216   NaN   0.0   0.000000   0.00
#      Light_Snow           6       6         0   0.2   2.0   1.383333   1.50
#      Moderate_Snow       10      10         0   2.3   6.0   3.730000   3.35
#      Heavy_Snow           2       2         0  10.2  13.8  12.000000  12.00
#
#                          var      q1      q3    iqr      skew      kurt  range
# Year S_Grade
# 2021 No_Snow        0.000000   0.000   0.000  0.000       NaN       NaN    0.0
#      Light_Snow     0.223352   0.475   1.075  0.600  0.264842 -0.394398    1.7
#      Moderate_Snow  0.922000   3.450   4.500  1.050 -0.570777 -0.784819    2.8
# 2022 No_Snow        0.000000   0.000   0.000  0.000       NaN       NaN    0.0
#      Light_Snow     0.340233   0.500   1.500  1.000  0.244340 -1.271880    1.8
#      Moderate_Snow  0.830667   3.500   4.400  0.900 -0.322828 -0.808494    2.6
# 2023 No_Snow        0.000000   0.000   0.000  0.000       NaN       NaN    0.0
#      Light_Snow     0.281111   0.400   1.000  0.600  0.636894 -0.943827    1.5
#      Moderate_Snow  5.558667   3.150   4.275  1.125  1.343758  0.474765    6.7
#      Heavy_Snow          NaN  12.200  12.200  0.000       NaN       NaN    0.0
# 2024 No_Snow        0.000000   0.000   0.000  0.000       NaN       NaN    0.0
#      Light_Snow     0.453667   1.200   1.875  0.675 -0.865810 -0.368317    1.8
#      Moderate_Snow  1.957889   2.550   4.850  2.300  0.537426 -1.216287    3.7
#      Heavy_Snow     6.480000  11.100  12.900  1.800  0.000000 -2.000000    3.6
#
# Year-Season Stats (적설량):
#               tot_cnt  cnt_nz  zero_cnt  min   max      mean  med       var  \
# Year Season
# 2021 Spring       92       2        90  2.3   2.3  0.050000  0.0  0.113736
#      Summer       92       0        92  NaN   0.0  0.000000  0.0  0.000000
#      Fall         91       0        91  NaN   0.0  0.000000  0.0  0.000000
#      Winter       90      23        67  0.1   5.1  0.553333  0.0  1.693753
# 2022 Spring       92       1        91  0.7   0.7  0.007609  0.0  0.005326
#      Summer       92       0        92  NaN   0.0  0.000000  0.0  0.000000
#      Fall         91       0        91  NaN   0.0  0.000000  0.0  0.000000
#      Winter       90      30        60  0.1   5.0  0.518889  0.0  1.118853
# 2023 Spring       92       0        92  NaN   0.0  0.000000  0.0  0.000000
#      Summer       92       0        92  NaN   0.0  0.000000  0.0  0.000000
#      Fall         91       0        91  NaN   0.0  0.000000  0.0  0.000000
#      Winter       90      16        74  0.2  12.2  0.498889  0.0  3.048426
# 2024 Spring       92       0        92  NaN   0.0  0.000000  0.0  0.000000
#      Summer       82       0        82  NaN   0.0  0.000000  0.0  0.000000
#      Winter       60      18        42  0.2  13.8  1.160000  0.0  6.512610
#
#               q1     q3    iqr      skew       kurt  range
# Year Season
# 2021 Spring  0.0  0.000  0.000  6.559133  41.022222    2.3
#      Summer  0.0  0.000  0.000       NaN        NaN    0.0
#      Fall    0.0  0.000  0.000       NaN        NaN    0.0
#      Winter  0.0  0.075  0.075  2.465575   4.695608    5.1
# 2022 Spring  0.0  0.000  0.000  9.434564  87.010989    0.7
#      Summer  0.0  0.000  0.000       NaN        NaN    0.0
#      Fall    0.0  0.000  0.000       NaN        NaN    0.0
#      Winter  0.0  0.500  0.500  2.529876   6.182972    5.0
# 2023 Spring  0.0  0.000  0.000       NaN        NaN    0.0
#      Summer  0.0  0.000  0.000       NaN        NaN    0.0
#      Fall    0.0  0.000  0.000       NaN        NaN    0.0
#      Winter  0.0  0.000  0.000  4.906454  26.330878   12.2
# 2024 Spring  0.0  0.000  0.000       NaN        NaN    0.0
#      Summer  0.0  0.000  0.000       NaN        NaN    0.0
#      Winter  0.0  1.500  1.500  3.096787  10.655262   13.8
#
# Year-Day Stats (적설량):
#                 tot_cnt  cnt_nz  zero_cnt  min   max      mean  med       var  \
# Year Day_type
# 2021 Weekday       251      18       233  0.2   5.1  0.161355  0.0  0.537581
#      Weekend       114       7       107  0.1   4.6  0.121930  0.0  0.409338
# 2022 Weekday       249      20       229  0.2   4.5  0.124900  0.0  0.318007
#      Weekend       116      11       105  0.1   5.0  0.140517  0.0  0.341388
# 2023 Weekday       249       8       241  0.3   4.5  0.056225  0.0  0.165455
#      Weekend       116       8       108  0.2  12.2  0.266379  0.0  2.118773
# 2024 Weekday       161      13       148  1.1  13.8  0.331677  0.0  2.313178
#      Weekend        73       5        68  0.2   6.0  0.221918  0.0  1.021735
#
#                 q1   q3  iqr      skew       kurt  range
# Year Day_type
# 2021 Weekday   0.0  0.0  0.0  5.167450  26.845166    5.1
#      Weekend   0.0  0.0  0.0  6.089404  37.523056    4.6
# 2022 Weekday   0.0  0.0  0.0  5.659783  34.093023    4.5
#      Weekend   0.0  0.0  0.0  5.901897  41.358630    5.0
# 2023 Weekday   0.0  0.0  0.0  8.761132  81.736746    4.5
#      Weekend   0.0  0.0  0.0  6.735797  47.344384   12.2
# 2024 Weekday   0.0  0.0  0.0  6.512456  47.965129   13.8
#      Weekend   0.0  0.0  0.0  4.924561  23.760799    6.0
#
# S_Grade-Season Stats (적설량):
#                        tot_cnt  cnt_nz  zero_cnt   min   max       mean   med  \
# S_Grade       Season
# No_Snow       Spring      365       0       365   NaN   0.0   0.000000   0.0
#               Summer      358       0       358   NaN   0.0   0.000000   0.0
#               Fall        273       0       273   NaN   0.0   0.000000   0.0
#               Winter      243       0       243   NaN   0.0   0.000000   0.0
# Light_Snow    Spring        1       1         0   0.7   0.7   0.700000   0.7
#               Winter       53      53         0   0.1   2.0   0.954717   0.9
# Moderate_Snow Spring        2       2         0   2.3   2.3   2.300000   2.3
#               Winter       31      31         0   2.1   8.8   4.006452   3.8
# Heavy_Snow    Winter        3       3         0  10.2  13.8  12.066667  12.2
#
#                            var    q1     q3   iqr      skew      kurt  range
# S_Grade       Season
# No_Snow       Spring  0.000000   0.0   0.00  0.00       NaN       NaN    0.0
#               Summer  0.000000   0.0   0.00  0.00       NaN       NaN    0.0
#               Fall    0.000000   0.0   0.00  0.00       NaN       NaN    0.0
#               Winter  0.000000   0.0   0.00  0.00       NaN       NaN    0.0
# Light_Snow    Spring       NaN   0.7   0.70  0.00       NaN       NaN    0.0
#               Winter  0.329448   0.5   1.50  1.00  0.264092 -1.127621    1.9
# Moderate_Snow Spring  0.000000   2.3   2.30  0.00       NaN       NaN    0.0
#               Winter  1.814624   3.2   4.55  1.35  1.369383  3.303721    6.7
# Heavy_Snow    Winter  3.253333  11.2  13.00  1.80 -0.135062 -1.500000    3.6
#
# S_Grade-Day Stats (적설량):
#                          tot_cnt  cnt_nz  zero_cnt   min   max       mean  \
# S_Grade       Day_type
# No_Snow       Weekday       851       0       851   NaN   0.0   0.000000
#               Weekend       388       0       388   NaN   0.0   0.000000
# Light_Snow    Weekday        34      34         0   0.2   2.0   0.938235
#               Weekend        20      20         0   0.1   2.0   0.970000
# Moderate_Snow Weekday        23      23         0   2.1   5.2   3.613043
#               Weekend        10      10         0   2.3   8.8   4.570000
# Heavy_Snow    Weekday         2       2         0  10.2  13.8  12.000000
#               Weekend         1       1         0  12.2  12.2  12.200000
#
#                          med       var      q1      q3    iqr      skew  \
# S_Grade       Day_type
# No_Snow       Weekday    0.0  0.000000   0.000   0.000  0.000       NaN
#               Weekend    0.0  0.000000   0.000   0.000  0.000       NaN
# Light_Snow    Weekday    0.9  0.291524   0.425   1.350  0.925  0.354012
#               Weekend    0.9  0.398000   0.500   1.525  1.025  0.187773
# Moderate_Snow Weekday    3.6  0.865731   3.050   4.250  1.200 -0.025175
#               Weekend    4.5  3.831222   3.150   5.450  2.300  0.829021
# Heavy_Snow    Weekday   12.0  6.480000  11.100  12.900  1.800  0.000000
#               Weekend   12.2       NaN  12.200  12.200  0.000       NaN
#
#                             kurt  range
# S_Grade       Day_type
# No_Snow       Weekday        NaN    0.0
#               Weekend        NaN    0.0
# Light_Snow    Weekday  -0.983890    1.8
#               Weekend  -1.277792    1.9
# Moderate_Snow Weekday  -0.900478    3.1
#               Weekend   0.206094    6.5
# Heavy_Snow    Weekday  -2.000000    3.6
#               Weekend        NaN    0.0
#
# Season-Day Stats (적설량):
#                   tot_cnt  cnt_nz  zero_cnt  min   max      mean  med  \
# Season Day_type
# Spring Weekday       253       1       252  2.3   2.3  0.009091  0.0
#        Weekend       115       2       113  0.7   2.3  0.026087  0.0
# Summer Weekday       253       0       253  NaN   0.0  0.000000  0.0
#        Weekend       105       0       105  NaN   0.0  0.000000  0.0
# Fall   Weekday       182       0       182  NaN   0.0  0.000000  0.0
#        Weekend        91       0        91  NaN   0.0  0.000000  0.0
# Winter Weekday       222      58       164  0.2  13.8  0.615766  0.0
#        Weekend       108      29        79  0.1  12.2  0.687963  0.0
#
#                       var   q1     q3    iqr       skew        kurt  range
# Season Day_type
# Spring Weekday   0.020909  0.0  0.000  0.000  15.811514  248.003968    2.3
#        Weekend   0.050015  0.0  0.000  0.000   9.500527   92.305291    2.3
# Summer Weekday   0.000000  0.0  0.000  0.000        NaN         NaN    0.0
#        Weekend   0.000000  0.0  0.000  0.000        NaN         NaN    0.0
# Fall   Weekday   0.000000  0.0  0.000  0.000        NaN         NaN    0.0
#        Weekend   0.000000  0.0  0.000  0.000        NaN         NaN    0.0
# Winter Weekday   2.551379  0.0  0.275  0.275   4.374997   26.042866   13.8
#        Weekend   3.379947  0.0  0.125  0.125   3.842753   16.964711   12.2
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\3779905641.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   ("skew", lambda x: skew(x)),
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\3779905641.py:16: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   ("kurt", lambda x: kurtosis(x)),

# %% [markdown]
# 3. 세 개 변수 조합 분석

# %%
# 3-1. 연도와 등급과 계절을 조합해서 분석
# 3-2. 연도와 등급과 평일/주말을 조합해서 분석
# 3-3. 등급과 계절과 평일/주말을 주합해서 분석

# %% [markdown]
# - 강수량, 적설량 (세개 변수 조합 분석)

# %%
def group_analysis_by_three_columns(df, group_col1, group_col2, group_col3, target_col):
    # 기본 통계치 계산
    stats = df.groupby([group_col1, group_col2, group_col3], observed=True)[target_col].agg([
        ("tot_cnt", "count"),               # 전체 카운트
        ("cnt_nz", lambda x: (x != 0).sum()), # 0 제외 카운트
        ("zero_cnt", lambda x: (x == 0).sum()), # 0인 값의 카운트
        ("min", lambda x: x[x != 0].min()), # 0 제외 최소값
        ("max", "max"),
        ("mean", "mean"),
        ("med", "median"),
        ("var", "var"),
        ("q1", lambda x: x.quantile(0.25)),
        ("q3", lambda x: x.quantile(0.75)),
        ("iqr", lambda x: x.quantile(0.75) - x.quantile(0.25)),
        ("skew", lambda x: skew(x)),
        ("kurt", lambda x: kurtosis(x)),
        ("range", lambda x: x.max() - x.min())
    ])
    
    # 컬럼 순서 재정렬
    stats = stats[[
        # 카운트 관련 (0 포함/제외 구분)
        "tot_cnt", "cnt_nz", "zero_cnt",
        # 기본 통계치 (min은 0 제외)
        "min", "max", "mean", "med", "var",
        "q1", "q3", "iqr",
        "skew", "kurt", "range"]]
    
    return stats

# %% [markdown]
# - 강수량 (세개 변수 조합 분석)

# %%
# 함수 실행 예시
df_Year_P_Grade_Season_stats = group_analysis_by_three_columns(
                                df = m_df,
                                group_col1 = "Year", 
                                group_col2 = "P_Grade", 
                                group_col3 = "Season", 
                                target_col = "Precipitation(mm)")
df_Year_P_Grade_day_stats = group_analysis_by_three_columns(
                                df = m_df,
                                group_col1 = "Year", 
                                group_col2 = "P_Grade", 
                                group_col3 = "Day_type", 
                                target_col = "Precipitation(mm)")
df_P_Grade_Season_day_stats = group_analysis_by_three_columns(
                                df = m_df,
                                group_col1 = "P_Grade", 
                                group_col2 = "Season", 
                                group_col3 = "Day_type", 
                                target_col = "Precipitation(mm)")

# 결과를 딕셔너리로 정리
triple_group_stats_P3 = {
    "Year-P_Grade-Season": df_Year_P_Grade_Season_stats,
    "Year-P_Grade-Day": df_Year_P_Grade_day_stats,
    "P_Grade-Season-Day": df_P_Grade_Season_day_stats,
}

# 결과 출력
print("2. 삼중 그룹 분석 - 강수량")
for key, value in triple_group_stats_P3.items():
    print(f"\n{key} Stats: (강수량)\n", value)
# Out:
# 2. 삼중 그룹 분석 - 강수량
#
# Year-P_Grade-Season Stats: (강수량)
#                        tot_cnt  cnt_nz  zero_cnt   min    max        mean  \
# Year P_Grade  Season
# 2021 Dry      Spring       57       0        57   NaN    0.0    0.000000
#               Summer       58       0        58   NaN    0.0    0.000000
#               Fall         66       0        66   NaN    0.0    0.000000
#               Winter       67       0        67   NaN    0.0    0.000000
#      Light    Spring       25      25         0   0.1    9.2    3.548000
#               Summer       23      23         0   0.1    9.3    3.560870
#               Fall         17      17         0   0.3    6.4    2.776471
#               Winter       23      23         0   0.1    9.2    1.473913
#      Moderate Spring        7       7         0  12.3   26.3   19.828571
#               Summer        7       7         0  10.5   38.2   19.228571
#               Fall          7       7         0  12.0   29.6   19.300000
#      Heavy    Spring        3       3         0  56.2   67.5   63.533333
#               Summer        4       4         0  60.0   77.4   66.900000
#               Fall          1       1         0  68.1   68.1   68.100000
# 2022 Dry      Spring       72       0        72   NaN    0.0    0.000000
#               Summer       47       0        47   NaN    0.0    0.000000
#               Fall         73       0        73   NaN    0.0    0.000000
#               Winter       69       0        69   NaN    0.0    0.000000
#      Light    Spring       15      15         0   0.3    8.7    1.840000
#               Summer       24      24         0   0.1    9.9    3.204167
#               Fall          8       8         0   0.1    4.3    1.875000
#               Winter       21      21         0   0.1    5.4    1.133333
#      Moderate Spring        5       5         0  10.9   42.1   20.580000
#               Summer       14      14         0  10.4   47.2   26.457143
#               Fall          7       7         0  11.8   33.8   20.171429
#      Heavy    Summer        7       7         0  51.1  176.2  109.085714
#               Fall          3       3         0  57.9  120.0   84.633333
# 2023 Dry      Spring       70       0        70   NaN    0.0    0.000000
#               Summer       49       0        49   NaN    0.0    0.000000
#               Fall         68       0        68   NaN    0.0    0.000000
#               Winter       69       0        69   NaN    0.0    0.000000
#      Light    Spring       16      16         0   0.1    6.9    2.268750
#               Summer       22      22         0   0.1    9.7    2.418182
#               Fall         16      16         0   0.1    8.5    3.643750
#               Winter       16      16         0   0.1    4.7    1.556250
#      Moderate Spring        5       5         0  25.1   47.5   35.280000
#               Summer       14      14         0  10.4   47.5   29.378571
#               Fall          7       7         0  10.4   45.8   27.014286
#               Winter        5       5         0  11.4   37.3   21.980000
#      Heavy    Spring        1       1         0  50.3   50.3   50.300000
#               Summer        7       7         0  54.8   91.6   69.871429
# 2024 Dry      Spring       70       0        70   NaN    0.0    0.000000
#               Summer       45       0        45   NaN    0.0    0.000000
#               Winter       40       0        40   NaN    0.0    0.000000
#      Light    Spring       16      16         0   0.1    9.0    2.918750
#               Summer       20      20         0   0.1    8.5    2.910000
#               Winter       17      17         0   0.2    9.7    2.811765
#      Moderate Spring        6       6         0  11.5   48.3   23.583333
#               Summer       13      13         0  11.0   42.2   24.023077
#               Winter        3       3         0  10.9   17.8   15.266667
#      Heavy    Summer        4       4         0  65.1  128.8   93.150000
#
#                          med          var      q1       q3     iqr      skew  \
# Year P_Grade  Season
# 2021 Dry      Spring    0.00     0.000000   0.000    0.000   0.000       NaN
#               Summer    0.00     0.000000   0.000    0.000   0.000       NaN
#               Fall      0.00     0.000000   0.000    0.000   0.000       NaN
#               Winter    0.00     0.000000   0.000    0.000   0.000       NaN
#      Light    Spring    1.70    11.345933   0.600    6.900   6.300  0.536713
#               Summer    3.00     8.741581   0.800    6.050   5.250  0.369735
#               Fall      2.00     4.591912   0.800    4.500   3.700  0.313979
#               Winter    0.70     3.852016   0.200    2.050   1.850  2.780402
#      Moderate Spring   19.60    26.965714  16.550   23.750   7.200 -0.103864
#               Summer   18.10    88.412381  12.700   21.200   8.500  1.217196
#               Fall     14.20    60.533333  13.200   26.450  13.250  0.333276
#      Heavy    Spring   66.90    40.423333  61.550   67.200   5.650 -0.700029
#               Summer   65.10    58.306667  62.100   69.900   7.800  0.657305
#               Fall     68.10          NaN  68.100   68.100   0.000       NaN
# 2022 Dry      Spring    0.00     0.000000   0.000    0.000   0.000       NaN
#               Summer    0.00     0.000000   0.000    0.000   0.000       NaN
#               Fall      0.00     0.000000   0.000    0.000   0.000       NaN
#               Winter    0.00     0.000000   0.000    0.000   0.000       NaN
#      Light    Spring    1.30     4.448286   0.500    2.150   1.650  2.465696
#               Summer    2.20     7.736938   1.075    4.525   3.450  1.063533
#               Fall      1.65     3.025000   0.100    3.425   3.325  0.217249
#               Winter    0.70     1.778333   0.200    1.700   1.500  1.880406
#      Moderate Spring   15.50   154.747000  14.600   19.800   5.200  1.265212
#               Summer   24.55   131.956484  17.700   35.350  17.650  0.227767
#               Fall     19.50    55.462381  15.200   22.850   7.650  0.794441
#      Heavy    Summer  114.50  1733.004762  84.550  126.350  41.800  0.097885
#               Fall     76.00  1020.003333  66.950   98.000  31.050  0.460320
# 2023 Dry      Spring    0.00     0.000000   0.000    0.000   0.000       NaN
#               Summer    0.00     0.000000   0.000    0.000   0.000       NaN
#               Fall      0.00     0.000000   0.000    0.000   0.000       NaN
#               Winter    0.00     0.000000   0.000    0.000   0.000       NaN
#      Light    Spring    1.70     4.143625   0.500    3.100   2.600  0.922037
#               Summer    1.45     6.222511   0.725    3.250   2.525  1.413479
#               Fall      3.30     8.641292   1.175    5.275   4.100  0.445035
#               Winter    0.90     2.186625   0.550    2.000   1.450  1.040973
#      Moderate Spring   31.80    83.347000  30.200   41.800  11.600  0.320954
#               Summer   30.45   176.451044  17.700   41.400  23.700 -0.130387
#               Fall     27.80   186.411429  15.300   37.250  21.950  0.076216
#               Winter   17.00   133.367000  13.100   31.100  18.000  0.425777
#      Heavy    Spring   50.30          NaN  50.300   50.300   0.000       NaN
#               Summer   63.80   201.092381  60.050   79.400  19.350  0.557615
# 2024 Dry      Spring    0.00     0.000000   0.000    0.000   0.000       NaN
#               Summer    0.00     0.000000   0.000    0.000   0.000       NaN
#               Winter    0.00     0.000000   0.000    0.000   0.000       NaN
#      Light    Spring    2.10     8.340292   0.800    4.875   4.075  1.000647
#               Summer    2.55     5.792526   0.800    4.350   3.550  0.692201
#               Winter    1.80    10.371103   0.400    3.100   2.700  1.281992
#      Moderate Spring   18.85   200.209667  13.500   28.925  15.425  0.938469
#               Summer   21.10   101.613590  16.500   32.200  15.700  0.464123
#               Winter   17.10    14.423333  14.000   17.450   3.450 -0.680177
#      Heavy    Summer   89.35   755.070000  76.200  106.300  30.100  0.391291
#
#                           kurt  range
# Year P_Grade  Season
# 2021 Dry      Spring       NaN    0.0
#               Summer       NaN    0.0
#               Fall         NaN    0.0
#               Winter       NaN    0.0
#      Light    Spring -1.301081    9.1
#               Summer -1.222406    9.2
#               Fall   -1.389228    6.1
#               Winter  8.556432    9.1
#      Moderate Spring -1.241593   14.0
#               Summer  0.457936   27.7
#               Fall   -1.773259   17.6
#      Heavy    Spring -1.500000   11.3
#               Summer -1.077666   17.4
#               Fall         NaN    0.0
# 2022 Dry      Spring       NaN    0.0
#               Summer       NaN    0.0
#               Fall         NaN    0.0
#               Winter       NaN    0.0
#      Light    Spring  5.675286    8.4
#               Summer  0.030050    9.8
#               Fall   -1.532982    4.2
#               Winter  3.296517    5.3
#      Moderate Spring -0.061219   31.2
#               Summer -1.278328   36.8
#               Fall   -0.381093   22.0
#      Heavy    Summer -0.719315  125.1
#               Fall   -1.500000   62.1
# 2023 Dry      Spring       NaN    0.0
#               Summer       NaN    0.0
#               Fall         NaN    0.0
#               Winter       NaN    0.0
#      Light    Spring -0.134480    6.8
#               Summer  1.383626    9.6
#               Fall   -1.039280    8.4
#               Winter -0.423654    4.6
#      Moderate Spring -1.395898   22.4
#               Summer -1.342298   37.1
#               Fall   -1.525010   35.4
#               Winter -1.570460   25.9
#      Heavy    Spring       NaN    0.0
#               Summer -1.233084   36.8
# 2024 Dry      Spring       NaN    0.0
#               Summer       NaN    0.0
#               Winter       NaN    0.0
#      Light    Spring -0.114189    8.9
#               Summer -0.447525    8.4
#               Winter  0.187491    9.5
#      Moderate Spring -0.503666   36.8
#               Summer -1.117915   31.2
#               Winter -1.500000    6.9
#      Heavy    Summer -1.233432   63.7
#
# Year-P_Grade-Day Stats: (강수량)
#                          tot_cnt  cnt_nz  zero_cnt   min    max        mean  \
# Year P_Grade  Day_type
# 2021 Dry      Weekday       171       0       171   NaN    0.0    0.000000
#               Weekend        77       0        77   NaN    0.0    0.000000
#      Light    Weekday        65      65         0   0.1    9.3    3.046154
#               Weekend        23      23         0   0.1    9.2    2.334783
#      Moderate Weekday        13      13         0  10.5   29.6   18.646154
#               Weekend         8       8         0  12.7   38.2   20.762500
#      Heavy    Weekday         2       2         0  67.4   77.4   72.400000
#               Weekend         6       6         0  56.2   68.1   63.583333
# 2022 Dry      Weekday       180       0       180   NaN    0.0    0.000000
#               Weekend        81       0        81   NaN    0.0    0.000000
#      Light    Weekday        45      45         0   0.1    9.0    2.235556
#               Weekend        23      23         0   0.1    9.9    1.856522
#      Moderate Weekday        16      16         0  10.4   38.8   22.225000
#               Weekend        10      10         0  13.6   47.2   25.890000
#      Heavy    Weekday         8       8         0  51.1  176.2  110.450000
#               Weekend         2       2         0  57.9   76.0   66.950000
# 2023 Dry      Weekday       176       0       176   NaN    0.0    0.000000
#               Weekend        80       0        80   NaN    0.0    0.000000
#      Light    Weekday        47      47         0   0.1    8.5    2.425532
#               Weekend        23      23         0   0.1    9.7    2.552174
#      Moderate Weekday        18      18         0  10.4   46.7   27.272222
#               Weekend        13      13         0  10.4   47.5   30.446154
#      Heavy    Weekday         8       8         0  50.3   91.6   67.425000
# 2024 Dry      Weekday       110       0       110   NaN    0.0    0.000000
#               Weekend        45       0        45   NaN    0.0    0.000000
#      Light    Weekday        37      37         0   0.1    9.7    2.683784
#               Weekend        16      16         0   0.1    8.7    3.337500
#      Moderate Weekday        10      10         0  10.9   42.2   18.990000
#               Weekend        12      12         0  11.0   48.3   25.808333
#      Heavy    Weekday         4       4         0  65.1  128.8   93.150000
#
#                            med          var      q1       q3     iqr  \
# Year P_Grade  Day_type
# 2021 Dry      Weekday     0.00     0.000000   0.000    0.000   0.000
#               Weekend     0.00     0.000000   0.000    0.000   0.000
#      Light    Weekday     1.90     8.149399   0.700    4.700   4.000
#               Weekend     0.70     7.277826   0.350    4.050   3.700
#      Moderate Weekday    18.10    46.621026  12.700   25.700  13.000
#               Weekend    19.55    67.905536  14.800   22.425   7.625
#      Heavy    Weekday    72.40    50.000000  69.900   74.900   5.000
#               Weekend    64.85    22.941667  60.700   67.350   6.650
# 2022 Dry      Weekday     0.00     0.000000   0.000    0.000   0.000
#               Weekend     0.00     0.000000   0.000    0.000   0.000
#      Light    Weekday     1.50     5.399162   0.700    3.200   2.500
#               Weekend     1.10     4.887115   0.400    2.450   2.050
#      Moderate Weekday    18.80    97.679333  15.275   30.875  15.600
#               Weekend    20.10   151.276556  16.250   33.950  17.700
#      Heavy    Weekday   117.25  1500.322857  93.775  124.725  30.950
#               Weekend    66.95   163.805000  62.425   71.475   9.050
# 2023 Dry      Weekday     0.00     0.000000   0.000    0.000   0.000
#               Weekend     0.00     0.000000   0.000    0.000   0.000
#      Light    Weekday     1.50     5.598030   0.550    3.650   3.100
#               Weekend     1.50     6.072609   0.750    4.550   3.800
#      Moderate Weekday    29.05   158.964477  15.450   36.925  21.475
#               Weekend    31.80   164.089359  25.000   40.200  15.200
#      Heavy    Weekday    62.80   220.245000  57.425   76.050  18.625
# 2024 Dry      Weekday     0.00     0.000000   0.000    0.000   0.000
#               Weekend     0.00     0.000000   0.000    0.000   0.000
#      Light    Weekday     2.00     7.424174   0.600    3.600   3.000
#               Weekend     2.60     8.611833   0.400    5.350   4.950
#      Moderate Weekday    17.05    86.292111  12.900   20.275   7.375
#               Weekend    24.65   128.386288  16.800   32.525  15.725
#      Heavy    Weekday    89.35   755.070000  76.200  106.300  30.100
#
#                                 skew      kurt  range
# Year P_Grade  Day_type
# 2021 Dry      Weekday            NaN       NaN    0.0
#               Weekend            NaN       NaN    0.0
#      Light    Weekday   8.145739e-01 -0.638436    9.2
#               Weekend   1.181311e+00  0.326214    9.1
#      Moderate Weekday   3.146000e-01 -1.472530   19.1
#               Weekend   1.198627e+00  0.547503   25.5
#      Heavy    Weekday   0.000000e+00 -2.000000   10.0
#               Weekend  -5.189393e-01 -1.217290   11.9
# 2022 Dry      Weekday            NaN       NaN    0.0
#               Weekend            NaN       NaN    0.0
#      Light    Weekday   1.495273e+00  1.436418    8.9
#               Weekend   2.259042e+00  5.629593    9.8
#      Moderate Weekday   5.257655e-01 -1.185231   28.4
#               Weekend   6.094104e-01 -1.166105   33.6
#      Heavy    Weekday  -6.508143e-03 -0.451483  125.1
#               Weekend  -1.150339e-15 -2.000000   18.1
# 2023 Dry      Weekday            NaN       NaN    0.0
#               Weekend            NaN       NaN    0.0
#      Light    Weekday   1.200474e+00  0.498840    8.4
#               Weekend   1.168371e+00  0.980615    9.6
#      Moderate Weekday   9.401987e-02 -1.383928   36.3
#               Weekend  -2.757693e-01 -1.116908   37.1
#      Heavy    Weekday   5.965942e-01 -1.036149   41.3
# 2024 Dry      Weekday            NaN       NaN    0.0
#               Weekend            NaN       NaN    0.0
#      Light    Weekday   1.339345e+00  0.857442    9.6
#               Weekend   5.463859e-01 -0.940071    8.6
#      Moderate Weekday   1.668517e+00  2.000562   31.3
#               Weekend   4.837683e-01 -0.778391   37.3
#      Heavy    Weekday   3.912913e-01 -1.233432   63.7
#
# P_Grade-Season-Day Stats: (강수량)
#                            tot_cnt  cnt_nz  zero_cnt    min    max        mean  \
# P_Grade  Season Day_type
# Dry      Spring Weekday       194       0       194    NaN    0.0    0.000000
#                 Weekend        75       0        75    NaN    0.0    0.000000
#          Summer Weekday       141       0       141    NaN    0.0    0.000000
#                 Weekend        58       0        58    NaN    0.0    0.000000
#          Fall   Weekday       139       0       139    NaN    0.0    0.000000
#                 Weekend        68       0        68    NaN    0.0    0.000000
#          Winter Weekday       163       0       163    NaN    0.0    0.000000
#                 Weekend        82       0        82    NaN    0.0    0.000000
# Light    Spring Weekday        49      49         0    0.1    9.0    2.885714
#                 Weekend        23      23         0    0.1    9.2    2.517391
#          Summer Weekday        65      65         0    0.1    9.3    2.892308
#                 Weekend        24      24         0    0.1    9.9    3.425000
#          Fall   Weekday        27      27         0    0.1    8.5    3.148148
#                 Weekend        14      14         0    0.1    5.9    2.535714
#          Winter Weekday        53      53         0    0.1    9.7    1.839623
#                 Weekend        24      24         0    0.1    4.7    1.370833
# Moderate Spring Weekday         9       9         0   10.9   26.3   16.388889
#                 Weekend        14      14         0   14.6   48.3   29.435714
#          Summer Weekday        27      27         0   10.4   46.7   24.951852
#                 Weekend        21      21         0   11.0   47.5   26.423810
#          Fall   Weekday        15      15         0   11.8   45.8   22.140000
#                 Weekend         6       6         0   10.4   38.7   22.216667
#          Winter Weekday         6       6         0   10.9   37.3   20.916667
#                 Weekend         2       2         0   13.1   17.1   15.100000
# Heavy    Spring Weekday         1       1         0   50.3   50.3   50.300000
#                 Weekend         3       3         0   56.2   67.5   63.533333
#          Summer Weekday        20      20         0   51.1  176.2   88.505000
#                 Weekend         2       2         0   60.0   62.8   61.400000
#          Fall   Weekday         1       1         0  120.0  120.0  120.000000
#                 Weekend         3       3         0   57.9   76.0   67.333333
#
#                              med          var       q1       q3     iqr  \
# P_Grade  Season Day_type
# Dry      Spring Weekday     0.00     0.000000    0.000    0.000   0.000
#                 Weekend     0.00     0.000000    0.000    0.000   0.000
#          Summer Weekday     0.00     0.000000    0.000    0.000   0.000
#                 Weekend     0.00     0.000000    0.000    0.000   0.000
#          Fall   Weekday     0.00     0.000000    0.000    0.000   0.000
#                 Weekend     0.00     0.000000    0.000    0.000   0.000
#          Winter Weekday     0.00     0.000000    0.000    0.000   0.000
#                 Weekend     0.00     0.000000    0.000    0.000   0.000
# Light    Spring Weekday     1.90     7.330417    1.000    3.900   2.900
#                 Weekend     0.60     9.106047    0.250    4.700   4.450
#          Summer Weekday     2.00     6.521034    0.900    5.200   4.300
#                 Weekend     2.90     8.887174    0.900    4.950   4.050
#          Fall   Weekday     2.10     6.748746    1.300    4.500   3.200
#                 Weekend     2.10     4.830165    0.475    4.450   3.975
#          Winter Weekday     0.80     5.990900    0.300    2.300   2.000
#                 Weekend     1.10     1.441286    0.400    1.925   1.525
# Moderate Spring Weekday    15.50    28.598611   12.300   19.600   7.300
#                 Weekend    27.85   136.071703   20.000   39.300  19.300
#          Summer Weekday    21.10   134.183362   15.700   34.650  18.950
#                 Weekend    25.00   138.571905   16.500   34.000  17.500
#          Fall   Weekday    19.50   100.718286   13.950   27.500  13.550
#                 Weekend    18.10   130.849667   14.600   30.450  15.850
#          Winter Weekday    17.40   117.613667   12.800   27.775  14.975
#                 Weekend    15.10     8.000000   14.100   16.100   2.000
# Heavy    Spring Weekday    50.30          NaN   50.300   50.300   0.000
#                 Weekend    66.90    40.423333   61.550   67.200   5.650
#          Summer Weekday    78.65  1048.435237   64.775  105.875  41.100
#                 Weekend    61.40     3.920000   60.700   62.100   1.400
#          Fall   Weekday   120.00          NaN  120.000  120.000   0.000
#                 Weekend    68.10    82.343333   63.000   72.050   9.050
#
#                                   skew      kurt  range
# P_Grade  Season Day_type
# Dry      Spring Weekday            NaN       NaN    0.0
#                 Weekend            NaN       NaN    0.0
#          Summer Weekday            NaN       NaN    0.0
#                 Weekend            NaN       NaN    0.0
#          Fall   Weekday            NaN       NaN    0.0
#                 Weekend            NaN       NaN    0.0
#          Winter Weekday            NaN       NaN    0.0
#                 Weekend            NaN       NaN    0.0
# Light    Spring Weekday   1.146871e+00  0.061561    8.9
#                 Weekend   1.063409e+00 -0.218423    9.1
#          Summer Weekday   8.452638e-01 -0.442103    9.2
#                 Weekend   8.433473e-01 -0.310553    9.8
#          Fall   Weekday   7.136518e-01 -0.483066    8.4
#                 Weekend   2.516923e-01 -1.517883    5.8
#          Winter Weekday   2.059603e+00  3.534979    9.6
#                 Weekend   1.047610e+00  0.555855    4.6
# Moderate Spring Weekday   6.623611e-01 -0.801657   15.4
#                 Weekend   3.569352e-01 -1.183680   33.7
#          Summer Weekday   3.788771e-01 -1.221801   36.3
#                 Weekend   3.112994e-01 -1.171261   36.5
#          Fall   Weekday   8.716701e-01 -0.013387   34.0
#                 Weekend   5.265485e-01 -1.357761   28.3
#          Winter Weekday   6.005347e-01 -1.240752   26.4
#                 Weekend  -1.332268e-15 -2.000000    4.0
# Heavy    Spring Weekday            NaN       NaN    0.0
#                 Weekend  -7.000289e-01 -1.500000   11.3
#          Summer Weekday   1.082641e+00  0.647549  125.1
#                 Weekend   0.000000e+00 -2.000000    2.8
#          Fall   Weekday            NaN       NaN    0.0
#                 Weekend  -1.541055e-01 -1.500000   18.1

# %% [markdown]
# - 적설량 (세개 변수 조합 분석)

# %%
# 함수 실행 예시
df_Year_S_Grade_Season_stats = group_analysis_by_three_columns(
                                df = m_df,
                                group_col1 = "Year", 
                                group_col2 = "S_Grade", 
                                group_col3 = "Season", 
                                target_col = "Snow_depth(cm)")
df_Year_S_Grade_day_stats = group_analysis_by_three_columns(
                                df = m_df,
                                group_col1 = "Year", 
                                group_col2 = "S_Grade", 
                                group_col3 = "Day_type", 
                                target_col = "Snow_depth(cm)")
df_S_Grade_Season_day_stats = group_analysis_by_three_columns(
                                df = m_df,
                                group_col1 = "S_Grade", 
                                group_col2 = "Season", 
                                group_col3 = "Day_type", 
                                target_col = "Snow_depth(cm)")

# 결과를 딕셔너리로 정리
triple_group_stats_S3 = {
    "Year-S_Grade-Season": df_Year_S_Grade_Season_stats,
    "Year-S_Grade-Day": df_Year_S_Grade_day_stats,
    "S_Grade-Season-Day": df_S_Grade_Season_day_stats,
}

# 결과 출력
print("2. 삼중 그룹 분석 - 적설량")
for key, value in triple_group_stats_S3.items():
    print(f"\n{key} Stats: (적설량)\n", value)
# Out:
# 2. 삼중 그룹 분석 - 적설량
#
# Year-S_Grade-Season Stats: (적설량)
#                             tot_cnt  cnt_nz  zero_cnt   min   max       mean  \
# Year S_Grade       Season
# 2021 No_Snow       Spring       90       0        90   NaN   0.0   0.000000
#                    Summer       92       0        92   NaN   0.0   0.000000
#                    Fall         91       0        91   NaN   0.0   0.000000
#                    Winter       67       0        67   NaN   0.0   0.000000
#      Light_Snow    Winter       14      14         0   0.1   1.8   0.821429
#      Moderate_Snow Spring        2       2         0   2.3   2.3   2.300000
#                    Winter        9       9         0   3.3   5.1   4.255556
# 2022 No_Snow       Spring       91       0        91   NaN   0.0   0.000000
#                    Summer       92       0        92   NaN   0.0   0.000000
#                    Fall         91       0        91   NaN   0.0   0.000000
#                    Winter       60       0        60   NaN   0.0   0.000000
#      Light_Snow    Spring        1       1         0   0.7   0.7   0.700000
#                    Winter       24      24         0   0.1   1.9   0.987500
#      Moderate_Snow Winter        6       6         0   2.4   5.0   3.833333
# 2023 No_Snow       Spring       92       0        92   NaN   0.0   0.000000
#                    Summer       92       0        92   NaN   0.0   0.000000
#                    Fall         91       0        91   NaN   0.0   0.000000
#                    Winter       74       0        74   NaN   0.0   0.000000
#      Light_Snow    Winter        9       9         0   0.2   1.7   0.788889
#      Moderate_Snow Winter        6       6         0   2.1   8.8   4.266667
#      Heavy_Snow    Winter        1       1         0  12.2  12.2  12.200000
# 2024 No_Snow       Spring       92       0        92   NaN   0.0   0.000000
#                    Summer       82       0        82   NaN   0.0   0.000000
#                    Winter       42       0        42   NaN   0.0   0.000000
#      Light_Snow    Winter        6       6         0   0.2   2.0   1.383333
#      Moderate_Snow Winter       10      10         0   2.3   6.0   3.730000
#      Heavy_Snow    Winter        2       2         0  10.2  13.8  12.000000
#
#                              med       var      q1      q3    iqr      skew  \
# Year S_Grade       Season
# 2021 No_Snow       Spring   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Summer   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Fall     0.00  0.000000   0.000   0.000  0.000       NaN
#                    Winter   0.00  0.000000   0.000   0.000  0.000       NaN
#      Light_Snow    Winter   0.85  0.223352   0.475   1.075  0.600  0.264842
#      Moderate_Snow Spring   2.30  0.000000   2.300   2.300  0.000       NaN
#                    Winter   4.30  0.370278   3.800   4.600  0.800 -0.111947
# 2022 No_Snow       Spring   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Summer   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Fall     0.00  0.000000   0.000   0.000  0.000       NaN
#                    Winter   0.00  0.000000   0.000   0.000  0.000       NaN
#      Light_Snow    Spring   0.70       NaN   0.700   0.700  0.000       NaN
#                    Winter   0.95  0.351576   0.500   1.525  1.025  0.187971
#      Moderate_Snow Winter   3.80  0.830667   3.500   4.400  0.900 -0.322828
# 2023 No_Snow       Spring   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Summer   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Fall     0.00  0.000000   0.000   0.000  0.000       NaN
#                    Winter   0.00  0.000000   0.000   0.000  0.000       NaN
#      Light_Snow    Winter   0.60  0.281111   0.400   1.000  0.600  0.636894
#      Moderate_Snow Winter   3.60  5.558667   3.150   4.275  1.125  1.343758
#      Heavy_Snow    Winter  12.20       NaN  12.200  12.200  0.000       NaN
# 2024 No_Snow       Spring   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Summer   0.00  0.000000   0.000   0.000  0.000       NaN
#                    Winter   0.00  0.000000   0.000   0.000  0.000       NaN
#      Light_Snow    Winter   1.50  0.453667   1.200   1.875  0.675 -0.865810
#      Moderate_Snow Winter   3.35  1.957889   2.550   4.850  2.300  0.537426
#      Heavy_Snow    Winter  12.00  6.480000  11.100  12.900  1.800  0.000000
#
#                                kurt  range
# Year S_Grade       Season
# 2021 No_Snow       Spring       NaN    0.0
#                    Summer       NaN    0.0
#                    Fall         NaN    0.0
#                    Winter       NaN    0.0
#      Light_Snow    Winter -0.394398    1.7
#      Moderate_Snow Spring       NaN    0.0
#                    Winter -1.059808    1.8
# 2022 No_Snow       Spring       NaN    0.0
#                    Summer       NaN    0.0
#                    Fall         NaN    0.0
#                    Winter       NaN    0.0
#      Light_Snow    Spring       NaN    0.0
#                    Winter -1.327667    1.8
#      Moderate_Snow Winter -0.808494    2.6
# 2023 No_Snow       Spring       NaN    0.0
#                    Summer       NaN    0.0
#                    Fall         NaN    0.0
#                    Winter       NaN    0.0
#      Light_Snow    Winter -0.943827    1.5
#      Moderate_Snow Winter  0.474765    6.7
#      Heavy_Snow    Winter       NaN    0.0
# 2024 No_Snow       Spring       NaN    0.0
#                    Summer       NaN    0.0
#                    Winter       NaN    0.0
#      Light_Snow    Winter -0.368317    1.8
#      Moderate_Snow Winter -1.216287    3.7
#      Heavy_Snow    Winter -2.000000    3.6
#
# Year-S_Grade-Day Stats: (적설량)
#                               tot_cnt  cnt_nz  zero_cnt   min   max       mean  \
# Year S_Grade       Day_type
# 2021 No_Snow       Weekday       233       0       233   NaN   0.0   0.000000
#                    Weekend       107       0       107   NaN   0.0   0.000000
#      Light_Snow    Weekday        10      10         0   0.2   1.8   0.890000
#                    Weekend         4       4         0   0.1   1.0   0.650000
#      Moderate_Snow Weekday         8       8         0   2.3   5.1   3.950000
#                    Weekend         3       3         0   2.3   4.6   3.766667
# 2022 No_Snow       Weekday       229       0       229   NaN   0.0   0.000000
#                    Weekend       105       0       105   NaN   0.0   0.000000
#      Light_Snow    Weekday        15      15         0   0.2   1.9   0.873333
#                    Weekend        10      10         0   0.1   1.9   1.130000
#      Moderate_Snow Weekday         5       5         0   2.4   4.5   3.600000
#                    Weekend         1       1         0   5.0   5.0   5.000000
# 2023 No_Snow       Weekday       241       0       241   NaN   0.0   0.000000
#                    Weekend       108       0       108   NaN   0.0   0.000000
#      Light_Snow    Weekday         5       5         0   0.3   1.7   0.760000
#                    Weekend         4       4         0   0.2   1.5   0.825000
#      Moderate_Snow Weekday         3       3         0   2.1   4.5   3.400000
#                    Weekend         3       3         0   3.0   8.8   5.133333
#      Heavy_Snow    Weekend         1       1         0  12.2  12.2  12.200000
# 2024 No_Snow       Weekday       148       0       148   NaN   0.0   0.000000
#                    Weekend        68       0        68   NaN   0.0   0.000000
#      Light_Snow    Weekday         4       4         0   1.1   2.0   1.525000
#                    Weekend         2       2         0   0.2   2.0   1.100000
#      Moderate_Snow Weekday         7       7         0   2.3   5.2   3.328571
#                    Weekend         3       3         0   2.4   6.0   4.666667
#      Heavy_Snow    Weekday         2       2         0  10.2  13.8  12.000000
#
#                                med        var      q1      q3    iqr  \
# Year S_Grade       Day_type
# 2021 No_Snow       Weekday    0.00   0.000000   0.000   0.000  0.000
#                    Weekend    0.00   0.000000   0.000   0.000  0.000
#      Light_Snow    Weekday    0.95   0.254333   0.475   1.100  0.625
#                    Weekend    0.75   0.150000   0.550   0.850  0.300
#      Moderate_Snow Weekday    4.00   0.842857   3.525   4.475  0.950
#                    Weekend    4.40   1.623333   3.350   4.500  1.150
# 2022 No_Snow       Weekday    0.00   0.000000   0.000   0.000  0.000
#                    Weekend    0.00   0.000000   0.000   0.000  0.000
#      Light_Snow    Weekday    0.80   0.284952   0.450   1.150  0.700
#                    Weekend    1.25   0.420111   0.550   1.675  1.125
#      Moderate_Snow Weekday    3.50   0.630000   3.500   4.100  0.600
#                    Weekend    5.00        NaN   5.000   5.000  0.000
# 2023 No_Snow       Weekday    0.00   0.000000   0.000   0.000  0.000
#                    Weekend    0.00   0.000000   0.000   0.000  0.000
#      Light_Snow    Weekday    0.50   0.328000   0.400   0.900  0.500
#                    Weekend    0.80   0.309167   0.500   1.125  0.625
#      Moderate_Snow Weekday    3.60   1.470000   2.850   4.050  1.200
#                    Weekend    3.60  10.173333   3.300   6.200  2.900
#      Heavy_Snow    Weekend   12.20        NaN  12.200  12.200  0.000
# 2024 No_Snow       Weekday    0.00   0.000000   0.000   0.000  0.000
#                    Weekend    0.00   0.000000   0.000   0.000  0.000
#      Light_Snow    Weekday    1.50   0.135833   1.400   1.625  0.225
#                    Weekend    1.10   1.620000   0.650   1.550  0.900
#      Moderate_Snow Weekday    3.10   1.012381   2.650   3.700  1.050
#                    Weekend    5.60   3.893333   4.000   5.800  1.800
#      Heavy_Snow    Weekday   12.00   6.480000  11.100  12.900  1.800
#
#                                      skew      kurt  range
# Year S_Grade       Day_type
# 2021 No_Snow       Weekday            NaN       NaN    0.0
#                    Weekend            NaN       NaN    0.0
#      Light_Snow    Weekday   2.261634e-01 -0.777977    1.6
#                    Weekend  -7.950464e-01 -0.885926    0.9
#      Moderate_Snow Weekday  -4.097268e-01 -0.566343    2.8
#                    Weekend  -6.875556e-01 -1.500000    2.3
# 2022 No_Snow       Weekday            NaN       NaN    0.0
#                    Weekend            NaN       NaN    0.0
#      Light_Snow    Weekday   5.732812e-01 -0.690470    1.7
#                    Weekend  -2.484203e-01 -1.460277    1.8
#      Moderate_Snow Weekday  -4.896529e-01 -0.801398    2.1
#                    Weekend            NaN       NaN    0.0
# 2023 No_Snow       Weekday            NaN       NaN    0.0
#                    Weekend            NaN       NaN    0.0
#      Light_Snow    Weekday   9.995359e-01 -0.538918    1.4
#                    Weekend   1.284641e-01 -1.308956    1.3
#      Moderate_Snow Weekday  -2.947996e-01 -1.500000    2.4
#                    Weekend   6.790609e-01 -1.500000    5.8
#      Heavy_Snow    Weekend            NaN       NaN    0.0
# 2024 No_Snow       Weekday            NaN       NaN    0.0
#                    Weekend            NaN       NaN    0.0
#      Light_Snow    Weekday   2.335366e-01 -0.987843    0.9
#                    Weekend  -3.807349e-16 -2.000000    1.8
#      Moderate_Snow Weekday   7.873572e-01 -0.235154    2.9
#                    Weekend  -6.745555e-01 -1.500000    3.6
#      Heavy_Snow    Weekday   0.000000e+00 -2.000000    3.6
#
# S_Grade-Season-Day Stats: (적설량)
#                                 tot_cnt  cnt_nz  zero_cnt   min   max  \
# S_Grade       Season Day_type
# No_Snow       Spring Weekday       252       0       252   NaN   0.0
#                      Weekend       113       0       113   NaN   0.0
#               Summer Weekday       253       0       253   NaN   0.0
#                      Weekend       105       0       105   NaN   0.0
#               Fall   Weekday       182       0       182   NaN   0.0
#                      Weekend        91       0        91   NaN   0.0
#               Winter Weekday       164       0       164   NaN   0.0
#                      Weekend        79       0        79   NaN   0.0
# Light_Snow    Spring Weekend         1       1         0   0.7   0.7
#               Winter Weekday        34      34         0   0.2   2.0
#                      Weekend        19      19         0   0.1   2.0
# Moderate_Snow Spring Weekday         1       1         0   2.3   2.3
#                      Weekend         1       1         0   2.3   2.3
#               Winter Weekday        22      22         0   2.1   5.2
#                      Weekend         9       9         0   2.4   8.8
# Heavy_Snow    Winter Weekday         2       2         0  10.2  13.8
#                      Weekend         1       1         0  12.2  12.2
#
#                                     mean   med       var      q1      q3  \
# S_Grade       Season Day_type
# No_Snow       Spring Weekday    0.000000   0.0  0.000000   0.000   0.000
#                      Weekend    0.000000   0.0  0.000000   0.000   0.000
#               Summer Weekday    0.000000   0.0  0.000000   0.000   0.000
#                      Weekend    0.000000   0.0  0.000000   0.000   0.000
#               Fall   Weekday    0.000000   0.0  0.000000   0.000   0.000
#                      Weekend    0.000000   0.0  0.000000   0.000   0.000
#               Winter Weekday    0.000000   0.0  0.000000   0.000   0.000
#                      Weekend    0.000000   0.0  0.000000   0.000   0.000
# Light_Snow    Spring Weekend    0.700000   0.7       NaN   0.700   0.700
#               Winter Weekday    0.938235   0.9  0.291524   0.425   1.350
#                      Weekend    0.984211   1.0  0.415848   0.500   1.550
# Moderate_Snow Spring Weekday    2.300000   2.3       NaN   2.300   2.300
#                      Weekend    2.300000   2.3       NaN   2.300   2.300
#               Winter Weekday    3.672727   3.6  0.821126   3.150   4.275
#                      Weekend    4.822222   4.6  3.594444   3.600   5.600
# Heavy_Snow    Winter Weekday   12.000000  12.0  6.480000  11.100  12.900
#                      Weekend   12.200000  12.2       NaN  12.200  12.200
#
#                                  iqr      skew      kurt  range
# S_Grade       Season Day_type
# No_Snow       Spring Weekday   0.000       NaN       NaN    0.0
#                      Weekend   0.000       NaN       NaN    0.0
#               Summer Weekday   0.000       NaN       NaN    0.0
#                      Weekend   0.000       NaN       NaN    0.0
#               Fall   Weekday   0.000       NaN       NaN    0.0
#                      Weekend   0.000       NaN       NaN    0.0
#               Winter Weekday   0.000       NaN       NaN    0.0
#                      Weekend   0.000       NaN       NaN    0.0
# Light_Snow    Spring Weekend   0.000       NaN       NaN    0.0
#               Winter Weekday   0.925  0.354012 -0.983890    1.8
#                      Weekend   1.050  0.122097 -1.346120    1.9
# Moderate_Snow Spring Weekday   0.000       NaN       NaN    0.0
#                      Weekend   0.000       NaN       NaN    0.0
#               Winter Weekday   1.125 -0.082844 -0.774861    3.1
#                      Weekend   2.000  0.834145  0.269246    6.4
# Heavy_Snow    Winter Weekday   1.800  0.000000 -2.000000    3.6
#                      Weekend   0.000       NaN       NaN    0.0
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\1731610920.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   ("skew", lambda x: skew(x)),
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\1731610920.py:16: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   ("kurt", lambda x: kurtosis(x)),

# %% [markdown]
# 4. 모든 변수 조합 분석

# %%
# 4-1. 연도와 등급과 계절과 평일/주말을 조합해서 분석

# %% [markdown]
# - 강수량, 적설량 (네개 변수 조합 분석)

# %%
def group_analysis_by_four_columns(df, group_col1, group_col2, group_col3, group_col4, target_col):
    # 기본 통계치 계산
    stats = df.groupby([group_col1, group_col2, group_col3, group_col4], observed=True)[target_col].agg([
        ("tot_cnt", "count"),               # 전체 카운트
        ("cnt_nz", lambda x: (x != 0).sum()), # 0 제외 카운트
        ("zero_cnt", lambda x: (x == 0).sum()), # 0인 값의 카운트
        ("min", lambda x: x[x != 0].min()), # 0 제외 최소값
        ("max", "max"),
        ("mean", "mean"),
        ("med", "median"),
        ("var", "var"),
        ("q1", lambda x: x.quantile(0.25)),
        ("q3", lambda x: x.quantile(0.75)),
        ("iqr", lambda x: x.quantile(0.75) - x.quantile(0.25)),
        ("skew", lambda x: skew(x)),
        ("kurt", lambda x: kurtosis(x)),
        ("range", lambda x: x.max() - x.min())
    ])
    
    # 컬럼 순서 재정렬
    stats = stats[[
        # 카운트 관련 (0 포함/제외 구분)
        "tot_cnt", "cnt_nz", "zero_cnt",
        # 기본 통계치 (min은 0 제외)
        "min", "max", "mean", "med", "var",
        "q1", "q3", "iqr",
        "skew", "kurt", "range"]]
    
    return stats

# %% [markdown]
# - 강수량 (네개 변수 조합 분석)

# %%
# 함수 실행 예시
df_Year_Season_P_Grade_day_stats = group_analysis_by_four_columns(
                                df = m_df,
                                group_col1 = "Year", 
                                group_col2 = "Season",
                                group_col3 = "P_Grade",  
                                group_col4 = "Day_type",
                                target_col = "Precipitation(mm)")

# 결과를 딕셔너리로 정리
quadruple_group_stats_P4 = {
    "Year-P_Grade-Season": df_Year_Season_P_Grade_day_stats
}

# 결과 출력
print("2. 사중 그룹 분석 - 강수량")
for key, value in quadruple_group_stats_P4.items():
    print(f"\n{key} Stats: (강수량) \n", value)
# Out:
# 2. 사중 그룹 분석 - 강수량
#
# Year-P_Grade-Season Stats: (강수량)
#                                 tot_cnt  cnt_nz  zero_cnt   min   max  \
# Year Season P_Grade  Day_type
# 2021 Spring Dry      Weekday        43       0        43   NaN   0.0
#                      Weekend        14       0        14   NaN   0.0
#             Light    Weekday        16      16         0   0.1   8.9
#                      Weekend         9       9         0   0.1   9.2
#             Moderate Weekday         4       4         0  12.3  26.3
# ...                                ...     ...       ...   ...   ...
# 2024 Winter Dry      Weekend        12       0        12   NaN   0.0
#             Light    Weekday        11      11         0   0.2   9.7
#                      Weekend         6       6         0   0.4   3.1
#             Moderate Weekday         2       2         0  10.9  17.8
#                      Weekend         1       1         0  17.1  17.1
#
#                                     mean    med        var      q1      q3  \
# Year Season P_Grade  Day_type
# 2021 Spring Dry      Weekday    0.000000   0.00   0.000000   0.000   0.000
#                      Weekend    0.000000   0.00   0.000000   0.000   0.000
#             Light    Weekday    3.950000   3.50  10.616000   1.200   7.175
#                      Weekend    2.833333   0.60  13.235000   0.300   5.100
#             Moderate Weekday   20.050000  20.80  34.376667  17.775  23.075
# ...                                  ...    ...        ...     ...     ...
# 2024 Winter Dry      Weekend    0.000000   0.00   0.000000   0.000   0.000
#             Light    Weekday    3.400000   1.60  14.896000   0.450   6.350
#                      Weekend    1.733333   2.05   1.238667   0.750   2.375
#             Moderate Weekday   14.350000  14.35  23.805000  12.625  16.075
#                      Weekend   17.100000  17.10        NaN  17.100  17.100
#
#                                  iqr          skew      kurt  range
# Year Season P_Grade  Day_type
# 2021 Spring Dry      Weekday   0.000           NaN       NaN    0.0
#                      Weekend   0.000           NaN       NaN    0.0
#             Light    Weekday   5.975  3.895624e-01 -1.376178    8.8
#                      Weekend   4.800  8.917321e-01 -0.916828    9.1
#             Moderate Weekday   5.300 -4.087021e-01 -1.063941   14.0
# ...                              ...           ...       ...    ...
# 2024 Winter Dry      Weekend   0.000           NaN       NaN    0.0
#             Light    Weekday   5.900  7.822337e-01 -1.128811    9.5
#                      Weekend   1.625 -2.716891e-01 -1.418519    2.7
#             Moderate Weekday   3.450 -7.786556e-16 -2.000000    6.9
#                      Weekend   0.000           NaN       NaN    0.0
#
# [95 rows x 14 columns]

# %% [markdown]
# - 적설량 (네개 변수 조합 분석)

# %%
# 함수 실행 예시
df_Year_Season_S_Grade_day_stats = group_analysis_by_four_columns(
                                df = m_df,
                                group_col1 = "Year", 
                                group_col2 = "Season",
                                group_col3 = "S_Grade",  
                                group_col4 = "Day_type",
                                target_col = "Snow_depth(cm)")

# 결과를 딕셔너리로 정리
quadruple_group_stats_S4 = {
    "Year-S_Grade-Season": df_Year_Season_S_Grade_day_stats
}

# 결과 출력
print("2. 사중 그룹 분석 - 적설량")
for key, value in quadruple_group_stats_S4.items():
    print(f"\n{key} Stats: (적설량) \n", value)
# Out:
# 2. 사중 그룹 분석 - 적설량
#
# Year-S_Grade-Season Stats: (적설량)
#                                      tot_cnt  cnt_nz  zero_cnt   min   max  \
# Year Season S_Grade       Day_type
# 2021 Spring No_Snow       Weekday        62       0        62   NaN   0.0
#                           Weekend        28       0        28   NaN   0.0
#             Moderate_Snow Weekday         1       1         0   2.3   2.3
#                           Weekend         1       1         0   2.3   2.3
#      Summer No_Snow       Weekday        66       0        66   NaN   0.0
#                           Weekend        26       0        26   NaN   0.0
#      Fall   No_Snow       Weekday        61       0        61   NaN   0.0
#                           Weekend        30       0        30   NaN   0.0
#      Winter No_Snow       Weekday        44       0        44   NaN   0.0
#                           Weekend        23       0        23   NaN   0.0
#             Light_Snow    Weekday        10      10         0   0.2   1.8
#                           Weekend         4       4         0   0.1   1.0
#             Moderate_Snow Weekday         7       7         0   3.3   5.1
#                           Weekend         2       2         0   4.4   4.6
# 2022 Spring No_Snow       Weekday        63       0        63   NaN   0.0
#                           Weekend        28       0        28   NaN   0.0
#             Light_Snow    Weekend         1       1         0   0.7   0.7
#      Summer No_Snow       Weekday        65       0        65   NaN   0.0
#                           Weekend        27       0        27   NaN   0.0
#      Fall   No_Snow       Weekday        61       0        61   NaN   0.0
#                           Weekend        30       0        30   NaN   0.0
#      Winter No_Snow       Weekday        40       0        40   NaN   0.0
#                           Weekend        20       0        20   NaN   0.0
#             Light_Snow    Weekday        15      15         0   0.2   1.9
#                           Weekend         9       9         0   0.1   1.9
#             Moderate_Snow Weekday         5       5         0   2.4   4.5
#                           Weekend         1       1         0   5.0   5.0
# 2023 Spring No_Snow       Weekday        64       0        64   NaN   0.0
#                           Weekend        28       0        28   NaN   0.0
#      Summer No_Snow       Weekday        65       0        65   NaN   0.0
#                           Weekend        27       0        27   NaN   0.0
#      Fall   No_Snow       Weekday        60       0        60   NaN   0.0
#                           Weekend        31       0        31   NaN   0.0
#      Winter No_Snow       Weekday        52       0        52   NaN   0.0
#                           Weekend        22       0        22   NaN   0.0
#             Light_Snow    Weekday         5       5         0   0.3   1.7
#                           Weekend         4       4         0   0.2   1.5
#             Moderate_Snow Weekday         3       3         0   2.1   4.5
#                           Weekend         3       3         0   3.0   8.8
#             Heavy_Snow    Weekend         1       1         0  12.2  12.2
# 2024 Spring No_Snow       Weekday        63       0        63   NaN   0.0
#                           Weekend        29       0        29   NaN   0.0
#      Summer No_Snow       Weekday        57       0        57   NaN   0.0
#                           Weekend        25       0        25   NaN   0.0
#      Winter No_Snow       Weekday        28       0        28   NaN   0.0
#                           Weekend        14       0        14   NaN   0.0
#             Light_Snow    Weekday         4       4         0   1.1   2.0
#                           Weekend         2       2         0   0.2   2.0
#             Moderate_Snow Weekday         7       7         0   2.3   5.2
#                           Weekend         3       3         0   2.4   6.0
#             Heavy_Snow    Weekday         2       2         0  10.2  13.8
#
#                                          mean    med        var      q1  \
# Year Season S_Grade       Day_type
# 2021 Spring No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#             Moderate_Snow Weekday    2.300000   2.30        NaN   2.300
#                           Weekend    2.300000   2.30        NaN   2.300
#      Summer No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Fall   No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Winter No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#             Light_Snow    Weekday    0.890000   0.95   0.254333   0.475
#                           Weekend    0.650000   0.75   0.150000   0.550
#             Moderate_Snow Weekday    4.185714   4.20   0.464762   3.700
#                           Weekend    4.500000   4.50   0.020000   4.450
# 2022 Spring No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#             Light_Snow    Weekend    0.700000   0.70        NaN   0.700
#      Summer No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Fall   No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Winter No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#             Light_Snow    Weekday    0.873333   0.80   0.284952   0.450
#                           Weekend    1.177778   1.50   0.446944   0.500
#             Moderate_Snow Weekday    3.600000   3.50   0.630000   3.500
#                           Weekend    5.000000   5.00        NaN   5.000
# 2023 Spring No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Summer No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Fall   No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Winter No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#             Light_Snow    Weekday    0.760000   0.50   0.328000   0.400
#                           Weekend    0.825000   0.80   0.309167   0.500
#             Moderate_Snow Weekday    3.400000   3.60   1.470000   2.850
#                           Weekend    5.133333   3.60  10.173333   3.300
#             Heavy_Snow    Weekend   12.200000  12.20        NaN  12.200
# 2024 Spring No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Summer No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#      Winter No_Snow       Weekday    0.000000   0.00   0.000000   0.000
#                           Weekend    0.000000   0.00   0.000000   0.000
#             Light_Snow    Weekday    1.525000   1.50   0.135833   1.400
#                           Weekend    1.100000   1.10   1.620000   0.650
#             Moderate_Snow Weekday    3.328571   3.10   1.012381   2.650
#                           Weekend    4.666667   5.60   3.893333   4.000
#             Heavy_Snow    Weekday   12.000000  12.00   6.480000  11.100
#
#                                         q3    iqr          skew      kurt  \
# Year Season S_Grade       Day_type
# 2021 Spring No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#             Moderate_Snow Weekday    2.300  0.000           NaN       NaN
#                           Weekend    2.300  0.000           NaN       NaN
#      Summer No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Fall   No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Winter No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#             Light_Snow    Weekday    1.100  0.625  2.261634e-01 -0.777977
#                           Weekend    0.850  0.300 -7.950464e-01 -0.885926
#             Moderate_Snow Weekday    4.650  0.950  2.002964e-01 -1.295192
#                           Weekend    4.550  0.100  0.000000e+00 -2.000000
# 2022 Spring No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#             Light_Snow    Weekend    0.700  0.000           NaN       NaN
#      Summer No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Fall   No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Winter No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#             Light_Snow    Weekday    1.150  0.700  5.732812e-01 -0.690470
#                           Weekend    1.700  1.200 -4.488333e-01 -1.372917
#             Moderate_Snow Weekday    4.100  0.600 -4.896529e-01 -0.801398
#                           Weekend    5.000  0.000           NaN       NaN
# 2023 Spring No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Summer No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Fall   No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Winter No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#             Light_Snow    Weekday    0.900  0.500  9.995359e-01 -0.538918
#                           Weekend    1.125  0.625  1.284641e-01 -1.308956
#             Moderate_Snow Weekday    4.050  1.200 -2.947996e-01 -1.500000
#                           Weekend    6.200  2.900  6.790609e-01 -1.500000
#             Heavy_Snow    Weekend   12.200  0.000           NaN       NaN
# 2024 Spring No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Summer No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#      Winter No_Snow       Weekday    0.000  0.000           NaN       NaN
#                           Weekend    0.000  0.000           NaN       NaN
#             Light_Snow    Weekday    1.625  0.225  2.335366e-01 -0.987843
#                           Weekend    1.550  0.900 -3.807349e-16 -2.000000
#             Moderate_Snow Weekday    3.700  1.050  7.873572e-01 -0.235154
#                           Weekend    5.800  1.800 -6.745555e-01 -1.500000
#             Heavy_Snow    Weekday   12.900  1.800  0.000000e+00 -2.000000
#
#                                     range
# Year Season S_Grade       Day_type
# 2021 Spring No_Snow       Weekday     0.0
#                           Weekend     0.0
#             Moderate_Snow Weekday     0.0
#                           Weekend     0.0
#      Summer No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Fall   No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Winter No_Snow       Weekday     0.0
#                           Weekend     0.0
#             Light_Snow    Weekday     1.6
#                           Weekend     0.9
#             Moderate_Snow Weekday     1.8
#                           Weekend     0.2
# 2022 Spring No_Snow       Weekday     0.0
#                           Weekend     0.0
#             Light_Snow    Weekend     0.0
#      Summer No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Fall   No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Winter No_Snow       Weekday     0.0
#                           Weekend     0.0
#             Light_Snow    Weekday     1.7
#                           Weekend     1.8
#             Moderate_Snow Weekday     2.1
#                           Weekend     0.0
# 2023 Spring No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Summer No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Fall   No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Winter No_Snow       Weekday     0.0
#                           Weekend     0.0
#             Light_Snow    Weekday     1.4
#                           Weekend     1.3
#             Moderate_Snow Weekday     2.4
#                           Weekend     5.8
#             Heavy_Snow    Weekend     0.0
# 2024 Spring No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Summer No_Snow       Weekday     0.0
#                           Weekend     0.0
#      Winter No_Snow       Weekday     0.0
#                           Weekend     0.0
#             Light_Snow    Weekday     0.9
#                           Weekend     1.8
#             Moderate_Snow Weekday     2.9
#                           Weekend     3.6
#             Heavy_Snow    Weekday     3.6

# %% [markdown]
# - 시각화

# %%
m_df['Snow_depth(mm)'] = m_df['Snow_depth(cm)'] * 10

# %%
plt.figure(figsize=(5, 3))
sns.boxplot(x='Year', y='Precipitation(mm)', data=m_df)
plt.title('연도별 강수량 분포')
plt.xlabel('Year')
plt.ylabel('Precipitation (mm)')
plt.grid(True)

plt.figure(figsize=(5, 3))
sns.boxplot(x='Year', y='Snow_depth(mm)', data=m_df)
plt.title('연도별 적설량 분포')
plt.xlabel('Year')
plt.ylabel('Snow_depth(mm)')
plt.grid(True)

plt.show()

# %%
# 계절별 평균 미세먼지농도 계산
seasonal_fine_dust = m_df.groupby('Season')['Fine_dust(㎍/㎥)'].mean()
# 막대 그래프 그리기
plt.figure(figsize=(5,3))
seasonal_fine_dust.plot(kind='bar', color='DarkKhaki')
plt.title(' Average Fine Dust by Season')
plt.xlabel('Season')
plt.ylabel('Average Fine_dust(㎍/㎥)')
plt.xticks(rotation=0)
plt.grid(axis='y')

# 계절별 평균 강수량 계산
seasonal_precipitation = m_df.groupby('Season')['Precipitation(mm)'].mean()
# 막대 그래프 그리기
plt.figure(figsize=(5,3))
seasonal_precipitation.plot(kind='bar', color='skyblue')
plt.title('Average Precipitation by Season')
plt.xlabel('Season')
plt.ylabel('Average Precipitation (mm)')
plt.xticks(rotation=0)
plt.grid(axis='y')

# 계절별 평균 적설량 계산
seasonal_snow_depth = m_df.groupby('Season')['Snow_depth(mm)'].mean()
# 막대 그래프 그리기
plt.figure(figsize=(5,3))
seasonal_snow_depth.plot(kind='bar', color='RoyalBlue')
plt.title('Average Snow Depth by Season')
plt.xlabel('Season')
plt.ylabel('Average Snow Depth (mm)')
plt.xticks(rotation=0)
plt.grid(axis='y')


plt.show()
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\1457363510.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   seasonal_fine_dust = m_df.groupby('Season')['Fine_dust(㎍/㎥)'].mean()
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\1457363510.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   seasonal_precipitation = m_df.groupby('Season')['Precipitation(mm)'].mean()
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\1457363510.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   seasonal_snow_depth = m_df.groupby('Season')['Snow_depth(mm)'].mean()

# %%
# 연도, 계절, 등급별 평균 강수량 계산
year_season_grade_avg = m_df.groupby(['Year', 'Season', 'P_Grade'])['Precipitation(mm)'].mean().unstack(level=1).unstack(level=1)

# 히트맵 그리기
plt.figure(figsize=(12, 6))
sns.heatmap(year_season_grade_avg, annot=True, cmap='YlGnBu', fmt=".1f", cbar_kws={'label': 'Precipitation(mm)'})
plt.title('Average Precipitation by Year, Season, and Grade')
plt.xlabel('Season')
plt.ylabel('Year')

plt.show()
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\498459889.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   year_season_grade_avg = m_df.groupby(['Year', 'Season', 'P_Grade'])['Precipitation(mm)'].mean().unstack(level=1).unstack(level=1)

# %%
# 연도, 계절, 등급별 평균 적설량 계산
year_season_grade_avg = m_df.groupby(['Year', 'Season', 'P_Grade'])['Snow_depth(mm)'].mean().unstack(level=1).unstack(level=1)

# 히트맵 그리기
plt.figure(figsize=(12, 6))
sns.heatmap(year_season_grade_avg, annot=True, cmap='YlGnBu', fmt=".1f", cbar_kws={'label': 'Snow_depth(mm)'})
plt.title('Average Snow Depth by Year, Season, and Grade')
plt.xlabel('Season')
plt.ylabel('Year')

plt.show()
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_9256\3535831800.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   year_season_grade_avg = m_df.groupby(['Year', 'Season', 'P_Grade'])['Snow_depth(mm)'].mean().unstack(level=1).unstack(level=1)

# %%
m_df
# Out:
#            Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 0    2021-01-01            36.0                0.0             0.0  Weekend
# 1    2021-01-02            43.0                0.0             0.0  Weekend
# 2    2021-01-03            47.0                0.0             0.0  Weekend
# 3    2021-01-04            50.0                0.0             0.0  Weekday
# 4    2021-01-05            37.0                0.0             0.0  Weekday
# ...         ...             ...                ...             ...      ...
# 1324 2024-08-17            25.0               11.0             0.0  Weekend
# 1325 2024-08-18            23.0                0.0             0.0  Weekend
# 1326 2024-08-19            26.0                2.3             0.0  Weekday
# 1327 2024-08-20            26.0                0.0             0.0  Weekday
# 1328 2024-08-21            13.0               42.2             0.0  Weekday
#
#       Season  Year FD_Grade   P_Grade  S_Grade  Snow_depth(mm)
# 0     Winter  2021   Normal       Dry  No_Snow             0.0
# 1     Winter  2021   Normal       Dry  No_Snow             0.0
# 2     Winter  2021   Normal       Dry  No_Snow             0.0
# 3     Winter  2021   Normal       Dry  No_Snow             0.0
# 4     Winter  2021   Normal       Dry  No_Snow             0.0
# ...      ...   ...      ...       ...      ...             ...
# 1324  Summer  2024     Good  Moderate  No_Snow             0.0
# 1325  Summer  2024     Good       Dry  No_Snow             0.0
# 1326  Summer  2024     Good     Light  No_Snow             0.0
# 1327  Summer  2024     Good       Dry  No_Snow             0.0
# 1328  Summer  2024     Good  Moderate  No_Snow             0.0
#
# [1329 rows x 11 columns]

# %% [markdown]
# - 미세먼지, 강수량, 적설량 시각화

# %%
# deep copy를 사용하여 새로운 데이터프레임 생성
m_df2 = m_df.copy()

from sklearn.preprocessing import MinMaxScaler

# 스케일링할 컬럼 선택
cols_to_scale = ['Fine_dust(㎍/㎥)', 'Precipitation(mm)', 'Snow_depth(mm)']

# MinMaxScaler 생성 및 fit_transform
scaler = MinMaxScaler()
m_df2[cols_to_scale] = scaler.fit_transform(m_df[cols_to_scale])

# 결과 확인
print(m_df2[cols_to_scale].head())
# Out:
#    Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(mm)
# 0        0.073491                0.0             0.0
# 1        0.091864                0.0             0.0
# 2        0.102362                0.0             0.0
# 3        0.110236                0.0             0.0
# 4        0.076115                0.0             0.0

# %%
m_df
# Out:
#            Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 0    2021-01-01            36.0                0.0             0.0  Weekend
# 1    2021-01-02            43.0                0.0             0.0  Weekend
# 2    2021-01-03            47.0                0.0             0.0  Weekend
# 3    2021-01-04            50.0                0.0             0.0  Weekday
# 4    2021-01-05            37.0                0.0             0.0  Weekday
# ...         ...             ...                ...             ...      ...
# 1324 2024-08-17            25.0               11.0             0.0  Weekend
# 1325 2024-08-18            23.0                0.0             0.0  Weekend
# 1326 2024-08-19            26.0                2.3             0.0  Weekday
# 1327 2024-08-20            26.0                0.0             0.0  Weekday
# 1328 2024-08-21            13.0               42.2             0.0  Weekday
#
#       Season  Year FD_Grade   P_Grade  S_Grade  Snow_depth(mm)
# 0     Winter  2021   Normal       Dry  No_Snow             0.0
# 1     Winter  2021   Normal       Dry  No_Snow             0.0
# 2     Winter  2021   Normal       Dry  No_Snow             0.0
# 3     Winter  2021   Normal       Dry  No_Snow             0.0
# 4     Winter  2021   Normal       Dry  No_Snow             0.0
# ...      ...   ...      ...       ...      ...             ...
# 1324  Summer  2024     Good  Moderate  No_Snow             0.0
# 1325  Summer  2024     Good       Dry  No_Snow             0.0
# 1326  Summer  2024     Good     Light  No_Snow             0.0
# 1327  Summer  2024     Good       Dry  No_Snow             0.0
# 1328  Summer  2024     Good  Moderate  No_Snow             0.0
#
# [1329 rows x 11 columns]

# %%
m_df2
# Out:
#            Date  Fine_dust(㎍/㎥)  Precipitation(mm)  Snow_depth(cm) Day_type  \
# 0    2021-01-01        0.073491           0.000000             0.0  Weekend
# 1    2021-01-02        0.091864           0.000000             0.0  Weekend
# 2    2021-01-03        0.102362           0.000000             0.0  Weekend
# 3    2021-01-04        0.110236           0.000000             0.0  Weekday
# 4    2021-01-05        0.076115           0.000000             0.0  Weekday
# ...         ...             ...                ...             ...      ...
# 1324 2024-08-17        0.044619           0.062429             0.0  Weekend
# 1325 2024-08-18        0.039370           0.000000             0.0  Weekend
# 1326 2024-08-19        0.047244           0.013053             0.0  Weekday
# 1327 2024-08-20        0.047244           0.000000             0.0  Weekday
# 1328 2024-08-21        0.013123           0.239501             0.0  Weekday
#
#       Season  Year FD_Grade   P_Grade  S_Grade  Snow_depth(mm)
# 0     Winter  2021   Normal       Dry  No_Snow             0.0
# 1     Winter  2021   Normal       Dry  No_Snow             0.0
# 2     Winter  2021   Normal       Dry  No_Snow             0.0
# 3     Winter  2021   Normal       Dry  No_Snow             0.0
# 4     Winter  2021   Normal       Dry  No_Snow             0.0
# ...      ...   ...      ...       ...      ...             ...
# 1324  Summer  2024     Good  Moderate  No_Snow             0.0
# 1325  Summer  2024     Good       Dry  No_Snow             0.0
# 1326  Summer  2024     Good     Light  No_Snow             0.0
# 1327  Summer  2024     Good       Dry  No_Snow             0.0
# 1328  Summer  2024     Good  Moderate  No_Snow             0.0
#
# [1329 rows x 11 columns]

# %%
# 미세먼지와 강수량의 관계

# 강수량이 0이 아닌 날의 인덱스 찾기
non_zero_precipitation_dates = m_df2[m_df2['Precipitation(mm)'] > 0]['Date']

# 같은 날의 미세먼지 농도 추출
filtered_df = m_df2[m_df2['Date'].isin(non_zero_precipitation_dates)]

# 상관관계 계산
corr_matrix = filtered_df[['Fine_dust(㎍/㎥)', 'Precipitation(mm)']].corr()

# 히트맵 그리기
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', cbar_kws={'label': 'Correlation Coefficient'})
plt.title('Correlation between Fine Dust Concentration and Precipitation (Matching Dates)')
plt.xticks([0.5, 1.5], ['Fine Dust (㎍/㎥)', 'Precipitation (mm)'])
plt.yticks([0.5, 1.5], ['Fine Dust (㎍/㎥)', 'Precipitation (mm)'])
plt.show()

# %%
# 미세먼지와 적설량의 관계

# 강수량이 0이 아닌 날의 인덱스 찾기
non_zero_Snow_depth_dates = m_df2[m_df2['Snow_depth(cm)'] > 0]['Date']

# 같은 날의 미세먼지 농도 추출
filtered_df = m_df[m_df2['Date'].isin(non_zero_Snow_depth_dates)]

# 상관관계 계산
corr_matrix = filtered_df[['Fine_dust(㎍/㎥)', 'Snow_depth(cm)']].corr()

# 히트맵 그리기
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', cbar_kws={'label': 'Correlation Coefficient'})
plt.title('Correlation between Fine Dust Concentration and Snow_depth (Matching Dates)')
plt.xticks([0.5, 1.5], ['Fine Dust (㎍/㎥)', 'Snow_depth (mm)'])
plt.yticks([0.5, 1.5], ['Fine Dust (㎍/㎥)', 'Snow_depth (mm)'])
plt.show()

# %%
# 시간에 따른 강수량과 적설량

plt.figure(figsize=(5, 3))
plt.scatter(m_df['Date'], m_df['Precipitation(mm)'], alpha=0.5, color='blue')
plt.title('Precipitation Over Time')
plt.xlabel('Date')
plt.ylabel('Precipitation(mm)')
plt.grid(True)

plt.figure(figsize=(5, 3))
plt.scatter(m_df['Date'], m_df['Snow_depth(mm)'], alpha=0.5, color='blue')
plt.title('Snow Depth Over Time')
plt.xlabel('Date')
plt.ylabel('Snow_depth(mm)')
plt.grid(True)


plt.show()

# %%
m_df.to_csv('data/m_df.csv')
m_df2.to_csv('data/m_df2.csv')

# %%
m_df.info(), m_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1329 entries, 0 to 1328
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1329 non-null   datetime64[ns]
#  1   Fine_dust(㎍/㎥)     1329 non-null   float64
#  2   Precipitation(mm)  1329 non-null   float64
#  3   Snow_depth(cm)     1329 non-null   float64
#  4   Day_type           1329 non-null   object
#  5   Season             1329 non-null   category
#  6   Year               1329 non-null   int32
#  7   FD_Grade           1329 non-null   category
#  8   P_Grade            1329 non-null   category
#  9   S_Grade            1329 non-null   category
#  10  Snow_depth(mm)     1329 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(4), int32(1), object(1)
# memory usage: 73.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1329 entries, 0 to 1328
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1329 non-null   datetime64[ns]
#  1   Fine_dust(㎍/㎥)     1329 non-null   float64
#  2   Precipitation(mm)  1329 non-null   float64
#  3   Snow_depth(cm)     1329 non-null   float64
#  4   Day_type           1329 non-null   object
#  5   Season             1329 non-null   category
#  6   Year               1329 non-null   int32
#  7   FD_Grade           1329 non-null   category
#  8   P_Grade            1329 non-null   category
#  9   S_Grade            1329 non-null   category
#  10  Snow_depth(mm)     1329 non-null   float64
# dtypes: category(4), datetime64[ns](1), float64(4), int32(1), object(1)
# memory usage: 73.6+ KB
# (None, None)
