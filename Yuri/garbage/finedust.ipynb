# %% [markdown]
# ### 2023 미세먼지 농도

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2023 = pd.read_csv('./finedust/일별평균대기오염도_2023.csv', encoding='cp949')
df_2023.head()
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  int64
#  1   측정소명          18250 non-null  object
#  2   이산화질소농도(ppm)  18159 non-null  float64
#  3   오존농도(ppm)     18157 non-null  float64
#  4   일산화탄소농도(ppm)  17766 non-null  float64
#  5   아황산가스농도(ppm)  18029 non-null  float64
#  6   미세먼지농도(㎍/㎥)   18137 non-null  float64
#  7   초미세먼지농도(㎍/㎥)  18132 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
df_2023.columns
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2023 = df_2023.loc[:, ['측정일시', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)']]
fd_2023.head()
fd_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  int64
#  1   미세먼지농도(㎍/㎥)   18137 non-null  float64
#  2   초미세먼지농도(㎍/㎥)  18132 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 427.9 KB

# %%
# 측정일시를 datetime 형식으로 변환
fd_2023['측정일시'] = fd_2023['측정일시'].astype('str')
fd_2023.info() # 측정일시가 int에서 object로 바뀐것을 확인
fd_2023['측정일시'] = pd.to_datetime(fd_2023['측정일시'])
fd_2023.info() # 측정일시가 object에서 datetime으로 바뀐것을 확인
fd_2023
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  object
#  1   미세먼지농도(㎍/㎥)   18137 non-null  float64
#  2   초미세먼지농도(㎍/㎥)  18132 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 427.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  datetime64[ns]
#  1   미세먼지농도(㎍/㎥)   18137 non-null  float64
#  2   초미세먼지농도(㎍/㎥)  18132 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 427.9 KB
#             측정일시  미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0     2023-01-01         52.0          36.0
# 1     2023-01-01         56.0          43.0
# 2     2023-01-01         51.0          34.0
# 3     2023-01-01         62.0          38.0
# 4     2023-01-01         54.0          35.0
# ...          ...          ...           ...
# 18245 2023-12-31         25.0          16.0
# 18246 2023-12-31         26.0          20.0
# 18247 2023-12-31         23.0          16.0
# 18248 2023-12-31         19.0          18.0
# 18249 2023-12-31         19.0          15.0
#
# [18250 rows x 3 columns]

# %%
# 일별 평균 계산
fd_2023 = fd_2023.groupby('측정일시').agg({
    '미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2023.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2023.head(), fd_2023.tail())
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2023-01-01    51.80     43.0     62.0       4.27     36.52      29.0
# 2023-01-02    24.82     18.0     34.0       3.37     11.02       5.0
# 2023-01-03    29.78     21.0     37.0       3.76     16.18       9.0
# 2023-01-04    35.42     22.0     48.0       4.70     22.58      15.0
# 2023-01-05    49.32     31.0     66.0       6.08     35.28      24.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2023-01-01      46.0        3.55
# 2023-01-02      15.0        2.40
# 2023-01-03      22.0        3.13
# 2023-01-04      29.0        3.24
# 2023-01-05      44.0        4.73               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2023-12-27    75.62     57.0     92.0       8.27     56.66      43.0
# 2023-12-28    52.18     35.0     87.0       7.62     40.28      27.0
# 2023-12-29    42.40     27.0     49.0       3.74     32.08      20.0
# 2023-12-30    39.18     26.0     50.0       5.89     30.90      19.0
# 2023-12-31    22.50     10.0     30.0       4.18     17.40       8.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2023-12-27      70.0        6.70
# 2023-12-28      67.0        6.11
# 2023-12-29      37.0        3.28
# 2023-12-30      40.0        5.09
# 2023-12-31      23.0        3.30

# %% [markdown]
# ### 2022 미세먼지 농도

# %%
df_2022 = pd.read_csv('./finedust/일별평균대기오염도_2022.csv', encoding='cp949')
print( df_2022.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2022 = df_2022.loc[:, ['측정일시', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)']]
fd_2022.head()
fd_2022.info()

# 측정일시를 datetime 형식으로 변환
fd_2022['측정일시'] = fd_2022['측정일시'].astype('str')
fd_2022.info() # 측정일시가 int에서 object로 바뀐것을 확인
fd_2022['측정일시'] = pd.to_datetime(fd_2022['측정일시'])
fd_2022.info() # 측정일시가 object에서 datetime으로 바뀐것을 확인
fd_2022


# 일별 평균 계산
fd_2022 = fd_2022.groupby('측정일시').agg({
    '미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2022.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2022.head(1), fd_2022.tail(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  int64
#  1   미세먼지농도(㎍/㎥)   18115 non-null  float64
#  2   초미세먼지농도(㎍/㎥)  18122 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 427.9 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  object
#  1   미세먼지농도(㎍/㎥)   18115 non-null  float64
#  2   초미세먼지농도(㎍/㎥)  18122 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 427.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   측정일시          18250 non-null  datetime64[ns]
#  1   미세먼지농도(㎍/㎥)   18115 non-null  float64
#  2   초미세먼지농도(㎍/㎥)  18122 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 427.9 KB
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2022-01-01     27.8     18.0     38.0       4.22     14.38       9.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2022-01-01      20.0        2.32               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2022-12-31    43.18     29.0     51.0        4.2     32.22      18.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2022-12-31      43.0        4.66

# %%
df_2021 = pd.read_csv('./finedust/일별평균대기오염도_2021.csv', encoding='cp949')
print( df_2021.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2021 = df_2021.loc[:, ['측정일시', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2021['측정일시'] = fd_2021['측정일시'].astype('str')
fd_2021['측정일시'] = pd.to_datetime(fd_2021['측정일시'])

# 일별 평균 계산
fd_2021 = fd_2021.groupby('측정일시').agg({
    '미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2021.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2021.head(1), fd_2021.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2021-01-01    25.41     13.0     33.0       4.17      15.9       6.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2021-01-01      23.0        3.01               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2021-12-31     22.9     17.0     33.0       3.48      6.22       3.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2021-12-31      10.0        1.46

# %%
df_2020 = pd.read_csv('./finedust/일별평균대기오염도_2020.csv', encoding='cp949')
print( df_2020.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2020 = df_2020.loc[:, ['측정일시', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2020['측정일시'] = fd_2020['측정일시'].astype('str')
fd_2020['측정일시'] = pd.to_datetime(fd_2020['측정일시'])

# 일별 평균 계산
fd_2020 = fd_2020.groupby('측정일시').agg({
    '미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2020.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2020.head(1), fd_2020.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2020-01-01    34.22     20.0     42.0       4.51     22.68      17.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2020-01-01      30.0        3.26               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2020-12-31    25.58      5.0     35.0       4.98     11.43       3.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2020-12-31      17.0        2.39

# %%
df_2019 = pd.read_csv('./finedust/일별평균대기오염도_2019.csv', encoding='cp949')
print( df_2019.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2019 = df_2019.loc[:, ['측정일시', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2019['측정일시'] = fd_2019['측정일시'].astype('str')
fd_2019['측정일시'] = pd.to_datetime(fd_2019['측정일시'])

# 일별 평균 계산
fd_2019 = fd_2019.groupby('측정일시').agg({
    '미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2019.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2019.head(1), fd_2019.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2019-01-01    37.04     28.0     47.0        4.8     23.89      16.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2019-01-01      30.0         3.7               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2019-12-31    26.62     19.0     59.0       6.06     14.82       8.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2019-12-31      19.0         2.9

# %%
df_2018 = pd.read_csv('./finedust/일별평균대기오염도_2018.csv', encoding='cp949')
print( df_2018.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2018 = df_2018.loc[:, ['측정일시', '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2018['측정일시'] = fd_2018['측정일시'].astype('str')
fd_2018['측정일시'] = pd.to_datetime(fd_2018['측정일시'])

# 일별 평균 계산
fd_2018 = fd_2018.groupby('측정일시').agg({
    '미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지농도(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2018.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2018.head(1), fd_2018.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2018-01-01    44.54     33.0     58.0       6.39     20.24      13.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2018-01-01      28.0        3.14               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2018-12-31     46.5     31.0     62.0       6.67     28.48      17.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2018-12-31      40.0        5.26

# %%
# !pip install openpyxl
import openpyxl

# %%
excel = "./finedust/일별평균대기오염도_2017.xlsx"
df_2017 = pd.read_excel(excel)
print( df_2017.columns )
df_2017
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)'],
#       dtype='object')
#            측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0      20170101   강남구         0.040      0.002           0.8       0.005
# 1      20170101  강남대로         0.082      0.005           1.4       0.007
# 2      20170101   강동구         0.039      0.003           0.8       0.004
# 3      20170101  강변북로         0.042      0.003           0.8       0.004
# 4      20170101   강북구         0.046      0.003           1.0       0.005
# ...         ...   ...           ...        ...           ...         ...
# 14230  20171231  천호대로         0.035      0.014           0.5       0.005
# 14231  20171231  청계천로         0.021      0.020           0.4       0.006
# 14232  20171231  한강대로         0.031      0.017           0.5       0.005
# 14233  20171231   홍릉로         0.031      0.016           0.5       0.007
# 14234  20171231   화랑로         0.025      0.016           0.6       0.004
#
#        미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0           80.0        58.0
# 1           83.0        58.0
# 2           80.0        54.0
# 3           81.0         NaN
# 4           78.0        65.0
# ...          ...         ...
# 14230       71.0        30.0
# 14231       58.0        35.0
# 14232       69.0        25.0
# 14233       63.0        38.0
# 14234       59.0        20.0
#
# [14235 rows x 8 columns]

# %%
# 미세먼지 데이터 프레임 
fd_2017 = df_2017.loc[:, ['측정일시', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2017['측정일시'] = fd_2017['측정일시'].astype('str')
fd_2017['측정일시'] = pd.to_datetime(fd_2017['측정일시'])

# 일별 평균 계산
fd_2017 = fd_2017.groupby('측정일시').agg({
    '미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2017.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2017.head(1), fd_2017.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2017-01-01    80.41     64.0    111.0       9.65     60.09      44.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2017-01-01      88.0       11.03               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2017-12-31    66.08     54.0     87.0       7.59     34.75      20.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2017-12-31      48.0        6.39

# %%
excel = "./finedust/일별평균대기오염도_2016.xlsx"
df_2016 = pd.read_excel(excel)
print( df_2016.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2016 = df_2016.loc[:, ['측정일시', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2016['측정일시'] = fd_2016['측정일시'].astype('str')
fd_2016['측정일시'] = pd.to_datetime(fd_2016['측정일시'])

# 일별 평균 계산
fd_2016 = fd_2016.groupby('측정일시').agg({
    '미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2016.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2016.head(1), fd_2016.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2016-01-01    70.74     54.0     88.0       9.06     44.18      24.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2016-01-01      65.0        7.75               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2016-12-31    60.41     51.0     83.0        7.2     42.22      30.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2016-12-31      66.0        8.15

# %%
excel = "./finedust/일별평균대기오염도_2015.xlsx"
df_2015 = pd.read_excel(excel)
print( df_2015.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2015 = df_2015.loc[:, ['측정일시', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2015['측정일시'] = fd_2015['측정일시'].astype('str')
fd_2015['측정일시'] = pd.to_datetime(fd_2015['측정일시'])

# 일별 평균 계산
fd_2015 = fd_2015.groupby('측정일시').agg({
    '미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2015.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2015.head(1), fd_2015.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2015-01-01     65.2     44.0     80.0       7.45      13.2       7.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2015-01-01      21.0        3.78               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2015-12-31    65.95     49.0     88.0      10.21      42.9      25.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2015-12-31      63.0        8.45

# %%
excel = "./finedust/일별평균대기오염도_2014.xlsx"
df_2014 = pd.read_excel(excel)
print( df_2014.columns )
# Out:
# Index(['측정일시', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)'],
#       dtype='object')

# %%
# 미세먼지 데이터 프레임 
fd_2014 = df_2014.loc[:, ['측정일시', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']]

# 측정일시를 datetime 형식으로 변환
fd_2014['측정일시'] = fd_2014['측정일시'].astype('str')
fd_2014['측정일시'] = pd.to_datetime(fd_2014['측정일시'])

# 일별 평균 계산
fd_2014 = fd_2014.groupby('측정일시').agg({
    '미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std'],
    '초미세먼지(㎍/㎥)': ['mean', 'min', 'max', 'std']
}).round(2)

# 인덱스 이름과 컬럼 이름을 보기 좋게 설정
fd_2014.columns = ['미세먼지_평균', '미세먼지_최소', '미세먼지_최대', '미세먼지_표준편차',
                        '초미세먼지_평균', '초미세먼지_최소', '초미세먼지_최대', '초미세먼지_표준편차']

print(fd_2014.head(1), fd_2014.tail(1))
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2014-01-01   116.75     96.0    142.0       8.14     26.98      21.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2014-01-01      53.0        6.28               미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2014-12-31    39.95     30.0     54.0       5.88     17.25      12.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2014-12-31      25.0        3.37

# %%
total_fd = pd.concat([fd_2014, fd_2015, fd_2016, fd_2017, fd_2018, fd_2019, fd_2020, 
                      fd_2021, fd_2022, fd_2023])
total_fd
# Out:
#             미세먼지_평균  미세먼지_최소  미세먼지_최대  미세먼지_표준편차  초미세먼지_평균  초미세먼지_최소  \
# 측정일시
# 2014-01-01   116.75     96.0    142.0       8.14     26.98      21.0
# 2014-01-02    55.08     43.0     77.0       7.51     21.15      15.0
# 2014-01-03    61.85     52.0     78.0       6.42     28.15      19.0
# 2014-01-04    47.75     39.0     64.0       6.65     22.50      15.0
# 2014-01-05    45.30     36.0     68.0       6.03     23.78      18.0
# ...             ...      ...      ...        ...       ...       ...
# 2023-12-27    75.62     57.0     92.0       8.27     56.66      43.0
# 2023-12-28    52.18     35.0     87.0       7.62     40.28      27.0
# 2023-12-29    42.40     27.0     49.0       3.74     32.08      20.0
# 2023-12-30    39.18     26.0     50.0       5.89     30.90      19.0
# 2023-12-31    22.50     10.0     30.0       4.18     17.40       8.0
#
#             초미세먼지_최대  초미세먼지_표준편차
# 측정일시
# 2014-01-01      53.0        6.28
# 2014-01-02      30.0        4.31
# 2014-01-03      41.0        5.47
# 2014-01-04      36.0        4.53
# 2014-01-05      34.0        4.05
# ...              ...         ...
# 2023-12-27      70.0        6.70
# 2023-12-28      67.0        6.11
# 2023-12-29      37.0        3.28
# 2023-12-30      40.0        5.09
# 2023-12-31      23.0        3.30
#
# [3652 rows x 8 columns]

# %%
total_fd.shape
# total_fd.to_csv('./wt_data/fd_14_23.csv') #- 데이터 프레임을 csv로 저장
total_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3652 entries, 2014-01-01 to 2023-12-31
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   미세먼지_평균     3652 non-null   float64
#  1   미세먼지_최소     3652 non-null   float64
#  2   미세먼지_최대     3652 non-null   float64
#  3   미세먼지_표준편차   3652 non-null   float64
#  4   초미세먼지_평균    3652 non-null   float64
#  5   초미세먼지_최소    3652 non-null   float64
#  6   초미세먼지_최대    3652 non-null   float64
#  7   초미세먼지_표준편차  3652 non-null   float64
# dtypes: float64(8)
# memory usage: 256.8 KB

# %% [markdown]
# ## 2024

# %%
import requests

service_key = "YgC6RL7Xuzrbvz7msHuvRG0JZ+JxR0E6iUI4qrJNk78+5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA=="
# 디코딩 인증키

url = 'http://apis.data.go.kr/B552584/ArpltnStatsSvc/getMsrstnAcctoRDyrg'
params ={'serviceKey' : service_key, 'returnType' : 'JSON', 'numOfRows' : '100000', 'pageNo' : '1', 'inqBginDt' : '20240101', 'inqEndDt' : '20241031'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"totalCount":99311,"items":[{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"\xec\xa7\x80\xec\xa0\x95\xeb\xa9\xb4","pm10Value":"19","no2Value":".005","o3Value":".054","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".2","msrstnName":"\xec\xb0\xbd\xeb\x85\x95\xec\x9d\x8d","pm10Value":"20","no2Value":".016","o3Value":".054","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"\xea\xb3\xb5\xeb\x8b\xa8\xeb\x8f\x99","pm10Value":"18","no2Value":".007","o3Value":".049","pm25Value":"8"},{"msurDt":"2024-06-01","so2Value":".001","coValue":".3","msrstnName":"\xec\x96\x91\xed\x8f\x89\xec\x9d\x8d","pm10Value":"22","no2Value":".006","o3Value":".053","pm25Value":"11"},{"msurDt":"2024-06-01","so2Value":".001","coValue":".4","msrstnName":"\xeb\xb3\xb4\xeb\xa0\xb9\xed\x95\xad","pm10Value":"44","no2Value":".007","o3Value":".053","pm25Value":"23"},{"msurDt":"2024-06-01","so2Value":".001","coValue":".4","msrstnName":"\xec\x8b\xa0\xed\x92\x8d\xeb\x8f\x99","pm10Value":"27","no2Value":".007","o3Value":".051","pm25Value":"12"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"\xea\xb4\x91\xea\xb5\x90\xeb\x8f\x99","pm10Value":"35","no2Value":".008","o3Value":".051","pm25Value":"28"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"\xec\xa7\x80\xec\x82\xb0\xeb\x8f\x99","pm10Value":"20","no2Value":".005","o3Value":".055","pm25Value":"10"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"\xeb\xb0\xb1\xeb\xa7\x88\xeb\xa1\x9c(\xeb\xa7\x88\xeb\x91\x90\xec\x97\xad)","pm10Value":"31","no2Value":".007","o3Value":".043","pm25Value":"15"},{"msurDt":"2024-06-01","so2Value":".004","coValue":".1","msrstnName":"\xeb\x82\xb4\xec\x9d\xbc\xeb\x8f\x99","pm10Value":"23","no2Value":".009","o3Value":".059","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".4","msrstnName":"\xec\x84\xb1\xea\xb1\xb0\xec\x9d\x8d","pm10Value":"34","no2Value":".008","o3Value":".051","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"\xed\x98\x95\xea\xb3\xa1\xeb\x8f\x99","pm10Value":"17","no2Value":".004","o3Value":".057","pm25Value":"7"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"\xec\x95\x88\xec\xa4\x91","pm10Value":"31","no2Value":".004","o3Value":".053","pm25Value":"17"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"\xea\xb5\x90\xeb\xac\xb8\xeb\x8f\x99","pm10Value":"21","no2Value":".003","o3Value":".038","pm25Value":"9"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".3","msrstnName":"\xec\xa3\xbd\xed\x95\xad\xeb\x8f\x99","pm10Value":"24","no2Value":".004","o3Value":".047","pm25Value":"6"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".3","msrstnName":"\xec\x9a\xa9\xec\x82\xb0\xea\xb5\xac","pm10Value":"31","no2Value":".012","o3Value":".043","pm25Value":"15"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"\xec\x8b\xa0\xed\x83\x9c\xec\x9d\xb8","pm10Value":"27","no2Value":".003","o3Value":".053","pm25Value":"13"},{"msurDt":"2024-06-01","so2Value":null,"coValue":null,"msrstnName":"\xed\x99\x94\xeb\xaa\x85\xeb\x8f\x99","pm10Value":"29","no2Value":".01","o3Value":".059","pm25Value":"18"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"\xec\x84\xb1\xec\x84\xb1\xeb\x8f\x99","pm10Value":"27","no2Value":".009","o3Value":".045","pm25Value":"20"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"\xec\x95\x88\xec\x96\x912\xeb\x8f\x99","pm10Value":"30","no2Value":".011","o3Value":".051","pm25Value":null},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"\xec\x82\xb4\xeb\xaf\xb8\xeb\xa9\xb4","pm10Value":"20","no2Value":".007","o3Value":".039","pm25Value":"11"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".3","msrstnName":"\xec\x86\xa1\xeb\xa6\xbc","pm10Value":"19","no2Value":".008","o3Value":".052","pm25Value":"9"},{"msurDt":"2024-06-01","so ...

# %%
# binary 텍스트를 text 포멧으로 변환하는 작업

dedcoded_response_content = response.content.decode('utf-8')
dedcoded_response_content
# Out:
# '{"response":{"body":{"totalCount":99311,"items":[{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"지정면","pm10Value":"19","no2Value":".005","o3Value":".054","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".2","msrstnName":"창녕읍","pm10Value":"20","no2Value":".016","o3Value":".054","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"공단동","pm10Value":"18","no2Value":".007","o3Value":".049","pm25Value":"8"},{"msurDt":"2024-06-01","so2Value":".001","coValue":".3","msrstnName":"양평읍","pm10Value":"22","no2Value":".006","o3Value":".053","pm25Value":"11"},{"msurDt":"2024-06-01","so2Value":".001","coValue":".4","msrstnName":"보령항","pm10Value":"44","no2Value":".007","o3Value":".053","pm25Value":"23"},{"msurDt":"2024-06-01","so2Value":".001","coValue":".4","msrstnName":"신풍동","pm10Value":"27","no2Value":".007","o3Value":".051","pm25Value":"12"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"광교동","pm10Value":"35","no2Value":".008","o3Value":".051","pm25Value":"28"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"지산동","pm10Value":"20","no2Value":".005","o3Value":".055","pm25Value":"10"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"백마로(마두역)","pm10Value":"31","no2Value":".007","o3Value":".043","pm25Value":"15"},{"msurDt":"2024-06-01","so2Value":".004","coValue":".1","msrstnName":"내일동","pm10Value":"23","no2Value":".009","o3Value":".059","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".4","msrstnName":"성거읍","pm10Value":"34","no2Value":".008","o3Value":".051","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"형곡동","pm10Value":"17","no2Value":".004","o3Value":".057","pm25Value":"7"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"안중","pm10Value":"31","no2Value":".004","o3Value":".053","pm25Value":"17"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"교문동","pm10Value":"21","no2Value":".003","o3Value":".038","pm25Value":"9"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".3","msrstnName":"죽항동","pm10Value":"24","no2Value":".004","o3Value":".047","pm25Value":"6"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".3","msrstnName":"용산구","pm10Value":"31","no2Value":".012","o3Value":".043","pm25Value":"15"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".2","msrstnName":"신태인","pm10Value":"27","no2Value":".003","o3Value":".053","pm25Value":"13"},{"msurDt":"2024-06-01","so2Value":null,"coValue":null,"msrstnName":"화명동","pm10Value":"29","no2Value":".01","o3Value":".059","pm25Value":"18"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"성성동","pm10Value":"27","no2Value":".009","o3Value":".045","pm25Value":"20"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"안양2동","pm10Value":"30","no2Value":".011","o3Value":".051","pm25Value":null},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"살미면","pm10Value":"20","no2Value":".007","o3Value":".039","pm25Value":"11"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".3","msrstnName":"송림","pm10Value":"19","no2Value":".008","o3Value":".052","pm25Value":"9"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".3","msrstnName":"여수항","pm10Value":"21","no2Value":".006","o3Value":".057","pm25Value":"12"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".4","msrstnName":"우동","pm10Value":"28","no2Value":".014","o3Value":".057","pm25Value":"19"},{"msurDt":"2024-06-01","so2Value":".002","coValue":".4","msrstnName":"양덕동","pm10Value":"26","no2Value":".003","o3Value":".056","pm25Value":"19"},{"msurDt":"2024-06-01","so2Value":".003","coValue":".3","msrstnName":"진량읍","pm10Value":"25","no2Value":".012","o3Value":".044","pm25Value":"18"},{"msurDt":"2024-06-01","so2Value":".004","coValue":".3","msrstnName":"성건동","pm10Value":"30","no2Value":".01","o3Value":".054","pm25Value":"14"},{"msurDt":"2024-06-01","so2Value":".001", ...

# %%
import json

# json string -> dict 변환
dict_content = json.loads(dedcoded_response_content)
dict_content
# Out:
# {'response': {'body': {'totalCount': 99311,
#    'items': [{'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '지정면',
#      'pm10Value': '19',
#      'no2Value': '.005',
#      'o3Value': '.054',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '창녕읍',
#      'pm10Value': '20',
#      'no2Value': '.016',
#      'o3Value': '.054',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '공단동',
#      'pm10Value': '18',
#      'no2Value': '.007',
#      'o3Value': '.049',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '양평읍',
#      'pm10Value': '22',
#      'no2Value': '.006',
#      'o3Value': '.053',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '보령항',
#      'pm10Value': '44',
#      'no2Value': '.007',
#      'o3Value': '.053',
#      'pm25Value': '23'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '신풍동',
#      'pm10Value': '27',
#      'no2Value': '.007',
#      'o3Value': '.051',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '광교동',
#      'pm10Value': '35',
#      'no2Value': '.008',
#      'o3Value': '.051',
#      'pm25Value': '28'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '지산동',
#      'pm10Value': '20',
#      'no2Value': '.005',
#      'o3Value': '.055',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '백마로(마두역)',
#      'pm10Value': '31',
#      'no2Value': '.007',
#      'o3Value': '.043',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.1',
#      'msrstnName': '내일동',
#      'pm10Value': '23',
#      'no2Value': '.009',
#      'o3Value': '.059',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '성거읍',
#      'pm10Value': '34',
#      'no2Value': '.008',
#      'o3Value': '.051',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '형곡동',
#      'pm10Value': '17',
#      'no2Value': '.004',
#      'o3Value': '.057',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '안중',
#      'pm10Value': '31',
#      'no2Value': '.004',
#      'o3Value': '.053',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '교문동',
#      'pm10Value': '21',
#      'no2Value': '.003',
#      'o3Value': '.038',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '죽항동',
#      'pm10Value': '24',
#      'no2Value': '.004',
#      'o3Value': '.047',
#      'pm25Value': '6'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '용산구',
#      'pm10Value': '31',
#      'no2Value': '.012',
#      'o3Value': '.043',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '신태인',
#      'pm10Value': '27',
#      'no2Value': '.003',
#      'o3Value': '.053',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': None,
#      'coValue': None,
#      'msrstnName': '화명동',
#      'pm10Value': '29',
#      'no2Value': '.01',
#      'o3Value': '.059',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '성성동',
#      'pm10Value': '27',
#      'no2Value': '.009',
#      'o3Value': '.045',
#      'pm25Value': '20'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '안양2동',
#      'pm10Value': '30',
#      'no2Value': '.011',
#      'o3Value': '.051',
#      'pm25Value': None},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '살미면',
#      'pm10Value': '20',
#      'no2Value': '.007',
#      'o3Value': '.039',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '송림',
#      'pm10Value': '19',
#      'no2Value': '.008',
#      'o3Value': '.052',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '여수항',
#      'pm10Value': '21',
#      'no2Value': '.006',
#      'o3Value': '.057',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '우동',
#      'pm10Value': '28',
#      'no2Value': '.014',
#      'o3Value': '.057',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '양덕동',
#      'pm10Value': '26',
#      'no2Value': '.003',
#      'o3Value': '.056',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '진량읍',
#      'pm10Value': '25',
#      'no2Value': '.012',
#      'o3Value': '.044',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '성건동',
#      'pm10Value': '30',
#      'no2Value': '.01',
#      'o3Value': '.054',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '설악면',
#      'pm10Value': '23',
#      'no2Value': '.006',
#      'o3Value': '.089',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '거창읍',
#      'pm10Value': '15',
#      'no2Value': '.007',
#      'o3Value': '.048',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '옥산면',
#      'pm10Value': '32',
#      'no2Value': '.004',
#      'o3Value': '.058',
#      'pm25Value': '20'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '의정부동',
#      'pm10Value': '28',
#      'no2Value': '.004',
#      'o3Value': '.047',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '상대동(진주)',
#      'pm10Value': '23',
#      'no2Value': '.014',
#      'o3Value': '.046',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '인천 북항',
#      'pm10Value': '25',
#      'no2Value': '.007',
#      'o3Value': '.036',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '호매실',
#      'pm10Value': '27',
#      'no2Value': '.005',
#      'o3Value': '.042',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '성황동',
#      'pm10Value': '28',
#      'no2Value': '.01',
#      'o3Value': '.05',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '수정동',
#      'pm10Value': '23',
#      'no2Value': '.011',
#      'o3Value': '.059',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '종로구',
#      'pm10Value': '27',
#      'no2Value': '.008',
#      'o3Value': '.049',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '사곡면',
#      'pm10Value': '26',
#      'no2Value': '.005',
#      'o3Value': '.051',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '율곡동',
#      'pm10Value': '25',
#      'no2Value': '.008',
#      'o3Value': '.055',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '약사동',
#      'pm10Value': '22',
#      'no2Value': '.009',
#      'o3Value': '.051',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '본동',
#      'pm10Value': '22',
#      'no2Value': '.006',
#      'o3Value': '.052',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '남산1동',
#      'pm10Value': '21',
#      'no2Value': '.005',
#      'o3Value': '.052',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '옥천동',
#      'pm10Value': '20',
#      'no2Value': '.007',
#      'o3Value': '.038',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '중앙대로(고잔동)',
#      'pm10Value': '28',
#      'no2Value': '.011',
#      'o3Value': None,
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '양천구',
#      'pm10Value': '27',
#      'no2Value': '.01',
#      'o3Value': '.052',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '연동',
#      'pm10Value': '25',
#      'no2Value': '.007',
#      'o3Value': '.047',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '영암읍',
#      'pm10Value': '30',
#      'no2Value': '.004',
#      'o3Value': '.041',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '애월읍',
#      'pm10Value': '20',
#      'no2Value': '.004',
#      'o3Value': '.049',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '청천면',
#      'pm10Value': '23',
#      'no2Value': '.004',
#      'o3Value': '.052',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.1',
#      'msrstnName': '인천항',
#      'pm10Value': '36',
#      'no2Value': '.007',
#      'o3Value': '.049',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '복정동',
#      'pm10Value': '26',
#      'no2Value': '.008',
#      'o3Value': '.052',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '백암면',
#      'pm10Value': '26',
#      'no2Value': '.003',
#      'o3Value': '.051',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '성산읍',
#      'pm10Value': '20',
#      'no2Value': '.005',
#      'o3Value': '.05',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '광양 중마',
#      'pm10Value': '18',
#      'no2Value': '.004',
#      'o3Value': '.052',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '예천군',
#      'pm10Value': '18',
#      'no2Value': '.004',
#      'o3Value': '.058',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '광복동',
#      'pm10Value': '23',
#      'no2Value': '.011',
#      'o3Value': '.058',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.1',
#      'msrstnName': '우천면',
#      'pm10Value': '22',
#      'no2Value': '.03',
#      'o3Value': '.015',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '진월면',
#      'pm10Value': '17',
#      'no2Value': '.009',
#      'o3Value': '.042',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.2',
#      'msrstnName': '안성면',
#      'pm10Value': '17',
#      'no2Value': '.004',
#      'o3Value': '.049',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '영통동',
#      'pm10Value': '29',
#      'no2Value': '.007',
#      'o3Value': '.054',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '진천동',
#      'pm10Value': '21',
#      'no2Value': '.008',
#      'o3Value': '.055',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '우정읍',
#      'pm10Value': '33',
#      'no2Value': '.004',
#      'o3Value': '.05',
#      'pm25Value': '22'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '고천동',
#      'pm10Value': '25',
#      'no2Value': '.007',
#      'o3Value': '.048',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '단양읍',
#      'pm10Value': '19',
#      'no2Value': '.007',
#      'o3Value': '.051',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.6',
#      'msrstnName': '중앙탑면',
#      'pm10Value': '22',
#      'no2Value': '.008',
#      'o3Value': '.049',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.1',
#      'msrstnName': '고덕동',
#      'pm10Value': '28',
#      'no2Value': '.003',
#      'o3Value': '.053',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '사우동',
#      'pm10Value': '27',
#      'no2Value': '.003',
#      'o3Value': '.051',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '가거도',
#      'pm10Value': '25',
#      'no2Value': '.003',
#      'o3Value': '.06',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '평리동',
#      'pm10Value': '21',
#      'no2Value': '.01',
#      'o3Value': '.053',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '혁신동',
#      'pm10Value': '27',
#      'no2Value': '.004',
#      'o3Value': '.054',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.2',
#      'msrstnName': '회원동',
#      'pm10Value': '22',
#      'no2Value': '.011',
#      'o3Value': '.059',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '엄사면',
#      'pm10Value': '25',
#      'no2Value': '.005',
#      'o3Value': '.028',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '송파구',
#      'pm10Value': '29',
#      'no2Value': '.01',
#      'o3Value': '.048',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '간성읍',
#      'pm10Value': '12',
#      'no2Value': '.003',
#      'o3Value': '.049',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '성주동',
#      'pm10Value': '20',
#      'no2Value': '.016',
#      'o3Value': '.061',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '인제(DMZ)',
#      'pm10Value': '14',
#      'no2Value': '.004',
#      'o3Value': '.035',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '부평역',
#      'pm10Value': '42',
#      'no2Value': '.014',
#      'o3Value': '.042',
#      'pm25Value': '20'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '전하동',
#      'pm10Value': '29',
#      'no2Value': '.011',
#      'o3Value': '.058',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '침산동',
#      'pm10Value': '21',
#      'no2Value': '.007',
#      'o3Value': '.051',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '신흥',
#      'pm10Value': '27',
#      'no2Value': '.007',
#      'o3Value': '.049',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '금왕',
#      'pm10Value': '28',
#      'no2Value': '.006',
#      'o3Value': '.052',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '와부읍',
#      'pm10Value': '25',
#      'no2Value': '.007',
#      'o3Value': '.045',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '우산동(광주)',
#      'pm10Value': '18',
#      'no2Value': '.009',
#      'o3Value': '.048',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.5',
#      'msrstnName': '공도읍',
#      'pm10Value': '29',
#      'no2Value': '.006',
#      'o3Value': '.053',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '양양읍',
#      'pm10Value': '10',
#      'no2Value': '.003',
#      'o3Value': '.031',
#      'pm25Value': '6'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '향촌동',
#      'pm10Value': '15',
#      'no2Value': '.008',
#      'o3Value': '.049',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '신흥동',
#      'pm10Value': '20',
#      'no2Value': '.007',
#      'o3Value': '.022',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.2',
#      'msrstnName': '초당동',
#      'pm10Value': '16',
#      'no2Value': '.004',
#      'o3Value': '.035',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.5',
#      'msrstnName': '장흥동',
#      'pm10Value': '31',
#      'no2Value': '.01',
#      'o3Value': '.051',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '읍내동',
#      'pm10Value': '23',
#      'no2Value': '.005',
#      'o3Value': '.046',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '관촌면',
#      'pm10Value': '19',
#      'no2Value': '.007',
#      'o3Value': '.047',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '용지동',
#      'pm10Value': '22',
#      'no2Value': '.01',
#      'o3Value': '.059',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '저구리',
#      'pm10Value': '11',
#      'no2Value': '.007',
#      'o3Value': '.049',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '마포구',
#      'pm10Value': '28',
#      'no2Value': '.011',
#      'o3Value': '.05',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '청라',
#      'pm10Value': '27',
#      'no2Value': '.009',
#      'o3Value': '.054',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '구로구',
#      'pm10Value': '33',
#      'no2Value': '.007',
#      'o3Value': '.054',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '북평면',
#      'pm10Value': '13',
#      'no2Value': '.006',
#      'o3Value': '.043',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.5',
#      'msrstnName': '서호동',
#      'pm10Value': '18',
#      'no2Value': '.007',
#      'o3Value': '.059',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '금산읍',
#      'pm10Value': '18',
#      'no2Value': '.007',
#      'o3Value': '.051',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '장락동',
#      'pm10Value': '21',
#      'no2Value': '.005',
#      'o3Value': '.059',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.2',
#      'msrstnName': '신대',
#      'pm10Value': '10',
#      'no2Value': '.004',
#      'o3Value': '.06',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '명서동',
#      'pm10Value': '24',
#      'no2Value': '.014',
#      'o3Value': '.054',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.2',
#      'msrstnName': '태안항',
#      'pm10Value': '53',
#      'no2Value': '.005',
#      'o3Value': '.054',
#      'pm25Value': '36'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '내포',
#      'pm10Value': '21',
#      'no2Value': '.004',
#      'o3Value': '.056',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '월영동',
#      'pm10Value': '15',
#      'no2Value': '.018',
#      'o3Value': '.058',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '호암동',
#      'pm10Value': '17',
#      'no2Value': '.006',
#      'o3Value': '.056',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.5',
#      'msrstnName': '명륜동',
#      'pm10Value': '23',
#      'no2Value': '.006',
#      'o3Value': '.05',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '새만금',
#      'pm10Value': '23',
#      'no2Value': '.004',
#      'o3Value': '.055',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '원평동',
#      'pm10Value': '16',
#      'no2Value': '.01',
#      'o3Value': '.054',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '보은읍',
#      'pm10Value': '21',
#      'no2Value': '.005',
#      'o3Value': '.05',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '장흥읍',
#      'pm10Value': '17',
#      'no2Value': '.004',
#      'o3Value': '.035',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '울도',
#      'pm10Value': '27',
#      'no2Value': '.003',
#      'o3Value': '.047',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '부여읍',
#      'pm10Value': '21',
#      'no2Value': '.006',
#      'o3Value': '.033',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '상남리',
#      'pm10Value': '31',
#      'no2Value': '.016',
#      'o3Value': '.046',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '송악면',
#      'pm10Value': '21',
#      'no2Value': '.005',
#      'o3Value': '.056',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '노대동',
#      'pm10Value': '16',
#      'no2Value': '.004',
#      'o3Value': '.048',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '북부동',
#      'pm10Value': '27',
#      'no2Value': '.02',
#      'o3Value': '.051',
#      'pm25Value': '20'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '파주',
#      'pm10Value': '35',
#      'no2Value': '.004',
#      'o3Value': '.042',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '정선읍',
#      'pm10Value': '13',
#      'no2Value': '.006',
#      'o3Value': '.048',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '음성읍',
#      'pm10Value': '21',
#      'no2Value': '.006',
#      'o3Value': '.055',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '파주읍',
#      'pm10Value': '24',
#      'no2Value': '.002',
#      'o3Value': '.046',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.2',
#      'msrstnName': '장계면',
#      'pm10Value': '17',
#      'no2Value': '.005',
#      'o3Value': '.049',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '서신면',
#      'pm10Value': '31',
#      'no2Value': '.004',
#      'o3Value': '.054',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '덕산읍',
#      'pm10Value': '27',
#      'no2Value': '.004',
#      'o3Value': '.052',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '오창읍',
#      'pm10Value': '25',
#      'no2Value': '.009',
#      'o3Value': '.045',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '주안',
#      'pm10Value': '25',
#      'no2Value': '.009',
#      'o3Value': '.049',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '용담동',
#      'pm10Value': '24',
#      'no2Value': '.006',
#      'o3Value': '.056',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '수내동',
#      'pm10Value': '25',
#      'no2Value': '.009',
#      'o3Value': '.047',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '치평동',
#      'pm10Value': '21',
#      'no2Value': '.008',
#      'o3Value': '.044',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '서초구',
#      'pm10Value': '32',
#      'no2Value': '.008',
#      'o3Value': '.051',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '향남읍',
#      'pm10Value': '35',
#      'no2Value': '.005',
#      'o3Value': '.051',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.2',
#      'msrstnName': '안양8동',
#      'pm10Value': '29',
#      'no2Value': '.005',
#      'o3Value': '.051',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.1',
#      'msrstnName': '영양군',
#      'pm10Value': '13',
#      'no2Value': '.004',
#      'o3Value': '.042',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '중방동',
#      'pm10Value': '26',
#      'no2Value': '.006',
#      'o3Value': '.051',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '반곡동(명륜동)',
#      'pm10Value': '21',
#      'no2Value': '.007',
#      'o3Value': '.056',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '성동면',
#      'pm10Value': '20',
#      'no2Value': '.005',
#      'o3Value': '.013',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '전곡',
#      'pm10Value': '20',
#      'no2Value': '.003',
#      'o3Value': '.042',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '영덕읍',
#      'pm10Value': '21',
#      'no2Value': '.003',
#      'o3Value': '.054',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '관평동',
#      'pm10Value': '20',
#      'no2Value': '.004',
#      'o3Value': '.051',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '치악산',
#      'pm10Value': '23',
#      'no2Value': '.008',
#      'o3Value': '.043',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '운서',
#      'pm10Value': '27',
#      'no2Value': '.004',
#      'o3Value': '.053',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '홍릉로',
#      'pm10Value': '30',
#      'no2Value': '.016',
#      'o3Value': '.042',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '청계천로',
#      'pm10Value': '33',
#      'no2Value': '.012',
#      'o3Value': '.043',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.5',
#      'msrstnName': '부흥동',
#      'pm10Value': None,
#      'no2Value': '.003',
#      'o3Value': '.058',
#      'pm25Value': None},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '안강읍',
#      'pm10Value': '20',
#      'no2Value': '.006',
#      'o3Value': '.052',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '삼진로',
#      'pm10Value': '19',
#      'no2Value': '.009',
#      'o3Value': '.051',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '경수대로(동수원)',
#      'pm10Value': '29',
#      'no2Value': '.013',
#      'o3Value': '.037',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '화양읍',
#      'pm10Value': '22',
#      'no2Value': '.007',
#      'o3Value': '.049',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '좌동',
#      'pm10Value': '32',
#      'no2Value': '.006',
#      'o3Value': '.055',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '일곡동',
#      'pm10Value': '15',
#      'no2Value': '.007',
#      'o3Value': '.048',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '미사',
#      'pm10Value': '27',
#      'no2Value': '.009',
#      'o3Value': '.048',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '부림동',
#      'pm10Value': '36',
#      'no2Value': '.008',
#      'o3Value': '.053',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-01',
#      'so2Value': None,
#      'coValue': None,
#      'msrstnName': '용암동',
#      'pm10Value': None,
#      'no2Value': None,
#      'o3Value': None,
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '온의동',
#      'pm10Value': '18',
#      'no2Value': '.011',
#      'o3Value': '.044',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '화도읍',
#      'pm10Value': '25',
#      'no2Value': '.006',
#      'o3Value': '.042',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '합덕읍',
#      'pm10Value': '30',
#      'no2Value': '.005',
#      'o3Value': '.059',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '영주동',
#      'pm10Value': '28',
#      'no2Value': '.006',
#      'o3Value': '.051',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.008',
#      'coValue': '.3',
#      'msrstnName': '용호동',
#      'pm10Value': '26',
#      'no2Value': '.012',
#      'o3Value': '.053',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '영등포구',
#      'pm10Value': '25',
#      'no2Value': '.009',
#      'o3Value': '.054',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.005',
#      'coValue': '.3',
#      'msrstnName': '진천읍',
#      'pm10Value': '26',
#      'no2Value': '.006',
#      'o3Value': '.054',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '봉동읍',
#      'pm10Value': '27',
#      'no2Value': '.006',
#      'o3Value': '.051',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '주문진읍',
#      'pm10Value': '18',
#      'no2Value': '.004',
#      'o3Value': '.03',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.2',
#      'msrstnName': '장수읍',
#      'pm10Value': '21',
#      'no2Value': '.004',
#      'o3Value': '.049',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '순창읍',
#      'pm10Value': '21',
#      'no2Value': '.003',
#      'o3Value': '.048',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '덕적도',
#      'pm10Value': '24',
#      'no2Value': '.003',
#      'o3Value': '.048',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '금호동',
#      'pm10Value': '20',
#      'no2Value': '.004',
#      'o3Value': '.033',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '대신면',
#      'pm10Value': '32',
#      'no2Value': '.006',
#      'o3Value': '.051',
#      'pm25Value': '21'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '삼남읍',
#      'pm10Value': '31',
#      'no2Value': '.008',
#      'o3Value': '.057',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '신방동',
#      'pm10Value': '38',
#      'no2Value': '.007',
#      'o3Value': '.052',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '수창동',
#      'pm10Value': '18',
#      'no2Value': '.007',
#      'o3Value': '.058',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '성주군',
#      'pm10Value': '22',
#      'no2Value': '.009',
#      'o3Value': '.049',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '용동면',
#      'pm10Value': '34',
#      'no2Value': '.003',
#      'o3Value': '.049',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '파도리',
#      'pm10Value': '36',
#      'no2Value': '.007',
#      'o3Value': '.055',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.005',
#      'coValue': '.2',
#      'msrstnName': '서해안로',
#      'pm10Value': '31',
#      'no2Value': '.01',
#      'o3Value': '.052',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '상리',
#      'pm10Value': '11',
#      'no2Value': '.003',
#      'o3Value': '.036',
#      'pm25Value': '4'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '태전동',
#      'pm10Value': '17',
#      'no2Value': '.007',
#      'o3Value': '.056',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '논산',
#      'pm10Value': '25',
#      'no2Value': '.011',
#      'o3Value': '.023',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '북부순환도로',
#      'pm10Value': '28',
#      'no2Value': '.014',
#      'o3Value': '.045',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '우현동',
#      'pm10Value': '26',
#      'no2Value': '.013',
#      'o3Value': '.052',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '가흥동',
#      'pm10Value': '25',
#      'no2Value': '.007',
#      'o3Value': '.053',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '유가읍',
#      'pm10Value': '19',
#      'no2Value': '.007',
#      'o3Value': '.055',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '옥천읍',
#      'pm10Value': '15',
#      'no2Value': '.009',
#      'o3Value': '.054',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.023',
#      'coValue': '.5',
#      'msrstnName': '월내동',
#      'pm10Value': '18',
#      'no2Value': '.011',
#      'o3Value': '.048',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '공주',
#      'pm10Value': '23',
#      'no2Value': '.003',
#      'o3Value': '.058',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '강변북로',
#      'pm10Value': '32',
#      'no2Value': '.022',
#      'o3Value': '.034',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '한솔동',
#      'pm10Value': '19',
#      'no2Value': '.006',
#      'o3Value': '.045',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '개금동',
#      'pm10Value': '30',
#      'no2Value': '.014',
#      'o3Value': '.058',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '성북구',
#      'pm10Value': '28',
#      'no2Value': '.007',
#      'o3Value': '.046',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '도고면',
#      'pm10Value': '28',
#      'no2Value': '.004',
#      'o3Value': '.054',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '가덕면',
#      'pm10Value': '20',
#      'no2Value': '.006',
#      'o3Value': '.05',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '둔산동',
#      'pm10Value': '22',
#      'no2Value': '.008',
#      'o3Value': '.052',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '증평읍',
#      'pm10Value': '18',
#      'no2Value': '.005',
#      'o3Value': '.05',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': None,
#      'coValue': None,
#      'msrstnName': '광안동',
#      'pm10Value': '34',
#      'no2Value': '.007',
#      'o3Value': '.062',
#      'pm25Value': '20'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '김해대로',
#      'pm10Value': '26',
#      'no2Value': '.018',
#      'o3Value': '.055',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '대부동',
#      'pm10Value': '42',
#      'no2Value': '.004',
#      'o3Value': '.049',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '기장읍',
#      'pm10Value': '27',
#      'no2Value': '.004',
#      'o3Value': '.059',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '영천시',
#      'pm10Value': '18',
#      'no2Value': '.004',
#      'o3Value': '.055',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '상주시',
#      'pm10Value': '20',
#      'no2Value': '.003',
#      'o3Value': '.062',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '아암',
#      'pm10Value': '23',
#      'no2Value': '.007',
#      'o3Value': '.049',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '사정동',
#      'pm10Value': '28',
#      'no2Value': '.006',
#      'o3Value': '.057',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.4',
#      'msrstnName': '인주면',
#      'pm10Value': '29',
#      'no2Value': '.006',
#      'o3Value': '.048',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.1',
#      'msrstnName': '송북동',
#      'pm10Value': '38',
#      'no2Value': '.004',
#      'o3Value': '.053',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '월곶면',
#      'pm10Value': '22',
#      'no2Value': '.003',
#      'o3Value': '.046',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '오포1동',
#      'pm10Value': '24',
#      'no2Value': '.006',
#      'o3Value': '.051',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '공항대로',
#      'pm10Value': '30',
#      'no2Value': '.013',
#      'o3Value': '.048',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '강구면',
#      'pm10Value': '19',
#      'no2Value': '.004',
#      'o3Value': '.06',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '논현',
#      'pm10Value': '30',
#      'no2Value': '.009',
#      'o3Value': '.046',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '시지동',
#      'pm10Value': '20',
#      'no2Value': '.008',
#      'o3Value': '.054',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.2',
#      'msrstnName': '괴산읍',
#      'pm10Value': '24',
#      'no2Value': '.005',
#      'o3Value': '.052',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '강북구',
#      'pm10Value': '21',
#      'no2Value': '.005',
#      'o3Value': '.054',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '새솔동',
#      'pm10Value': '27',
#      'no2Value': '.006',
#      'o3Value': '.063',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '숭의',
#      'pm10Value': '27',
#      'no2Value': '.009',
#      'o3Value': '.051',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '모현읍',
#      'pm10Value': '28',
#      'no2Value': '.006',
#      'o3Value': '.047',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '구성동',
#      'pm10Value': '21',
#      'no2Value': '.005',
#      'o3Value': '.052',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '합천읍',
#      'pm10Value': '11',
#      'no2Value': '.006',
#      'o3Value': '.052',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '대도동',
#      'pm10Value': '39',
#      'no2Value': '.007',
#      'o3Value': '.056',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '금촌동',
#      'pm10Value': '36',
#      'no2Value': '.005',
#      'o3Value': '.049',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '장유동',
#      'pm10Value': '21',
#      'no2Value': '.011',
#      'o3Value': '.055',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '대천2동',
#      'pm10Value': '24',
#      'no2Value': '.004',
#      'o3Value': '.052',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '남상면',
#      'pm10Value': '14',
#      'no2Value': '.006',
#      'o3Value': '.051',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '동상동',
#      'pm10Value': '21',
#      'no2Value': '.01',
#      'o3Value': '.062',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '이도동',
#      'pm10Value': '23',
#      'no2Value': '.008',
#      'o3Value': '.048',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '부산항',
#      'pm10Value': '39',
#      'no2Value': '.033',
#      'o3Value': '.038',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '인계동',
#      'pm10Value': '26',
#      'no2Value': '.008',
#      'o3Value': '.049',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '청학동',
#      'pm10Value': '22',
#      'no2Value': '.01',
#      'o3Value': '.06',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '황지동',
#      'pm10Value': '17',
#      'no2Value': '.006',
#      'o3Value': '.048',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '팔봉동',
#      'pm10Value': '30',
#      'no2Value': '.003',
#      'o3Value': '.062',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '가평',
#      'pm10Value': '18',
#      'no2Value': '.005',
#      'o3Value': '.049',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '이현동',
#      'pm10Value': '24',
#      'no2Value': '.009',
#      'o3Value': '.056',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '함양읍',
#      'pm10Value': '15',
#      'no2Value': '.004',
#      'o3Value': '.055',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '평택당진항',
#      'pm10Value': '31',
#      'no2Value': '.009',
#      'o3Value': '.052',
#      'pm25Value': '28'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '고산면',
#      'pm10Value': '23',
#      'no2Value': '.004',
#      'o3Value': '.049',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '부안읍',
#      'pm10Value': '26',
#      'no2Value': '.005',
#      'o3Value': '.056',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '서면',
#      'pm10Value': '20',
#      'no2Value': '.008',
#      'o3Value': '.03',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.5',
#      'msrstnName': '산업로',
#      'pm10Value': '31',
#      'no2Value': '.017',
#      'o3Value': '.041',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '부산감만',
#      'pm10Value': '33',
#      'no2Value': '.024',
#      'o3Value': '.047',
#      'pm25Value': '6'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '아주동',
#      'pm10Value': '14',
#      'no2Value': '.006',
#      'o3Value': '.058',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '시화산단',
#      'pm10Value': '34',
#      'no2Value': '.007',
#      'o3Value': '.048',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '초량동',
#      'pm10Value': '29',
#      'no2Value': '.018',
#      'o3Value': '.05',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-01',
#      'so2Value': '.004',
#      'coValue': '.2',
#      'msrstnName': '장성읍',
#      'pm10Value': '21',
#      'no2Value': '.006',
#      'o3Value': '.048',
# ...
#      'pm10Value': '12',
#      'no2Value': '.006',
#      'o3Value': '.035',
#      'pm25Value': '7'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '고촌읍',
#      'pm10Value': '22',
#      'no2Value': '.004',
#      'o3Value': '.053',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '보성읍',
#      'pm10Value': '21',
#      'no2Value': '.003',
#      'o3Value': '.042',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '대흥동1',
#      'pm10Value': '26',
#      'no2Value': '.011',
#      'o3Value': '.045',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '강남대로',
#      'pm10Value': '37',
#      'no2Value': '.017',
#      'o3Value': '.035',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '증평읍',
#      'pm10Value': '18',
#      'no2Value': '.005',
#      'o3Value': '.047',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': None,
#      'coValue': None,
#      'msrstnName': '말도',
#      'pm10Value': '19',
#      'no2Value': None,
#      'o3Value': None,
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '가덕면',
#      'pm10Value': '19',
#      'no2Value': '.006',
#      'o3Value': '.046',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '목감동',
#      'pm10Value': '26',
#      'no2Value': '.017',
#      'o3Value': '.041',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '서초구',
#      'pm10Value': '24',
#      'no2Value': '.006',
#      'o3Value': '.057',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '중2동',
#      'pm10Value': '21',
#      'no2Value': '.007',
#      'o3Value': '.055',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '서강동',
#      'pm10Value': '23',
#      'no2Value': '.009',
#      'o3Value': '.053',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '운암면',
#      'pm10Value': '21',
#      'no2Value': '.003',
#      'o3Value': '.05',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '영종',
#      'pm10Value': '28',
#      'no2Value': '.005',
#      'o3Value': '.053',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '부평',
#      'pm10Value': '21',
#      'no2Value': '.01',
#      'o3Value': '.057',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '여수항',
#      'pm10Value': '28',
#      'no2Value': '.011',
#      'o3Value': '.058',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '강동구',
#      'pm10Value': '15',
#      'no2Value': '.008',
#      'o3Value': '.055',
#      'pm25Value': '3'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '저구리',
#      'pm10Value': '15',
#      'no2Value': '.005',
#      'o3Value': '.052',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.4',
#      'msrstnName': '새솔동',
#      'pm10Value': '21',
#      'no2Value': '.007',
#      'o3Value': '.064',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '삼락동',
#      'pm10Value': '26',
#      'no2Value': '.009',
#      'o3Value': '.047',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.1',
#      'msrstnName': '송북동',
#      'pm10Value': '28',
#      'no2Value': '.005',
#      'o3Value': '.057',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '공주',
#      'pm10Value': '20',
#      'no2Value': '.003',
#      'o3Value': '.06',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '백령도',
#      'pm10Value': '23',
#      'no2Value': '.002',
#      'o3Value': '.069',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '오천읍',
#      'pm10Value': '25',
#      'no2Value': '.007',
#      'o3Value': '.043',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '조천읍',
#      'pm10Value': '23',
#      'no2Value': '.006',
#      'o3Value': '.06',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '광활면',
#      'pm10Value': '30',
#      'no2Value': '.006',
#      'o3Value': '.058',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '신흥',
#      'pm10Value': '23',
#      'no2Value': '.008',
#      'o3Value': '.06',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '월곶면',
#      'pm10Value': '20',
#      'no2Value': '.004',
#      'o3Value': '.053',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '정자동',
#      'pm10Value': '21',
#      'no2Value': '.008',
#      'o3Value': '.05',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.2',
#      'msrstnName': '괴산읍',
#      'pm10Value': '23',
#      'no2Value': '.005',
#      'o3Value': '.049',
#      'pm25Value': '17'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '야음동',
#      'pm10Value': '24',
#      'no2Value': '.004',
#      'o3Value': '.034',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '중앙동(경기)',
#      'pm10Value': '23',
#      'no2Value': '.005',
#      'o3Value': '.04',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '신풍동(군산)',
#      'pm10Value': '25',
#      'no2Value': '.007',
#      'o3Value': '.06',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '고산면',
#      'pm10Value': '24',
#      'no2Value': '.005',
#      'o3Value': '.048',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '소룡동2',
#      'pm10Value': '27',
#      'no2Value': '.008',
#      'o3Value': '.059',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '4공단',
#      'pm10Value': '16',
#      'no2Value': '.006',
#      'o3Value': '.047',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '화산리',
#      'pm10Value': '26',
#      'no2Value': '.011',
#      'o3Value': '.038',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '남원읍',
#      'pm10Value': '22',
#      'no2Value': '.004',
#      'o3Value': '.06',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '영월읍',
#      'pm10Value': '15',
#      'no2Value': '.006',
#      'o3Value': '.029',
#      'pm25Value': '4'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.006',
#      'coValue': '.5',
#      'msrstnName': '월내동',
#      'pm10Value': '23',
#      'no2Value': '.013',
#      'o3Value': '.051',
#      'pm25Value': '15'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '모현동',
#      'pm10Value': '35',
#      'no2Value': '.004',
#      'o3Value': '.063',
#      'pm25Value': '19'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '군위읍',
#      'pm10Value': '18',
#      'no2Value': '.003',
#      'o3Value': '.044',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '문막읍',
#      'pm10Value': '21',
#      'no2Value': '.005',
#      'o3Value': '.04',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.6',
#      'msrstnName': '덕충동',
#      'pm10Value': '22',
#      'no2Value': '.012',
#      'o3Value': '.063',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '일곡동',
#      'pm10Value': '18',
#      'no2Value': '.007',
#      'o3Value': '.05',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '대정읍',
#      'pm10Value': '23',
#      'no2Value': '.005',
#      'o3Value': '.061',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '이원면',
#      'pm10Value': '23',
#      'no2Value': '.005',
#      'o3Value': '.058',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '당진시청사',
#      'pm10Value': '20',
#      'no2Value': '.005',
#      'o3Value': '.061',
#      'pm25Value': None},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.4',
#      'msrstnName': '묵호항',
#      'pm10Value': '7',
#      'no2Value': '.006',
#      'o3Value': '.034',
#      'pm25Value': None},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '경화동',
#      'pm10Value': '19',
#      'no2Value': '.005',
#      'o3Value': '.052',
#      'pm25Value': '13'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '의정부1동',
#      'pm10Value': '24',
#      'no2Value': '.006',
#      'o3Value': '.046',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '운암동',
#      'pm10Value': '33',
#      'no2Value': '.016',
#      'o3Value': '.052',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '대산리',
#      'pm10Value': '22',
#      'no2Value': '.008',
#      'o3Value': '.064',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '대부동',
#      'pm10Value': '6',
#      'no2Value': '.005',
#      'o3Value': '.054',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.5',
#      'msrstnName': '영천동',
#      'pm10Value': '20',
#      'no2Value': '.006',
#      'o3Value': '.04',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '모종동',
#      'pm10Value': '26',
#      'no2Value': '.007',
#      'o3Value': '.057',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '효성',
#      'pm10Value': '21',
#      'no2Value': '.01',
#      'o3Value': '.06',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '여의동',
#      'pm10Value': '29',
#      'no2Value': '.006',
#      'o3Value': '.06',
#      'pm25Value': '18'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '창전동',
#      'pm10Value': '18',
#      'no2Value': '.005',
#      'o3Value': '.048',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': None,
#      'coValue': None,
#      'msrstnName': '광안동',
#      'pm10Value': '30',
#      'no2Value': '.004',
#      'o3Value': '.054',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.2',
#      'msrstnName': '선단동',
#      'pm10Value': '16',
#      'no2Value': '.005',
#      'o3Value': '.039',
#      'pm25Value': '6'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '부산신항',
#      'pm10Value': '21',
#      'no2Value': '.01',
#      'o3Value': '.048',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '정릉로',
#      'pm10Value': '25',
#      'no2Value': '.017',
#      'o3Value': '.049',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '방산면',
#      'pm10Value': '13',
#      'no2Value': '.003',
#      'o3Value': '.023',
#      'pm25Value': '5'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '행신동',
#      'pm10Value': '22',
#      'no2Value': '.007',
#      'o3Value': '.053',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '비응도동',
#      'pm10Value': '22',
#      'no2Value': '.005',
#      'o3Value': '.062',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '송해',
#      'pm10Value': '23',
#      'no2Value': '.004',
#      'o3Value': '.056',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '남상면',
#      'pm10Value': '15',
#      'no2Value': '.006',
#      'o3Value': '.048',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '양천구',
#      'pm10Value': '20',
#      'no2Value': '.01',
#      'o3Value': '.058',
#      'pm25Value': '9'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.005',
#      'coValue': '.3',
#      'msrstnName': '성동구',
#      'pm10Value': '21',
#      'no2Value': '.01',
#      'o3Value': '.051',
#      'pm25Value': '10'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '삼산동',
#      'pm10Value': '18',
#      'no2Value': '.007',
#      'o3Value': '.042',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '죽항동',
#      'pm10Value': '27',
#      'no2Value': '.004',
#      'o3Value': '.048',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '의령읍',
#      'pm10Value': '16',
#      'no2Value': '.004',
#      'o3Value': '.041',
#      'pm25Value': '11'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '복정동',
#      'pm10Value': '22',
#      'no2Value': '.008',
#      'o3Value': '.051',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.004',
#      'coValue': '.3',
#      'msrstnName': '예산군',
#      'pm10Value': '21',
#      'no2Value': '.004',
#      'o3Value': '.049',
#      'pm25Value': '16'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '지정면',
#      'pm10Value': '19',
#      'no2Value': '.005',
#      'o3Value': '.041',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '주교면',
#      'pm10Value': '20',
#      'no2Value': '.008',
#      'o3Value': '.021',
#      'pm25Value': '12'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.002',
#      'coValue': '.2',
#      'msrstnName': '빛가람동',
#      'pm10Value': '39',
#      'no2Value': '.005',
#      'o3Value': '.058',
#      'pm25Value': '14'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.001',
#      'coValue': '.3',
#      'msrstnName': '화북면',
#      'pm10Value': '17',
#      'no2Value': '.005',
#      'o3Value': '.043',
#      'pm25Value': '8'},
#     {'msurDt': '2024-06-02',
#      'so2Value': '.001',
#      'coValue': '.4',
#      'msrstnName': '수지',
#      'pm10Value': '22',
#      'no2Value': '.006',
#      'o3Value': '.047',
#      'pm25Value': '13'},
#     ...],
#    'pageNo': 1,
#    'numOfRows': 100000},
#   'header': {'resultMsg': 'NORMAL_CODE', 'resultCode': '00'}}}

# %%
import pandas as pd

# 판다스 데이터프레임으로 변환
df_content = pd.DataFrame(dict_content['response']['body']['items'])
print(df_content.columns)
# Out:
# Index(['msurDt', 'so2Value', 'coValue', 'msrstnName', 'pm10Value', 'no2Value',
#        'o3Value', 'pm25Value'],
#       dtype='object')

# %%
df_content.shape
df_content.head()
# Out:
#        msurDt so2Value coValue msrstnName pm10Value no2Value o3Value pm25Value
# 0  2024-06-01     .002      .2        지정면        19     .005    .054        14
# 1  2024-06-01     .003      .2        창녕읍        20     .016    .054        14
# 2  2024-06-01     .002      .4        공단동        18     .007    .049         8
# 3  2024-06-01     .001      .3        양평읍        22     .006    .053        11
# 4  2024-06-01     .001      .4        보령항        44     .007    .053        23
