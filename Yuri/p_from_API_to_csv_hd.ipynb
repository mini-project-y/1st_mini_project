# %% [markdown]
# ## 2021년

# %%
# Python3 샘플 코드 #

import requests

# service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ%2BJxR0E6iUI4qrJNk78%2B5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA%3D%3D'
# 인코딩
service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ+JxR0E6iUI4qrJNk78+5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA=='
# 디코딩


url = 'http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/getHoliDeInfo'
params ={'serviceKey' : service_key, 'pageNo' : '1', 'numOfRows' : '1000', 'solYear' : '2021', '_type':'json'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"dateKind":"01","dateName":"1\xec\x9b\x941\xec\x9d\xbc","isHoliday":"Y","locdate":20210101,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20210211,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20210212,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20210213,"seq":1},{"dateKind":"01","dateName":"\xec\x82\xbc\xec\x9d\xbc\xec\xa0\x88","isHoliday":"Y","locdate":20210301,"seq":1},{"dateKind":"01","dateName":"\xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4\xeb\x82\xa0","isHoliday":"Y","locdate":20210505,"seq":1},{"dateKind":"01","dateName":"\xeb\xb6\x80\xec\xb2\x98\xeb\x8b\x98\xec\x98\xa4\xec\x8b\xa0\xeb\x82\xa0","isHoliday":"Y","locdate":20210519,"seq":1},{"dateKind":"01","dateName":"\xed\x98\x84\xec\xb6\xa9\xec\x9d\xbc","isHoliday":"Y","locdate":20210606,"seq":1},{"dateKin
# ...

# %%
# json str -> dict
import json

text_response = response.content.decode('utf-8')
dict_response = json.loads(text_response)
dict_response
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'dateKind': '01',
#       'dateName': '1월1일',
#       'isHoliday': 'Y',
#       'locdate': 20210101,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20210211,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20210212,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20210213,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '삼일절',
#       'isHoliday': 'Y',
#       'locdate': 20210301,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '어린이날',
#       'isHoliday': 'Y',
#       'locdate': 20210505,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '부처님오신날',
#       'isHoliday': 'Y',
#       'locdate': 20210519,
#       'seq': 1},
# ...

# %%
# 단계별로 접근하면서 데이터 구조 파악
dict_response['response'].keys()
dict_response['response']['body'].keys()
dict_response['response']['body']['items'].keys()
len( dict_response['response']['body']['items']['item'] )
# Out:
# 19

# %%
import pandas as pd

hd_21_df = pd.DataFrame(dict_response['response']['body']['items']['item'])
hd_21_df.head(30)
# Out:
#    dateKind dateName isHoliday   locdate  seq        remarks
# 0        01     1월1일         Y  20210101    1            NaN
# 1        01       설날         Y  20210211    1            NaN
# 2        01       설날         Y  20210212    1            NaN
# 3        01       설날         Y  20210213    1            NaN
# 4        01      삼일절         Y  20210301    1            NaN
# 5        01     어린이날         Y  20210505    1            NaN
# 6        01   부처님오신날         Y  20210519    1            NaN
# 7        01      현충일         Y  20210606    1            NaN
# 8        01      제헌절         N  20210717    1  국경일이지만 공휴일 아님
# 9        01      광복절         Y  20210815    1            NaN
# 10       01    대체공휴일         Y  20210816    1            NaN
# 11       01       추석         Y  20210920    1            NaN
# 12       01       추석         Y  20210921    1            NaN
# 13       01       추석         Y  20210922    1            NaN
# ...

# %% [markdown]
# ## 2022년

# %%
# Python3 샘플 코드 #

import requests

# service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ%2BJxR0E6iUI4qrJNk78%2B5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA%3D%3D'
# 인코딩
service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ+JxR0E6iUI4qrJNk78+5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA=='
# 디코딩


url = 'http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/getHoliDeInfo'
params ={'serviceKey' : service_key, 'pageNo' : '1', 'numOfRows' : '1000', 'solYear' : '2022', '_type':'json'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"dateKind":"01","dateName":"1\xec\x9b\x941\xec\x9d\xbc","isHoliday":"Y","locdate":20220101,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20220131,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20220201,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20220202,"seq":1},{"dateKind":"01","dateName":"\xec\x82\xbc\xec\x9d\xbc\xec\xa0\x88","isHoliday":"Y","locdate":20220301,"seq":1},{"dateKind":"01","dateName":"\xeb\x8c\x80\xed\x86\xb5\xeb\xa0\xb9\xec\x84\xa0\xea\xb1\xb0\xec\x9d\xbc","isHoliday":"Y","locdate":20220309,"seq":1},{"dateKind":"01","dateName":"\xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4\xeb\x82\xa0","isHoliday":"Y","locdate":20220505,"seq":1},{"dateKind":"01","dateName":"\xeb\xb6\x80\xec\xb2\x98\xeb\x8b\x98\xec\x98\xa4\xec\x8b\xa0\xeb\x82\xa0","isHoliday":"Y","
# ...

# %%
# json str -> dict
import json

text_response = response.content.decode('utf-8')
dict_response = json.loads(text_response)
dict_response
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'dateKind': '01',
#       'dateName': '1월1일',
#       'isHoliday': 'Y',
#       'locdate': 20220101,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20220131,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20220201,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20220202,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '삼일절',
#       'isHoliday': 'Y',
#       'locdate': 20220301,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '대통령선거일',
#       'isHoliday': 'Y',
#       'locdate': 20220309,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '어린이날',
#       'isHoliday': 'Y',
#       'locdate': 20220505,
#       'seq': 1},
# ...

# %%
# 단계별로 접근하면서 데이터 구조 파악
dict_response['response'].keys()
dict_response['response']['body'].keys()
dict_response['response']['body']['items'].keys()
len( dict_response['response']['body']['items']['item'] )
# Out:
# 20

# %%
import pandas as pd

hd_22_df = pd.DataFrame(dict_response['response']['body']['items']['item'])
hd_22_df.head(30)
# Out:
#    dateKind  dateName isHoliday   locdate  seq        remarks
# 0        01      1월1일         Y  20220101    1            NaN
# 1        01        설날         Y  20220131    1            NaN
# 2        01        설날         Y  20220201    1            NaN
# 3        01        설날         Y  20220202    1            NaN
# 4        01       삼일절         Y  20220301    1            NaN
# 5        01    대통령선거일         Y  20220309    1            NaN
# 6        01      어린이날         Y  20220505    1            NaN
# 7        01    부처님오신날         Y  20220508    1            NaN
# 8        01  전국동시지방선거         Y  20220601    1            NaN
# 9        01       현충일         Y  20220606    1            NaN
# 10       01       제헌절         N  20220717    1  국경일이지만 공휴일 아님
# 11       01       광복절         Y  20220815    1            NaN
# 12       01        추석         Y  20220909    1            NaN
# 13       01        추석         Y  20220910    1            NaN
# ...

# %% [markdown]
# ## 2023년

# %%
# Python3 샘플 코드 #

import requests

# service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ%2BJxR0E6iUI4qrJNk78%2B5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA%3D%3D'
# 인코딩
service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ+JxR0E6iUI4qrJNk78+5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA=='
# 디코딩


url = 'http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/getHoliDeInfo'
params ={'serviceKey' : service_key, 'pageNo' : '1', 'numOfRows' : '1000', 'solYear' : '2023', '_type':'json'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"dateKind":"01","dateName":"1\xec\x9b\x941\xec\x9d\xbc","isHoliday":"Y","locdate":20230101,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20230121,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20230122,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20230123,"seq":1},{"dateKind":"01","dateName":"\xeb\x8c\x80\xec\xb2\xb4\xea\xb3\xb5\xed\x9c\xb4\xec\x9d\xbc","isHoliday":"Y","locdate":20230124,"seq":1},{"dateKind":"01","dateName":"\xec\x82\xbc\xec\x9d\xbc\xec\xa0\x88","isHoliday":"Y","locdate":20230301,"seq":1},{"dateKind":"01","dateName":"\xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4\xeb\x82\xa0","isHoliday":"Y","locdate":20230505,"seq":1},{"dateKind":"01","dateName":"\xeb\xb6\x80\xec\xb2\x98\xeb\x8b\x98\xec\x98\xa4\xec\x8b\xa0\xeb\x82\xa0","isHoliday":"Y","locdate":202
# ...

# %%
# json str -> dict
import json

text_response = response.content.decode('utf-8')
dict_response = json.loads(text_response)
dict_response
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'dateKind': '01',
#       'dateName': '1월1일',
#       'isHoliday': 'Y',
#       'locdate': 20230101,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20230121,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20230122,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20230123,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '대체공휴일',
#       'isHoliday': 'Y',
#       'locdate': 20230124,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '삼일절',
#       'isHoliday': 'Y',
#       'locdate': 20230301,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '어린이날',
#       'isHoliday': 'Y',
#       'locdate': 20230505,
#       'seq': 1},
# ...

# %%
# 단계별로 접근하면서 데이터 구조 파악
dict_response['response'].keys()
dict_response['response']['body'].keys()
dict_response['response']['body']['items'].keys()
len( dict_response['response']['body']['items']['item'] )
# Out:
# 19

# %%
import pandas as pd

hd_23_df = pd.DataFrame(dict_response['response']['body']['items']['item'])
hd_23_df.head(30)
# Out:
#    dateKind dateName isHoliday   locdate  seq        remarks
# 0        01     1월1일         Y  20230101    1            NaN
# 1        01       설날         Y  20230121    1            NaN
# 2        01       설날         Y  20230122    1            NaN
# 3        01       설날         Y  20230123    1            NaN
# 4        01    대체공휴일         Y  20230124    1            NaN
# 5        01      삼일절         Y  20230301    1            NaN
# 6        01     어린이날         Y  20230505    1            NaN
# 7        01   부처님오신날         Y  20230527    1            NaN
# 8        01    대체공휴일         Y  20230529    1            NaN
# 9        01      현충일         Y  20230606    1            NaN
# 10       01      제헌절         N  20230717    1  국경일이지만 공휴일 아님
# 11       01      광복절         Y  20230815    1            NaN
# 12       01       추석         Y  20230928    1            NaN
# 13       01       추석         Y  20230929    1            NaN
# ...

# %%
hd_21_df.to_csv('./data/hd_21.csv')
hd_22_df.to_csv('./data/hd_22.csv')
hd_23_df.to_csv('./data/hd_23.csv')

# %% [markdown]
# ## 2024년

# %%
# Python3 샘플 코드 #

import requests

# service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ%2BJxR0E6iUI4qrJNk78%2B5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA%3D%3D'
# 인코딩
service_key = 'YgC6RL7Xuzrbvz7msHuvRG0JZ+JxR0E6iUI4qrJNk78+5FdBneHQ8wktN9kjkpfJFCUeVtCuvThmYWikuonEuA=='
# 디코딩


url = 'http://apis.data.go.kr/B090041/openapi/service/SpcdeInfoService/getHoliDeInfo'
params ={'serviceKey' : service_key, 'pageNo' : '1', 'numOfRows' : '1000', 'solYear' : '2024', '_type':'json'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE."},"body":{"items":{"item":[{"dateKind":"01","dateName":"1\xec\x9b\x941\xec\x9d\xbc","isHoliday":"Y","locdate":20240101,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20240209,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20240210,"seq":1},{"dateKind":"01","dateName":"\xec\x84\xa4\xeb\x82\xa0","isHoliday":"Y","locdate":20240211,"seq":1},{"dateKind":"01","dateName":"\xeb\x8c\x80\xec\xb2\xb4\xea\xb3\xb5\xed\x9c\xb4\xec\x9d\xbc(\xec\x84\xa4\xeb\x82\xa0)","isHoliday":"Y","locdate":20240212,"seq":1},{"dateKind":"01","dateName":"\xec\x82\xbc\xec\x9d\xbc\xec\xa0\x88","isHoliday":"Y","locdate":20240301,"seq":1},{"dateKind":"01","dateName":"\xea\xb5\xad\xed\x9a\x8c\xec\x9d\x98\xec\x9b\x90\xec\x84\xa0\xea\xb1\xb0","isHoliday":"Y","locdate":20240410,"seq":1},{"dateKind":"01","dateName":"\xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4\xeb\x82\xa0","is
# ...

# %%
# json str -> dict
import json

text_response = response.content.decode('utf-8')
dict_response = json.loads(text_response)
dict_response
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'dateKind': '01',
#       'dateName': '1월1일',
#       'isHoliday': 'Y',
#       'locdate': 20240101,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20240209,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20240210,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '설날',
#       'isHoliday': 'Y',
#       'locdate': 20240211,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '대체공휴일(설날)',
#       'isHoliday': 'Y',
#       'locdate': 20240212,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '삼일절',
#       'isHoliday': 'Y',
#       'locdate': 20240301,
#       'seq': 1},
#      {'dateKind': '01',
#       'dateName': '국회의원선거',
#       'isHoliday': 'Y',
#       'locdate': 20240410,
# ...

# %%
# 단계별로 접근하면서 데이터 구조 파악
dict_response['response'].keys()
dict_response['response']['body'].keys()
dict_response['response']['body']['items'].keys()
len( dict_response['response']['body']['items']['item'] )
# Out:
# 20

# %%
import pandas as pd

hd_24_df = pd.DataFrame(dict_response['response']['body']['items']['item'])
hd_24_df.head(30)
# Out:
#    dateKind     dateName isHoliday   locdate  seq
# 0        01         1월1일         Y  20240101    1
# 1        01           설날         Y  20240209    1
# 2        01           설날         Y  20240210    1
# 3        01           설날         Y  20240211    1
# 4        01    대체공휴일(설날)         Y  20240212    1
# 5        01          삼일절         Y  20240301    1
# 6        01       국회의원선거         Y  20240410    1
# 7        01         어린이날         Y  20240505    1
# 8        01  대체공휴일(어린이날)         Y  20240506    1
# 9        01       부처님오신날         Y  20240515    1
# 10       01          현충일         Y  20240606    1
# 11       01          제헌절         N  20240717    1
# 12       01          광복절         Y  20240815    1
# 13       01           추석         Y  20240916    1
# 14       01           추석         Y  20240917    1
# 15       01           추석         Y  20240918    1
# 16       01        임시공휴일         Y  20241001    2
# 17       01          개천절         Y  20241003    1
# ...

# %%
hd_24_df.to_csv('./data/hd_24.csv')

# %% [markdown]
# ## 공휴일 합치기

# %%
hd_df = pd.concat([hd_21_df, hd_22_df, hd_23_df, hd_24_df])
hd_df.head(50)
# Out:
#    dateKind  dateName isHoliday   locdate  seq        remarks
# 0        01      1월1일         Y  20210101    1            NaN
# 1        01        설날         Y  20210211    1            NaN
# 2        01        설날         Y  20210212    1            NaN
# 3        01        설날         Y  20210213    1            NaN
# 4        01       삼일절         Y  20210301    1            NaN
# 5        01      어린이날         Y  20210505    1            NaN
# 6        01    부처님오신날         Y  20210519    1            NaN
# 7        01       현충일         Y  20210606    1            NaN
# 8        01       제헌절         N  20210717    1  국경일이지만 공휴일 아님
# 9        01       광복절         Y  20210815    1            NaN
# 10       01     대체공휴일         Y  20210816    1            NaN
# 11       01        추석         Y  20210920    1            NaN
# 12       01        추석         Y  20210921    1            NaN
# 13       01        추석         Y  20210922    1            NaN
# ...

# %%
hd_df.columns
# Out:
# Index(['dateKind', 'dateName', 'isHoliday', 'locdate', 'seq', 'remarks'], dtype='object')

# %%
idx = hd_df[hd_df['isHoliday'].str.contains('N')].index
hd_df.drop(idx, inplace=True)
hd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dateKind   66 non-null     object
#  1   dateName   66 non-null     object
#  2   isHoliday  66 non-null     object
#  3   locdate    66 non-null     int64
#  4   seq        66 non-null     int64
#  5   remarks    0 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 3.6+ KB

# %%
hd_df.rename(columns={"locdate":"일시"}, inplace=True)
hd_df
# Out:
#    dateKind dateName isHoliday        일시  seq remarks
# 0        01     1월1일         Y  20210101    1     NaN
# 1        01       설날         Y  20210211    1     NaN
# 2        01       설날         Y  20210212    1     NaN
# 3        01       설날         Y  20210213    1     NaN
# 4        01      삼일절         Y  20210301    1     NaN
# ..      ...      ...       ...       ...  ...     ...
# 15       01       추석         Y  20240918    1     NaN
# 16       01    임시공휴일         Y  20241001    2     NaN
# 17       01      개천절         Y  20241003    1     NaN
# 18       01      한글날         Y  20241009    1     NaN
# 19       01    기독탄신일         Y  20241225    1     NaN
#
# [66 rows x 6 columns]

# %%
hd_df = hd_df.loc[:, ['일시', 'dateName']]
hd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   일시        66 non-null     int64
#  1   dateName  66 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.5+ KB

# %%
hd_df.to_csv('./data/hd_21_24.csv')

# %% [markdown]
# ## 날짜를 datetime

# %%
import pandas as pd

# %%
hd = pd.read_csv('./data/hd_21_24.csv')
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  66 non-null     int64
#  1   일시          66 non-null     int64
#  2   dateName    66 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 1.7+ KB

# %%
hd['일시'] = hd['일시'].apply(lambda v: pd.to_datetime(str(v), format='%Y%m%d'))
hd
# Out:
#     Unnamed: 0         일시 dateName
# 0            0 2021-01-01     1월1일
# 1            1 2021-02-11       설날
# 2            2 2021-02-12       설날
# 3            3 2021-02-13       설날
# 4            4 2021-03-01      삼일절
# ..         ...        ...      ...
# 61          15 2024-09-18       추석
# 62          16 2024-10-01    임시공휴일
# 63          17 2024-10-03      개천절
# 64          18 2024-10-09      한글날
# 65          19 2024-12-25    기독탄신일
#
# [66 rows x 3 columns]

# %%
hd = hd.iloc[:, 1:]
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   일시        66 non-null     datetime64[ns]
#  1   dateName  66 non-null     object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.2+ KB

# %%
hd.to_csv('./data/hd_21_24.csv')
