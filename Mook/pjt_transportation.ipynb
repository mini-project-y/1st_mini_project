# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_bus = pd.read_csv("D:/humanda/project/1st_miniproject/Mook/서울시_행정동별_버스_총_승차_승객수_정보.csv", encoding='cp949')
df_train = pd.read_csv("D:/humanda/project/1st_miniproject/Mook/서울시_행정동별_지하철_총_승차_승객수_정보.csv", encoding='cp949')

# %%
df_bus
# Out:
#            기준_날짜    행정동_ID  버스_승객_수  버스_승객_수_00시  버스_승객_수_01시  버스_승객_수_02시  \
# 0       20241030  11250770  11178.0         75.0         29.0          1.0
# 1       20241030  11250760   4100.0         12.0          3.0          0.0
# 2       20241030  11250740   3644.0          6.0          0.0          0.0
# 3       20241030  11250730   8433.0        103.0         24.0         13.0
# 4       20241030  11250720   6584.0         44.0          5.0          1.0
# ...          ...       ...      ...          ...          ...          ...
# 438231  20220101   1110061   2480.0          5.0          0.0          0.0
# 438232  20220101   1110060   3485.0         19.0          0.0          0.0
# 438233  20220101   1110056   2377.0          1.0          0.0          0.0
# 438234  20220101   1115069   2229.0          6.0          0.0          0.0
# 438235  20220101   1115065   1353.0          5.0          0.0          0.0
#
# ...

# %%
df_train
# Out:
#            기준_날짜    행정동_ID  지하철_승객_수  지하철_승객_수_00시  지하철_승객_수_01시  \
# 0       20241030  11250770       NaN           NaN           NaN
# 1       20241030  11250760       NaN           NaN           NaN
# 2       20241030  11250740    9435.0          16.0           0.0
# 3       20241030  11250730       NaN           NaN           NaN
# 4       20241030  11250720       NaN           NaN           NaN
# ...          ...       ...       ...           ...           ...
# 439077  20211130   1105057   10728.0           1.0           0.0
# 439078  20211130   1101061   95603.0           4.0           0.0
# 439079  20211130   1114066  101870.0          11.0           0.0
# 439080  20211130   1114060   21633.0           0.0           0.0
# 439081  20211130   1113066       NaN           NaN           NaN
#
#         지하철_승객_수_02시  지하철_승객_수_03시  지하철_승객_수_04시  지하철_승객_수_05시  지하철_승객_수_06시  \
# 0                NaN           NaN           NaN           NaN           NaN
# ...

# %%
df_train = df_train.fillna(0)

# %%
bus_sum = df_bus.groupby('기준_날짜').sum().reset_index()
train_sum = df_train.groupby('기준_날짜').sum().reset_index()

# %%
bus_sum
# Out:
#          기준_날짜      행정동_ID    버스_승객_수  버스_승객_수_00시  버스_승객_수_01시  버스_승객_수_02시  \
# 0     20220101   472193485  1880120.0       6686.0       1323.0        705.0
# 1     20220102   472193485  2083725.0       6187.0       1204.0        687.0
# 2     20220103   472193485  4047637.0       9400.0       2033.0       1364.0
# 3     20220104   472193485  4169434.0       9681.0       2256.0       1405.0
# 4     20220105   472193485  4169434.0       9681.0       2256.0       1405.0
# ...        ...         ...        ...          ...          ...          ...
# 1027  20241026  4733105911  4049925.0      41077.0      10583.0       6761.0
# 1028  20241027  4733105911  3030968.0      22586.0       5876.0       3797.0
# 1029  20241028  4733105911  4911895.0      23853.0       7349.0       4869.0
# 1030  20241029  4733105911  5023205.0      26698.0       7940.0       5225.0
# 1031  20241030  4733105911  5106658.0      28747.0       8540.0       5642.0
#
# ...

# %%
train_sum
# Out:
#          기준_날짜      행정동_ID   지하철_승객_수  지하철_승객_수_00시  지하철_승객_수_01시  \
# 0     20211130   472193485  4675652.0         188.0           3.0
# 1     20211230   472193485  4654132.0          58.0           0.0
# 2     20211231   472193485  4315971.0          61.0           4.0
# 3     20220101   472193485  1792725.0          28.0           0.0
# 4     20220102   472193485  2053208.0          30.0           1.0
# ...        ...         ...        ...           ...           ...
# 1029  20241026  4733105911  4561254.0         513.0           2.0
# 1030  20241027  4733105911  3490702.0         200.0           0.0
# 1031  20241028  4733105911  5645227.0       11953.0          10.0
# 1032  20241029  4733105911  5796770.0       13682.0           7.0
# 1033  20241030  4733105911  5873424.0       14821.0          11.0
#
#       지하철_승객_수_02시  지하철_승객_수_03시  지하철_승객_수_04시  지하철_승객_수_05시  지하철_승객_수_06시  \
# 0              0.0           0.0        1565.0       58674.0      137513.0
# ...

# %%
bus_sum['total_passenger'] = bus_sum.iloc[:, 3:29].sum(axis=1)
bus_sum['commute_passenger'] = bus_sum['버스_승객_수_07시'] + bus_sum['버스_승객_수_08시'] + bus_sum['버스_승객_수_09시']\
                            + bus_sum['버스_승객_수_18시'] + bus_sum['버스_승객_수_19시'] + bus_sum['버스_승객_수_20시']

train_sum['total_passenger'] = train_sum.iloc[:, 3:29].sum(axis=1)
train_sum['commute_passenger'] = train_sum['지하철_승객_수_07시'] + train_sum['지하철_승객_수_08시'] + train_sum['지하철_승객_수_09시']\
                            + train_sum['지하철_승객_수_18시'] + train_sum['지하철_승객_수_19시'] + train_sum['지하철_승객_수_20시']

# %%
bus_sum = bus_sum.drop(['버스_승객_수_07시', '버스_승객_수_08시', '버스_승객_수_09시', \
                      '버스_승객_수_18시', '버스_승객_수_19시', '버스_승객_수_20시'], axis=1)

train_sum = train_sum.drop(['지하철_승객_수_07시', '지하철_승객_수_08시', '지하철_승객_수_09시', \
                      '지하철_승객_수_18시', '지하철_승객_수_19시', '지하철_승객_수_20시'], axis=1)

# %%
bus_sum['other_passenger'] = bus_sum.iloc[:, 3:21].sum(axis=1)
train_sum['other_passenger'] = train_sum.iloc[:, 3:21].sum(axis=1)

# %%
bus_sum = bus_sum[['기준_날짜', 'total_passenger', 'commute_passenger', 'other_passenger']]
train_sum = train_sum[['기준_날짜', 'total_passenger', 'commute_passenger', 'other_passenger']]

# %%
bus_sum = bus_sum.rename(columns={'기준_날짜': 'date'})
train_sum = train_sum.rename(columns={'기준_날짜': 'date'})

# %%
bus_sum
# Out:
#           date  total_passenger  commute_passenger  other_passenger
# 0     20220101        1858954.0           519623.0        1339331.0
# 1     20220102        2048632.0           579340.0        1469292.0
# 2     20220103        4028715.0          1793953.0        2234762.0
# 3     20220104        4151012.0          1823826.0        2327186.0
# 4     20220105        4151012.0          1823826.0        2327186.0
# ...        ...              ...                ...              ...
# 1027  20241026        4026928.0          1194663.0        2832265.0
# 1028  20241027        2991012.0           860873.0        2130139.0
# 1029  20241028        4900706.0          2052646.0        2848060.0
# 1030  20241029        5017336.0          2095851.0        2921485.0
# 1031  20241030        5092649.0          2111786.0        2980863.0
#
# [1032 rows x 4 columns]

# %%
train_sum
# Out:
#           date  total_passenger  commute_passenger  other_passenger
# 0     20211130        4675652.0          2327114.0        2348538.0
# 1     20211230        4654132.0          2094071.0        2560061.0
# 2     20211231        4315971.0          1686377.0        2629594.0
# 3     20220101        1792725.0           502533.0        1290192.0
# 4     20220102        2053208.0           608212.0        1444996.0
# ...        ...              ...                ...              ...
# 1029  20241026        4561254.0          1356948.0        3204306.0
# 1030  20241027        3490702.0           979266.0        2511436.0
# 1031  20241028        5645227.0          2635818.0        3009409.0
# 1032  20241029        5796770.0          2691367.0        3105403.0
# 1033  20241030        5873424.0          2692693.0        3180731.0
#
# [1034 rows x 4 columns]

# %%
print(bus_sum.info())
print(train_sum.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1032 non-null   int64
#  1   total_passenger    1032 non-null   float64
#  2   commute_passenger  1032 non-null   float64
#  3   other_passenger    1032 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 32.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1034 non-null   int64
#  1   total_passenger    1034 non-null   float64
#  2   commute_passenger  1034 non-null   float64
#  3   other_passenger    1034 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 32.4 KB
# None

# %%
bus_sum['date'] = pd.to_datetime(bus_sum['date'].astype(str), format='%Y%m%d')
train_sum['date'] = pd.to_datetime(train_sum['date'].astype(str), format='%Y%m%d')

# %%
print(bus_sum.info())
print(train_sum.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1032 non-null   datetime64[ns]
#  1   total_passenger    1032 non-null   float64
#  2   commute_passenger  1032 non-null   float64
#  3   other_passenger    1032 non-null   float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 32.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1034 non-null   datetime64[ns]
#  1   total_passenger    1034 non-null   float64
#  2   commute_passenger  1034 non-null   float64
#  3   other_passenger    1034 non-null   float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 32.4 KB
# None

# %%
bus_sum
# Out:
#            date  total_passenger  commute_passenger  other_passenger
# 0    2022-01-01        1858954.0           519623.0        1339331.0
# 1    2022-01-02        2048632.0           579340.0        1469292.0
# 2    2022-01-03        4028715.0          1793953.0        2234762.0
# 3    2022-01-04        4151012.0          1823826.0        2327186.0
# 4    2022-01-05        4151012.0          1823826.0        2327186.0
# ...         ...              ...                ...              ...
# 1027 2024-10-26        4026928.0          1194663.0        2832265.0
# 1028 2024-10-27        2991012.0           860873.0        2130139.0
# 1029 2024-10-28        4900706.0          2052646.0        2848060.0
# 1030 2024-10-29        5017336.0          2095851.0        2921485.0
# 1031 2024-10-30        5092649.0          2111786.0        2980863.0
#
# [1032 rows x 4 columns]

# %%
mask_1 = (bus_sum['date'] > '2021-12-31')
bus_sum = bus_sum[mask_1]

mask_2 = (train_sum['date'] > '2021-12-31')
train_sum = train_sum[mask_2]

# %%
bus_sum
# Out:
#            date  total_passenger  commute_passenger  other_passenger
# 0    2022-01-01        1858954.0           519623.0        1339331.0
# 1    2022-01-02        2048632.0           579340.0        1469292.0
# 2    2022-01-03        4028715.0          1793953.0        2234762.0
# 3    2022-01-04        4151012.0          1823826.0        2327186.0
# 4    2022-01-05        4151012.0          1823826.0        2327186.0
# ...         ...              ...                ...              ...
# 1027 2024-10-26        4026928.0          1194663.0        2832265.0
# 1028 2024-10-27        2991012.0           860873.0        2130139.0
# 1029 2024-10-28        4900706.0          2052646.0        2848060.0
# 1030 2024-10-29        5017336.0          2095851.0        2921485.0
# 1031 2024-10-30        5092649.0          2111786.0        2980863.0
#
# [1032 rows x 4 columns]

# %%
train_sum
# Out:
#            date  total_passenger  commute_passenger  other_passenger
# 3    2022-01-01        1792725.0           502533.0        1290192.0
# 4    2022-01-02        2053208.0           608212.0        1444996.0
# 5    2022-01-03        4487668.0          2285899.0        2201769.0
# 6    2022-01-04        4648008.0          2316071.0        2331937.0
# 7    2022-01-05        4648008.0          2316071.0        2331937.0
# ...         ...              ...                ...              ...
# 1029 2024-10-26        4561254.0          1356948.0        3204306.0
# 1030 2024-10-27        3490702.0           979266.0        2511436.0
# 1031 2024-10-28        5645227.0          2635818.0        3009409.0
# 1032 2024-10-29        5796770.0          2691367.0        3105403.0
# 1033 2024-10-30        5873424.0          2692693.0        3180731.0
#
# [1031 rows x 4 columns]

# %%
print(train_sum[train_sum['total_passenger'] == 0])
# Out:
#           date  total_passenger  commute_passenger  other_passenger
# 266 2022-09-21              0.0                0.0              0.0
# 944 2024-08-02              0.0                0.0              0.0

# %%
train_sum = train_sum[train_sum['total_passenger'] != 0]

# %%
df_date = pd.read_csv("D:/humanda/project/1st_miniproject/Mook/df_date.csv")

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1035 non-null   int64
#  1   date                1035 non-null   object
#  2   holiday_or_weekend  1035 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 24.4+ KB

# %%
df_date['date'] = pd.to_datetime(df_date['date'])

# %%
df_date
# Out:
#         ID       date  holiday_or_weekend
# 0        1 2022-01-01                   1
# 1        2 2022-01-02                   1
# 2        3 2022-01-03                   0
# 3        4 2022-01-04                   0
# 4        5 2022-01-05                   0
# ...    ...        ...                 ...
# 1030  1031 2024-10-27                   1
# 1031  1032 2024-10-28                   0
# 1032  1033 2024-10-29                   0
# 1033  1034 2024-10-30                   0
# 1034  1035 2024-10-31                   0
#
# [1035 rows x 3 columns]

# %%
bus_merged = pd.merge(bus_sum, df_date, on = 'date', how = 'inner')
train_merged = pd.merge(train_sum, df_date, on = 'date', how = 'inner')

# %%
bus_merged
# Out:
#            date  total_passenger  commute_passenger  other_passenger    ID  \
# 0    2022-01-01        1858954.0           519623.0        1339331.0     1
# 1    2022-01-02        2048632.0           579340.0        1469292.0     2
# 2    2022-01-03        4028715.0          1793953.0        2234762.0     3
# 3    2022-01-04        4151012.0          1823826.0        2327186.0     4
# 4    2022-01-05        4151012.0          1823826.0        2327186.0     5
# ...         ...              ...                ...              ...   ...
# 1027 2024-10-26        4026928.0          1194663.0        2832265.0  1030
# 1028 2024-10-27        2991012.0           860873.0        2130139.0  1031
# 1029 2024-10-28        4900706.0          2052646.0        2848060.0  1032
# 1030 2024-10-29        5017336.0          2095851.0        2921485.0  1033
# 1031 2024-10-30        5092649.0          2111786.0        2980863.0  1034
#
#       holiday_or_weekend
# 0                      1
# ...

# %%
train_merged
# Out:
#            date  total_passenger  commute_passenger  other_passenger    ID  \
# 0    2022-01-01        1792725.0           502533.0        1290192.0     1
# 1    2022-01-02        2053208.0           608212.0        1444996.0     2
# 2    2022-01-03        4487668.0          2285899.0        2201769.0     3
# 3    2022-01-04        4648008.0          2316071.0        2331937.0     4
# 4    2022-01-05        4648008.0          2316071.0        2331937.0     5
# ...         ...              ...                ...              ...   ...
# 1024 2024-10-26        4561254.0          1356948.0        3204306.0  1030
# 1025 2024-10-27        3490702.0           979266.0        2511436.0  1031
# 1026 2024-10-28        5645227.0          2635818.0        3009409.0  1032
# 1027 2024-10-29        5796770.0          2691367.0        3105403.0  1033
# 1028 2024-10-30        5873424.0          2692693.0        3180731.0  1034
#
#       holiday_or_weekend
# 0                      1
# ...

# %%
bus_merged = bus_merged.drop(['ID'], axis=1)

# %%
train_merged = train_merged.drop(['ID'], axis=1)

# %% [markdown]
# # 결측치 확인

# %%
bus_merged.isnull().sum()
# Out:
# date                  0
# total_passenger       0
# commute_passenger     0
# other_passenger       0
# holiday_or_weekend    0
# dtype: int64

# %% [markdown]
# # 이상치 제거
# 버스 및 지하철 파업이나 교통문제로 이상이 생긴 날짜 제거

# %%
df_bus_weekday = bus_merged[bus_merged['holiday_or_weekend'] == 0]
df_bus_weekend = bus_merged[bus_merged['holiday_or_weekend'] == 1]
df_train_weekday = train_merged[train_merged['holiday_or_weekend'] == 0]
df_train_weekend = train_merged[train_merged['holiday_or_weekend'] == 1]

# %%
from scipy import stats

z_scores = stats.zscore(df_bus_weekday['total_passenger'])
outliers = df_bus_weekday[(z_scores > 3) | (z_scores < -3)]
print(outliers)
# Out:
#           date  total_passenger  commute_passenger  other_passenger  \
# 72  2022-03-14        1859371.0           543249.0        1316122.0
# 255 2022-09-13        2453648.0           700878.0        1752770.0
# 345 2022-12-12        3450969.0           978652.0        2472317.0
# 346 2022-12-13        3450969.0           978652.0        2472317.0
# 353 2022-12-20        2431543.0           695959.0        1735584.0
# 485 2023-05-01        3579174.0          1186343.0        2392831.0
# 513 2023-05-29        2973154.0           890279.0        2082875.0
# 817 2024-03-28        2635754.0          1193219.0        1442535.0
# 856 2024-05-06        2571338.0           757763.0        1813575.0
# 885 2024-06-06        3171357.0           922093.0        2249264.0
# 911 2024-07-02        2603371.0           777431.0        1825940.0
#
#      holiday_or_weekend
# 72                    0
# 255                   0
# 345                   0
# 346                   0
# ...

# %%
bus_merged = bus_merged[~bus_merged['date'].isin(outliers['date'])]

# %%
z_scores = stats.zscore(df_bus_weekend['total_passenger'])
outliers = df_bus_weekend[(z_scores > 3) | (z_scores < -3)]
print(outliers)
# Out:
#           date  total_passenger  commute_passenger  other_passenger  \
# 182 2022-07-02        5117110.0          2115442.0        3001668.0
# 280 2022-10-08        5014788.0          2084024.0        2930764.0
#
#      holiday_or_weekend
# 182                   1
# 280                   1

# %%
bus_merged = bus_merged[~bus_merged['date'].isin(outliers['date'])]

# %%
z_scores = stats.zscore(df_train_weekday['total_passenger'])
outliers = df_train_weekday[(z_scores > 3) | (z_scores < -3)]
print(outliers)
# Out:
#           date  total_passenger  commute_passenger  other_passenger  \
# 72  2022-03-14        1885163.0           553553.0        1331610.0
# 255 2022-09-13        2509959.0           747804.0        1762155.0
# 352 2022-12-20        2786142.0           800278.0        1985864.0
# 484 2023-05-01        3890778.0          1305707.0        2585071.0
# 512 2023-05-29        3128297.0           952162.0        2176135.0
# 854 2024-05-06        2845083.0           848279.0        1996804.0
# 883 2024-06-06        3481117.0          1033848.0        2447269.0
# 909 2024-07-02        2719676.0           816430.0        1903246.0
#
#      holiday_or_weekend
# 72                    0
# 255                   0
# 352                   0
# 484                   0
# 512                   0
# 854                   0
# 883                   0
# 909                   0

# %%
train_merged = train_merged[~train_merged['date'].isin(outliers['date'])]

# %%
z_scores = stats.zscore(df_train_weekend['total_passenger'])
outliers = df_train_weekend[(z_scores > 3) | (z_scores < -3)]
print(outliers)
# Out:
#           date  total_passenger  commute_passenger  other_passenger  \
# 279 2022-10-08        5838293.0          2612688.0        3225605.0
#
#      holiday_or_weekend
# 279                   1

# %%
train_merged = train_merged[~train_merged['date'].isin(outliers['date'])]

# %% [markdown]
# # 시각화

# %%
bus_merged.set_index('date', inplace=True)
bus_monthly = bus_merged.resample('ME').sum(numeric_only=True)

train_merged.set_index('date', inplace=True)
train_monthly = train_merged.resample('ME').sum(numeric_only=True)

# %%
bus_monthly
# Out:
#             total_passenger  commute_passenger  other_passenger  \
# date
# 2022-01-31      110163939.0         43605035.0       66558904.0
# 2022-02-28       95379922.0         37744046.0       57635876.0
# 2022-03-31      106975852.0         42904055.0       64071797.0
# 2022-04-30      121910386.0         48702451.0       73207935.0
# 2022-05-31      131910732.0         51905182.0       80005550.0
# 2022-06-30      125714997.0         49693873.0       76021124.0
# 2022-07-31      127215477.0         50759241.0       76456236.0
# 2022-08-31      131148627.0         52847043.0       78301584.0
# 2022-09-30      121284854.0         47866767.0       73418087.0
# 2022-10-31      126869633.0         49674712.0       77194921.0
# 2022-11-30      128675902.0         51644034.0       77031868.0
# 2022-12-31      118569650.0         45755280.0       72814370.0
# 2023-01-31      114670773.0         45292552.0       69378221.0
# 2023-02-28      114495110.0         45393466.0       69101644.0
# ...

# %%
train_monthly
# Out:
#             total_passenger  commute_passenger  other_passenger  \
# date
# 2022-01-31      121888056.0         53757911.0       68130145.0
# 2022-02-28      103270768.0         45447499.0       57823269.0
# 2022-03-31      113161346.0         49767770.0       63393576.0
# 2022-04-30      131832555.0         57623291.0       74209264.0
# 2022-05-31      145465826.0         62697424.0       82768402.0
# 2022-06-30      137704318.0         59383795.0       78320523.0
# 2022-07-31      141884156.0         61955277.0       79928879.0
# 2022-08-31      141014403.0         62264124.0       78750279.0
# 2022-09-30      127661399.0         54386491.0       73274908.0
# 2022-10-31      145001146.0         61128838.0       83872308.0
# 2022-11-30      147721225.0         64198210.0       83523015.0
# 2022-12-31      144647913.0         58088214.0       86559699.0
# 2023-01-31      133853877.0         57549359.0       76304518.0
# 2023-02-28      136940679.0         58906179.0       78034500.0
# ...

# %%
bus_monthly2 = bus_monthly.reset_index()
train_monthly2 = train_monthly.reset_index()

# %%
bus_monthly2["date_month"] = bus_monthly2['date'].map(lambda v: str(v)[:7])
train_monthly2["date_month"] = train_monthly2['date'].map(lambda v: str(v)[:7])

# %%
bus_monthly2
# Out:
#          date  total_passenger  commute_passenger  other_passenger  \
# 0  2022-01-31      110163939.0         43605035.0       66558904.0
# 1  2022-02-28       95379922.0         37744046.0       57635876.0
# 2  2022-03-31      106975852.0         42904055.0       64071797.0
# 3  2022-04-30      121910386.0         48702451.0       73207935.0
# 4  2022-05-31      131910732.0         51905182.0       80005550.0
# 5  2022-06-30      125714997.0         49693873.0       76021124.0
# 6  2022-07-31      127215477.0         50759241.0       76456236.0
# 7  2022-08-31      131148627.0         52847043.0       78301584.0
# 8  2022-09-30      121284854.0         47866767.0       73418087.0
# 9  2022-10-31      126869633.0         49674712.0       77194921.0
# 10 2022-11-30      128675902.0         51644034.0       77031868.0
# 11 2022-12-31      118569650.0         45755280.0       72814370.0
# 12 2023-01-31      114670773.0         45292552.0       69378221.0
# ...

# %%
train_monthly2
# Out:
#          date  total_passenger  commute_passenger  other_passenger  \
# 0  2022-01-31      121888056.0         53757911.0       68130145.0
# 1  2022-02-28      103270768.0         45447499.0       57823269.0
# 2  2022-03-31      113161346.0         49767770.0       63393576.0
# 3  2022-04-30      131832555.0         57623291.0       74209264.0
# 4  2022-05-31      145465826.0         62697424.0       82768402.0
# 5  2022-06-30      137704318.0         59383795.0       78320523.0
# 6  2022-07-31      141884156.0         61955277.0       79928879.0
# 7  2022-08-31      141014403.0         62264124.0       78750279.0
# 8  2022-09-30      127661399.0         54386491.0       73274908.0
# 9  2022-10-31      145001146.0         61128838.0       83872308.0
# 10 2022-11-30      147721225.0         64198210.0       83523015.0
# 11 2022-12-31      144647913.0         58088214.0       86559699.0
# 12 2023-01-31      133853877.0         57549359.0       76304518.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

plt.figure(figsize=(14, 7))
sns.lineplot(data=bus_monthly2, x='date_month', y='total_passenger', marker='o', label = 'bus')
sns.lineplot(data=train_monthly2, x='date_month', y='total_passenger', marker='o', label = 'train')
plt.title('Monthly Passenger Count by Transportation Mode')
plt.xlabel('Month')
plt.ylabel('Total Passenger Count')
plt.grid()
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
bus_avg = bus_merged.groupby('holiday_or_weekend')['total_passenger'].mean().reset_index()
bus_avg['holiday_or_weekend'] = bus_avg['holiday_or_weekend'].map({0: 'Weekday', 1: 'holiday_or_weekend'})

train_avg = train_merged.groupby('holiday_or_weekend')['total_passenger'].mean().reset_index()
train_avg['holiday_or_weekend'] = train_avg['holiday_or_weekend'].map({0: 'Weekday', 1: 'holiday_or_weekend'})

# %%
bus_merged = bus_merged.reset_index()
train_merged = train_merged.reset_index()

# %%
plt.figure(figsize=(8, 6))
plt.bar(bus_avg['holiday_or_weekend'], bus_avg['total_passenger'], color=['lightblue', 'salmon'])

plt.title('Bus Average Passengers', fontsize=16)
plt.xlabel('Day Type', fontsize=14)
plt.ylabel('Average Number of Passengers', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.bar(train_avg['holiday_or_weekend'], train_avg['total_passenger'], color=['lightblue', 'salmon'])

plt.title('Train Average Passengers', fontsize=16)
plt.xlabel('Day Type', fontsize=14)
plt.ylabel('Average Number of Passengers', fontsize=14)
plt.show()

# %%
from pprint import pprint

bus_passengers_description = {}

for holiday_status in [0, 1]:
    bus_passengers_description[holiday_status] = bus_merged[
        (bus_merged['holiday_or_weekend'] == holiday_status)
    ]['total_passenger'].describe()

pprint(bus_passengers_description)
# Out:
# {0: count    6.870000e+02
# mean     4.715515e+06
# std      2.770378e+05
# min      3.776811e+06
# 25%      4.566426e+06
# 50%      4.771566e+06
# 75%      4.905256e+06
# max      5.338460e+06
# Name: total_passenger, dtype: float64,
#  1: count    3.320000e+02
# mean     2.978559e+06
# std      5.740824e+05
# min      1.400020e+06
# 25%      2.601230e+06
# 50%      2.899443e+06
# 75%      3.464411e+06
# max      4.698326e+06
# Name: total_passenger, dtype: float64}

# %%
from pprint import pprint

train_passengers_description = {}

for holiday_status in [0, 1]:
    train_passengers_description[holiday_status] = train_merged[
        (train_merged['holiday_or_weekend'] == holiday_status)
    ]['total_passenger'].describe()

pprint(train_passengers_description)
# Out:
# {0: count    6.880000e+02
# mean     5.429680e+06
# std      4.126886e+05
# min      4.130808e+06
# 25%      5.228317e+06
# 50%      5.508950e+06
# 75%      5.717359e+06
# max      6.333782e+06
# Name: total_passenger, dtype: float64,
#  1: count    3.320000e+02
# mean     3.309337e+06
# std      7.588199e+05
# min      1.241418e+06
# 25%      2.792034e+06
# 50%      3.176252e+06
# 75%      3.967403e+06
# max      5.483267e+06
# Name: total_passenger, dtype: float64}

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 통계 데이터프레임 설정 (예시 코드)
statistics_bus = pd.DataFrame(bus_passengers_description).T
statistics_train = pd.DataFrame(train_passengers_description).T
statistics_bus = statistics_bus[['mean', 'max', 'min']]
statistics_train = statistics_train[['mean', 'max', 'min']]

# 인덱스 변경
statistics_bus.index = ['버스_평일 (0)', '버스_주말&공휴일 (1)']
statistics_train.index = ['지하철_평일 (2)', '지하철_주말&공휴일 (3)']

# 두 데이터프레임을 결합
statistics_combined = pd.concat([statistics_bus, statistics_train])

# 결합된 데이터프레임으로 시각화
statistics_combined.plot(kind='bar', figsize=(12, 6))
plt.title('버스 및 지하철 승객 수 통계')
plt.xticks(rotation=0)
plt.ylabel('승객 수')
plt.grid(axis='y')
plt.show()

# %%
# bus_merged.to_csv('transportation_bus.csv', index=False )

# %%
# train_merged.to_csv("transportation_train.csv", index = False)
