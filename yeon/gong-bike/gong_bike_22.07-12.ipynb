# %%
import requests

service_key = '445754734a6c656f363548676f6665'
url = f'http://openapi.seoul.go.kr:8088/{service_key}/json/tbCycleUseStatus/1/1000/2022-07-01'

# API 요청
response = requests.get(url)

# 응답 상태 확인
if response.status_code == 200:
    # 요청이 성공했을 경우 내용 출력
    print(response.content)
else:
    # 오류가 발생했을 경우 상태 코드 출력
    print(f"Request failed with status code: {response.status_code}")
# Out:
# b'{"useStatus":{"list_total_count":"2622","RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4."},"row":[{"STA_LOC":"\xeb\xa7\x88\xed\x8f\xac\xea\xb5\xac","RENT_NM":"108. \xec\x84\x9c\xea\xb5\x90\xeb\x8f\x99 \xec\x82\xac\xea\xb1\xb0\xeb\xa6\xac","STAT_DATA":"2022-07-01","RENT_CNT":"98","RTN_CNT":"93","START_INDEX":0,"END_INDEX":0,"RNUM":"1"},{"STA_LOC":"\xec\x96\x91\xec\xb2\x9c\xea\xb5\xac","RENT_NM":"729. \xec\x84\x9c\xeb\xb6\x80\xec\x8b\x9d\xec\x9e\x90\xec\x9e\xac\xeb\xa7\x88\xed\x8a\xb8 \xea\xb1\xb4\xeb\x84\x88\xed\x8e\xb8","STAT_DATA":"2022-07-01","RENT_CNT":"107","RTN_CNT":"126","START_INDEX":0,"END_INDEX":0,"RNUM":"2"},{"STA_LOC":"\xec\x96\x91\xec\xb2\x9c\xea\xb5\xac","RENT_NM":"731. \xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c \xeb\x8f\x84\xeb\xa1\x9c\xed\x99\x98\xea\xb2\xbd\xea\xb4\x80\xeb\xa6\xac\xec\x84\xbc\xed\x84\xb0","STAT_DATA":"2022-07-01","RENT_CNT":"102","RTN_CNT":"85","START_INDE
# ...

# %%
decoded_response_content = response.content.decode('utf-8')
decoded_response_content
# Out:
# '{"useStatus":{"list_total_count":"2622","RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다."},"row":[{"STA_LOC":"마포구","RENT_NM":"108. 서교동 사거리","STAT_DATA":"2022-07-01","RENT_CNT":"98","RTN_CNT":"93","START_INDEX":0,"END_INDEX":0,"RNUM":"1"},{"STA_LOC":"양천구","RENT_NM":"729. 서부식자재마트 건너편","STAT_DATA":"2022-07-01","RENT_CNT":"107","RTN_CNT":"126","START_INDEX":0,"END_INDEX":0,"RNUM":"2"},{"STA_LOC":"양천구","RENT_NM":"731. 서울시 도로환경관리센터","STAT_DATA":"2022-07-01","RENT_CNT":"102","RTN_CNT":"85","START_INDEX":0,"END_INDEX":0,"RNUM":"3"},{"STA_LOC":"양천구","RENT_NM":"732. 신월중학교","STAT_DATA":"2022-07-01","RENT_CNT":"74","RTN_CNT":"59","START_INDEX":0,"END_INDEX":0,"RNUM":"4"},{"STA_LOC":"양천구","RENT_NM":"733. 신정이펜하우스314동","STAT_DATA":"2022-07-01","RENT_CNT":"36","RTN_CNT":"17","START_INDEX":0,"END_INDEX":0,"RNUM":"5"},{"STA_LOC":"양천구","RENT_NM":"734. 신트리공원 입구","STAT_DATA":"2022-07-01","RENT_CNT":"132","RTN_CNT":"144","START_INDEX":0,"END_INDEX":0,"RNUM":"6"},{"STA_LOC":"양천구","RENT_NM":"735. 영도초등학교"
# ...

# %%
import json 

dict_content = json.loads(decoded_response_content) 
dict_content
# Out:
# {'useStatus': {'list_total_count': '2622',
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#   'row': [{'STA_LOC': '마포구',
#     'RENT_NM': '108. 서교동 사거리',
#     'STAT_DATA': '2022-07-01',
#     'RENT_CNT': '98',
#     'RTN_CNT': '93',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '1'},
#    {'STA_LOC': '양천구',
#     'RENT_NM': '729. 서부식자재마트 건너편',
#     'STAT_DATA': '2022-07-01',
#     'RENT_CNT': '107',
#     'RTN_CNT': '126',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '2'},
#    {'STA_LOC': '양천구',
#     'RENT_NM': '731. 서울시 도로환경관리센터',
#     'STAT_DATA': '2022-07-01',
#     'RENT_CNT': '102',
#     'RTN_CNT': '85',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '3'},
#    {'STA_LOC': '양천구',
#     'RENT_NM': '732. 신월중학교',
#     'STAT_DATA': '2022-07-01',
#     'RENT_CNT': '74',
#     'RTN_CNT': '59',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '4'},
#    {'STA_LOC': '양천구',
#     'RENT_NM': '733. 신정이펜하우스314동',
# ...

# %%
dict_content['useStatus']['row']
# Out:
# [{'STA_LOC': '마포구',
#   'RENT_NM': '108. 서교동 사거리',
#   'STAT_DATA': '2022-07-01',
#   'RENT_CNT': '98',
#   'RTN_CNT': '93',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '1'},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '729. 서부식자재마트 건너편',
#   'STAT_DATA': '2022-07-01',
#   'RENT_CNT': '107',
#   'RTN_CNT': '126',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '2'},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '731. 서울시 도로환경관리센터',
#   'STAT_DATA': '2022-07-01',
#   'RENT_CNT': '102',
#   'RTN_CNT': '85',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '3'},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '732. 신월중학교',
#   'STAT_DATA': '2022-07-01',
#   'RENT_CNT': '74',
#   'RTN_CNT': '59',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '4'},
#  {'STA_LOC': '양천구',
#   'RENT_NM': '733. 신정이펜하우스314동',
#   'STAT_DATA': '2022-07-01',
#   'RENT_CNT': '36',
#   'RTN_CNT': '17',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '5'},
#  {'STA_LOC': '양천구',
# ...

# %%
import pandas as pd 
df_content = pd.DataFrame(dict_content['useStatus']['row'])
print(df_content.columns)
# Out:
# Index(['STA_LOC', 'RENT_NM', 'STAT_DATA', 'RENT_CNT', 'RTN_CNT', 'START_INDEX',
#        'END_INDEX', 'RNUM'],
#       dtype='object')

# %%
df_bike = pd.DataFrame(dict_content['useStatus']['row'])
df_bike.head(3)
# Out:
#   STA_LOC            RENT_NM   STAT_DATA RENT_CNT RTN_CNT  START_INDEX  \
# 0     마포구       108. 서교동 사거리  2022-07-01       98      93            0
# 1     양천구   729. 서부식자재마트 건너편  2022-07-01      107     126            0
# 2     양천구  731. 서울시 도로환경관리센터  2022-07-01      102      85            0
#
#    END_INDEX RNUM
# 0          0    1
# 1          0    2
# 2          0    3

# %%
df_bike.to_csv("../bike-data/bike-data-220712.csv", encoding="utf-8", index=False)
