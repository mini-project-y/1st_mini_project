# %%
import pandas as pd

# %%
df_list = []

for idx in range(1, 13):
    # print("{0:02d}".format(idx))
    month_str = "{0:02d}".format(idx)
    df = pd.read_csv('../data-files2023/bike_data_23.{0}.csv'.format(month_str), encoding='cp949')
    df_list.append(df)

# %%
pd.concat(df_list)
# Out:
#                대여일자  대여소번호                           대여소 대여구분코드   성별   연령대  \
# 0        2023-01-01    735                   735. 영도초등학교    정기권  NaN  ~10대
# 1        2023-01-01    746                 746. 목동2단지 상가    정기권  NaN  ~10대
# 2        2023-01-01    505           505. 자양사거리 광진아크로텔 앞    정기권  NaN  ~10대
# 3        2023-01-01   1153       1153. 발산역 1번, 9번 인근 대여소    정기권  NaN  ~10대
# 4        2023-01-01   1155                 1155. 기쁜우리복지관    정기권  NaN  ~10대
# ...             ...    ...                           ...    ...  ...   ...
# 1272169  2023-12-31   2156               2156. 신림푸르지오아파트    정기권    M    기타
# 1272170  2023-12-31   3502                3502. 중곡역 1번출구    정기권    M    기타
# 1272171  2023-12-31   3505               3505. 신양초교앞 교차로    정기권    M    기타
# 1272172  2023-12-31    722  722. 경서농협 버스정류장(우리은행신정동지점방향)    정기권    M    기타
# 1272173  2023-12-31    726            726. 목동3단지 시내버스정류장    정기권    M    기타
#
#           이용건수     운동량   탄소량  이동거리(M)  이용시간(분)
# ...
